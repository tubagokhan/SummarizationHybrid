# %% [markdown]
# <a href="https://colab.research.google.com/github/tubagokhan/SummarizationHybrid/blob/main/ClusterandGraphPubMedNoWRank.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# !pip install datasets
# !pip install torch
# !pip install scikit-learn
# !pip install matplotlib
# !pip install sentence_transformers
# !pip install py-rouge==1.1
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.31.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.16.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.3.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.13.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.1)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.27.1)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.65.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.2.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.8.4)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.16.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (3.12.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (4.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.0.1+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (16.0.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.25.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.41.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.25.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: sentence_transformers in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.15.2+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.25.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.11.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.16.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (3.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2.27.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (4.7.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (23.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence_transformers) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence_transformers) (16.0.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2022.10.31)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.3.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence_transformers) (8.1.4)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence_transformers) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence_transformers) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence_transformers) (2.1.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence_transformers) (1.3.0)
# Requirement already satisfied: py-rouge==1.1 in /usr/local/lib/python3.10/dist-packages (1.1)

# %%
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sentence_transformers import SentenceTransformer
from nltk import sent_tokenize,word_tokenize

import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

import warnings
warnings.filterwarnings("ignore")
import re

from datasets import load_dataset
from scipy.spatial import distance

import math
from math import*

import rouge

import networkx as nx

import time
from transformers import logging
logging.set_verbosity_error()

import json
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# Preprocessing method
def preprocess_corpus(text):
    # Remove special characters and extra whitespaces
    text = re.sub(r"[^a-zA-Z0-9\s.]", "", text)
    text = re.sub(r"\s+", " ", text)
    return text

# %% [markdown]
# ## CLUSTER

# %%
#function calculates the optimal number of clusters using the elbow method. The function plots the elbow curve, which shows the inertia values for different cluster numbers. The user can visually inspect the plot to determine the elbow point, indicating the optimal number of clusters.
def find_optimum_clusters(data, max_clusters):
    inertias = []
    for k in range(1, max_clusters + 1):
        kmeans = KMeans(n_clusters=k, random_state=0).fit(data)
        inertias.append(kmeans.inertia_)

    # Plotting the elbow curve
    #plt.plot(range(1, max_clusters + 1), inertias)
    #plt.xlabel("Number of Clusters")
    #plt.ylabel("Inertia")
    #plt.title("Elbow Curve")
    #plt.show()

    # Calculate the optimal number of clusters using the elbow method
    diff = np.diff(inertias)
    acceleration = np.diff(diff)
    opt_cluster_num = acceleration.argmin() + 2  # Adding 2 to get the index of the minimum acceleration
    return opt_cluster_num

# %%
def createSummaryUsingKMeans(corpus, modelName):
    sentences = sent_tokenize(corpus)
    model = SentenceTransformer(modelName)
    sentence_embeddings = model.encode(sentences)

    optimum_clusters = find_optimum_clusters(sentence_embeddings, int(len(sentences) / 3))
    print("Optimum cluster number:", optimum_clusters)

    # Perform kmean clustering
    kmeans = KMeans(n_clusters=optimum_clusters, random_state=0, n_init='auto').fit(sentence_embeddings)

    chosen_sentence_indexes=[]
    for cluster_id in range(optimum_clusters):
        cluster_indices = np.where(kmeans.labels_ == cluster_id)[0]
        sorted_cluster_indices = sorted(cluster_indices, key=lambda x: sentences[x])
        chosen_sentence_index = sorted_cluster_indices[0]  # Select the first sentence from the sorted indices
        chosen_sentence_indexes.append(chosen_sentence_index)

    sorted_indexes=sorted(chosen_sentence_indexes)

    chosen_sentences = []
    for chosen_sentence_index in sorted_indexes:
        chosen_sentences.append(sentences[chosen_sentence_index])

    summary = " ".join(chosen_sentences)

    return summary

# %% [markdown]
# ## GRAPH NODE WEIGHTS

# %%
def allCorpusSentenceRanking(tokenizedCorpus,corpus):
    sentenceRankList=[]
    for i in range(len(tokenizedCorpus)):
        value=sentenceRanking(tokenizedCorpus[i],i,corpus)
        value=round(value,5)
        sentenceRankList.append(value)
    return sentenceRankList

def sentenceRanking(sentence,location,corpus):
    value=0
    value=sentencePosition(sentence,location,corpus)
    value=value+sentenceLength(sentence,corpus)
    value=value+properNoun(sentence,corpus)
    value=value+numericalToken(sentence,corpus)
    return value

def textWordCount(Text):
    number_of_words = word_tokenize(Text)
    count=(len(number_of_words))
    return count

def textSentenceCount(Text):
    number_of_sentences = sent_tokenize(Text)
    count=(len(number_of_sentences))
    return count

def longestSentenceLenght(Text):
    text=sent_tokenize(Text)
    temp=0
    for i in range(len(text)):
        if temp<textWordCount(text[i]):
            temp=textWordCount(text[i])
    return temp

def sentencePosition(sentence,location,corpus):
    N=textSentenceCount(corpus)
    if location+1 == N:
        return 1.0
    elif location==0:
        return 1.0
    else:
        value=(N-location)/N
        return value

def sentenceLength(sentence,corpus):
    return textWordCount(sentence)/longestSentenceLenght(corpus)

def properNoun(sentence,corpus):
    text = nltk.word_tokenize(sentence)
    tagged=nltk.pos_tag(text)
    noProperNoun=0
    #print(tagged)
    for word in tagged:
        if word[1]=='NNP':
            noProperNoun=noProperNoun+1
    #print(noProperNoun)
    return noProperNoun/len(text)

def numericalToken(sentence,corpus):
    text = nltk.word_tokenize(sentence)
    tagged=nltk.pos_tag(text)
    noNumericalToken=0
    #print(tagged)
    for word in tagged:
        if word[1]=='CD':
            noNumericalToken=noNumericalToken+1
  #print(noProperNoun)
    return 1-(noNumericalToken/len(text))

# %% [markdown]
# ## GRAPH

# %%
def cosine(u, v):
    return np.dot(u, v) / (np.linalg.norm(u) * np.linalg.norm(v))

def createGraph(sentences, modelName):
    model = SentenceTransformer(modelName)
    sentence_embeddings = model.encode(sentences)
    sentenceGraph =np.zeros((len(sentences), len(sentences)))
    temp = np.arange(len(sentences))
    for x in range(len(sentences)):
        newTemp= np.delete(temp, x)
        for y in newTemp:
            similarity= cosine(sentence_embeddings[x],sentence_embeddings[y]) # You can change the vector similarity measurement method used when creating graphs. Cosine, euclidean, manhattan and minkowski methods are defined.
            sentenceGraph[x][y]=abs(similarity)
    return sentenceGraph

def findHighestSimilarityRank(similarityMatrix, initialRank):
    newRank=[0] * len(similarityMatrix)
    temp=0
    for i in range(len(similarityMatrix)):
        for j in range(len(similarityMatrix)):
            temp=temp+similarityMatrix[i][j] # sum of total similarity of sentences
        newRank[i]=temp*initialRank[i]
        temp=0

    return newRank

def findHighestSimilarityRankNoWRANK(similarityMatrix, initialRank):

    nodeWeightLSARanks = initialRank

    for x in range(len(initialRank)):
        for y in range(len(initialRank)):
            temp=initialRank[x]+initialRank[y]
            similarityMatrix[x][y]=similarityMatrix[x][y]+temp*0.01
    G = nx.Graph()
    for x in range(len(initialRank)):
        for y in range(len(initialRank)):
            G.add_node(x)
            G.add_edge(x, y, weight=similarityMatrix[x,y] )
    eigenVectorCentrality = nx.eigenvector_centrality(G, max_iter=100, tol=1.0e-6, nstart=None, weight='weight')

    edgeWeightEigenVectorRanks=[0]*len(eigenVectorCentrality)
    for i in range (len(eigenVectorCentrality)):
        edgeWeightEigenVectorRanks[i]=eigenVectorCentrality[i]

    return edgeWeightEigenVectorRanks

def createSummaryUsingGraph(corpus,modelName):
  sentences = sent_tokenize(corpus)
  summaryAmmount= 7
  initialRank=allCorpusSentenceRanking(sentences,corpus)
  similarityMatrix=createGraph(sentences,modelName)
  sentencesRank=findHighestSimilarityRankNoWRANK(similarityMatrix, initialRank)

  temp=sorted(sentencesRank)
  threshold=temp[-summaryAmmount]
  summarySentencesIndexes=[]

  for i in range(len(sentencesRank)):
      if sentencesRank[i]>=threshold:
        summarySentencesIndexes.append(i)

  #print(summarySentencesIndexes)
  summary=""
  for i in range(len(summarySentencesIndexes)):
    summary=summary + ' ' +sentences[summarySentencesIndexes[i]]
  return summary

# %%
#MAIN
modelName='all-mpnet-base-v2'

#dataset = load_dataset('cnn_dailymail', '3.0.0')
#corpus = dataset['train']['article'][50]


dataset = load_dataset("scientific_papers","pubmed")


startTimeforOverall = time.time()
all_intermediate_summary=[]
all_summary=[]
all_goldstandart=[]

N=500
startN=0

for d in range(N):
    startTimeforDocument = time.time()
    print("Document:",startN+d+1)
    corpus=dataset['train']['article'][startN+d]
    corpus = preprocess_corpus(corpus)
    #print(corpus)
    print("Document sentence number:",textSentenceCount(corpus))
    all_goldstandart.append(dataset['train']['abstract'][startN+d])

    if (textSentenceCount(corpus)>8):
      intermadiatesummary=createSummaryUsingKMeans(corpus, modelName)
      print("Intermediate summary sentence number:",textSentenceCount(intermadiatesummary))
      all_intermediate_summary.append(intermadiatesummary)

      if (textSentenceCount(intermadiatesummary)>8):
        summary=createSummaryUsingGraph(intermadiatesummary, modelName)
        print("Final summary sentence number:",textSentenceCount(summary))
        all_summary.append(summary)

      else:
        print("Intermediate summary is shorter than 9 sentences, Second step didn't applied")
        all_summary.append(intermadiatesummary)


    else:
      print("Document is shorter than 9 sentences, Summarization didnt apply")
      all_intermediate_summary.append(corpus)
      all_summary.append(corpus)



    elapsedTimeforDocument = time.time() - startTimeforDocument
    elapsedTimeforAll = time.time() - startTimeforOverall
    print('Document processing time: '+time.strftime("%M:%S", time.gmtime(elapsedTimeforDocument)))
    print('Total processing time: '+time.strftime("%d:%H:%M:%S", time.gmtime(elapsedTimeforAll)))

    print("----------------------------------")
# Out:
# WARNING:datasets.builder:Found cached dataset scientific_papers (/root/.cache/huggingface/datasets/scientific_papers/pubmed/1.1.1/306757013fb6f37089b6a75469e6638a553bd9f009484938d8f75a4c5e84206f)
#   0%|          | 0/3 [00:00<?, ?it/s]
# Document: 1
# Document sentence number: 173
# Optimum cluster number: 20
# Intermediate summary sentence number: 20
# Final summary sentence number: 7
# Document processing time: 01:30
# Total processing time: 01:00:01:30
# ----------------------------------
# Document: 2
# Document sentence number: 81
# Optimum cluster number: 8
# Intermediate summary sentence number: 8
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:25
# Total processing time: 01:00:01:55
# ----------------------------------
# Document: 3
# Document sentence number: 45
# Optimum cluster number: 9
# Intermediate summary sentence number: 9
# Final summary sentence number: 7
# Document processing time: 00:12
# Total processing time: 01:00:02:07
# ----------------------------------
# Document: 4
# Document sentence number: 199
# Optimum cluster number: 27
# Intermediate summary sentence number: 27
# Final summary sentence number: 7
# Document processing time: 01:46
# Total processing time: 01:00:03:53
# ----------------------------------
# Document: 5
# Document sentence number: 42
# Optimum cluster number: 5
# Intermediate summary sentence number: 5
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:10
# Total processing time: 01:00:04:03
# ----------------------------------
# Document: 6
# Document sentence number: 95
# Optimum cluster number: 8
# Intermediate summary sentence number: 8
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:39
# Total processing time: 01:00:04:43
# ----------------------------------
# Document: 7
# Document sentence number: 47
# Optimum cluster number: 14
# Intermediate summary sentence number: 14
# Final summary sentence number: 7
# Document processing time: 00:15
# Total processing time: 01:00:04:58
# ----------------------------------
# Document: 8
# Document sentence number: 91
# Optimum cluster number: 16
# Intermediate summary sentence number: 16
# Final summary sentence number: 7
# Document processing time: 00:40
# Total processing time: 01:00:05:38
# ----------------------------------
# Document: 9
# Document sentence number: 97
# Optimum cluster number: 14
# Intermediate summary sentence number: 14
# Final summary sentence number: 7
# Document processing time: 00:43
# Total processing time: 01:00:06:22
# ----------------------------------
# Document: 10
# Document sentence number: 29
# Optimum cluster number: 6
# Intermediate summary sentence number: 6
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:00:06:30
# ----------------------------------
# Document: 11
# Document sentence number: 125
# Optimum cluster number: 21
# Intermediate summary sentence number: 21
# Final summary sentence number: 7
# Document processing time: 01:00
# Total processing time: 01:00:07:30
# ----------------------------------
# Document: 12
# Document sentence number: 0
# Document is shorter than 9 sentences, Summarization didnt apply
# Document processing time: 00:01
# Total processing time: 01:00:07:32
# ----------------------------------
# Document: 13
# Document sentence number: 150
# Optimum cluster number: 24
# Intermediate summary sentence number: 24
# Final summary sentence number: 7
# Document processing time: 01:16
# Total processing time: 01:00:08:48
# ----------------------------------
# Document: 14
# Document sentence number: 222
# Optimum cluster number: 14
# Intermediate summary sentence number: 14
# Final summary sentence number: 7
# Document processing time: 02:05
# Total processing time: 01:00:10:54
# ----------------------------------
# Document: 15
# Document sentence number: 24
# Optimum cluster number: 4
# Intermediate summary sentence number: 4
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:06
# Total processing time: 01:00:11:01
# ----------------------------------
# Document: 16
# Document sentence number: 100
# Optimum cluster number: 7
# Intermediate summary sentence number: 7
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:42
# Total processing time: 01:00:11:44
# ----------------------------------
# Document: 17
# Document sentence number: 54
# Optimum cluster number: 7
# Intermediate summary sentence number: 7
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:13
# Total processing time: 01:00:11:58
# ----------------------------------
# Document: 18
# Document sentence number: 45
# Optimum cluster number: 10
# Intermediate summary sentence number: 10
# Final summary sentence number: 7
# Document processing time: 00:13
# Total processing time: 01:00:12:12
# ----------------------------------
# Document: 19
# Document sentence number: 123
# Optimum cluster number: 9
# Intermediate summary sentence number: 9
# Final summary sentence number: 7
# Document processing time: 00:59
# Total processing time: 01:00:13:11
# ----------------------------------
# Document: 20
# Document sentence number: 86
# Optimum cluster number: 6
# Intermediate summary sentence number: 6
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:34
# Total processing time: 01:00:13:46
# ----------------------------------
# Document: 21
# Document sentence number: 65
# Optimum cluster number: 18
# Intermediate summary sentence number: 18
# Final summary sentence number: 7
# Document processing time: 00:17
# Total processing time: 01:00:14:04
# ----------------------------------
# Document: 22
# Document sentence number: 71
# Optimum cluster number: 8
# Intermediate summary sentence number: 8
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:17
# Total processing time: 01:00:14:21
# ----------------------------------
# Document: 23
# Document sentence number: 0
# Document is shorter than 9 sentences, Summarization didnt apply
# Document processing time: 00:01
# Total processing time: 01:00:14:22
# ----------------------------------
# Document: 24
# Document sentence number: 104
# Optimum cluster number: 21
# Intermediate summary sentence number: 21
# Final summary sentence number: 7
# Document processing time: 00:48
# Total processing time: 01:00:15:11
# ----------------------------------
# Document: 25
# Document sentence number: 233
# Optimum cluster number: 18
# Intermediate summary sentence number: 18
# Final summary sentence number: 7
# Document processing time: 02:08
# Total processing time: 01:00:17:19
# ----------------------------------
# Document: 26
# Document sentence number: 81
# Optimum cluster number: 18
# Intermediate summary sentence number: 18
# Final summary sentence number: 7
# Document processing time: 00:27
# Total processing time: 01:00:17:47
# ----------------------------------
# Document: 27
# Document sentence number: 199
# Optimum cluster number: 41
# Intermediate summary sentence number: 41
# Final summary sentence number: 7
# Document processing time: 01:50
# Total processing time: 01:00:19:38
# ----------------------------------
# Document: 28
# Document sentence number: 38
# Optimum cluster number: 9
# Intermediate summary sentence number: 9
# Final summary sentence number: 7
# Document processing time: 00:10
# Total processing time: 01:00:19:48
# ----------------------------------
# Document: 29
# Document sentence number: 91
# Optimum cluster number: 12
# Intermediate summary sentence number: 12
# Final summary sentence number: 7
# Document processing time: 00:41
# Total processing time: 01:00:20:29
# ----------------------------------
# Document: 30
# Document sentence number: 83
# Optimum cluster number: 14
# Intermediate summary sentence number: 14
# Final summary sentence number: 7
# Document processing time: 00:26
# Total processing time: 01:00:20:56
# ----------------------------------
# Document: 31
# Document sentence number: 31
# Optimum cluster number: 9
# Intermediate summary sentence number: 9
# Final summary sentence number: 7
# Document processing time: 00:08
# Total processing time: 01:00:21:05
# ----------------------------------
# Document: 32
# Document sentence number: 84
# Optimum cluster number: 12
# Intermediate summary sentence number: 12
# Final summary sentence number: 7
# Document processing time: 00:28
# Total processing time: 01:00:21:33
# ----------------------------------
# Document: 33
# Document sentence number: 92
# Optimum cluster number: 15
# Intermediate summary sentence number: 15
# Final summary sentence number: 7
# Document processing time: 00:39
# Total processing time: 01:00:22:12
# ----------------------------------
# Document: 34
# Document sentence number: 193
# Optimum cluster number: 51
# Intermediate summary sentence number: 51
# Final summary sentence number: 7
# Document processing time: 01:44
# Total processing time: 01:00:23:57
# ----------------------------------
# Document: 35
# Document sentence number: 82
# Optimum cluster number: 19
# Intermediate summary sentence number: 19
# Final summary sentence number: 7
# Document processing time: 00:26
# Total processing time: 01:00:24:23
# ----------------------------------
# Document: 36
# Document sentence number: 69
# Optimum cluster number: 16
# Intermediate summary sentence number: 16
# Final summary sentence number: 7
# Document processing time: 00:18
# Total processing time: 01:00:24:42
# ----------------------------------
# Document: 37
# Document sentence number: 172
# Optimum cluster number: 12
# Intermediate summary sentence number: 12
# Final summary sentence number: 7
# Document processing time: 01:28
# Total processing time: 01:00:26:10
# ----------------------------------
# Document: 38
# Document sentence number: 62
# Optimum cluster number: 10
# Intermediate summary sentence number: 10
# Final summary sentence number: 7
# Document processing time: 00:15
# Total processing time: 01:00:26:25
# ----------------------------------
# Document: 39
# Document sentence number: 130
# Optimum cluster number: 25
# Intermediate summary sentence number: 25
# Final summary sentence number: 7
# Document processing time: 01:05
# Total processing time: 01:00:27:31
# ----------------------------------
# Document: 40
# Document sentence number: 69
# Optimum cluster number: 15
# Intermediate summary sentence number: 15
# Final summary sentence number: 7
# Document processing time: 00:18
# Total processing time: 01:00:27:50
# ----------------------------------
# Document: 41
# Document sentence number: 102
# Optimum cluster number: 11
# Intermediate summary sentence number: 11
# Final summary sentence number: 7
# Document processing time: 00:45
# Total processing time: 01:00:28:36
# ----------------------------------
# Document: 42
# Document sentence number: 128
# Optimum cluster number: 24
# Intermediate summary sentence number: 24
# Final summary sentence number: 7
# Document processing time: 01:03
# Total processing time: 01:00:29:39
# ----------------------------------
# Document: 43
# Document sentence number: 70
# Optimum cluster number: 20
# Intermediate summary sentence number: 20
# Final summary sentence number: 7
# Document processing time: 00:19
# Total processing time: 01:00:29:58
# ----------------------------------
# Document: 44
# Document sentence number: 68
# Optimum cluster number: 13
# Intermediate summary sentence number: 13
# Final summary sentence number: 7
# Document processing time: 00:17
# Total processing time: 01:00:30:16
# ----------------------------------
# Document: 45
# Document sentence number: 37
# Optimum cluster number: 8
# Intermediate summary sentence number: 8
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:08
# Total processing time: 01:00:30:25
# ----------------------------------
# Document: 46
# Document sentence number: 135
# Optimum cluster number: 12
# Intermediate summary sentence number: 12
# Final summary sentence number: 7
# Document processing time: 01:06
# Total processing time: 01:00:31:31
# ----------------------------------
# Document: 47
# Document sentence number: 144
# Optimum cluster number: 10
# Intermediate summary sentence number: 10
# Final summary sentence number: 7
# Document processing time: 01:13
# Total processing time: 01:00:32:44
# ----------------------------------
# Document: 48
# Document sentence number: 113
# Optimum cluster number: 31
# Intermediate summary sentence number: 31
# Final summary sentence number: 7
# Document processing time: 00:53
# Total processing time: 01:00:33:38
# ----------------------------------
# Document: 49
# Document sentence number: 159
# Optimum cluster number: 14
# Intermediate summary sentence number: 14
# Final summary sentence number: 7
# Document processing time: 01:21
# Total processing time: 01:00:34:59
# ----------------------------------
# Document: 50
# Document sentence number: 132
# Optimum cluster number: 20
# Intermediate summary sentence number: 20
# Final summary sentence number: 7
# Document processing time: 01:06
# Total processing time: 01:00:36:06
# ----------------------------------
# Document: 51
# Document sentence number: 0
# Document is shorter than 9 sentences, Summarization didnt apply
# Document processing time: 00:01
# Total processing time: 01:00:36:07
# ----------------------------------
# Document: 52
# Document sentence number: 77
# Optimum cluster number: 8
# Intermediate summary sentence number: 8
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:20
# Total processing time: 01:00:36:28
# ----------------------------------
# Document: 53
# Document sentence number: 42
# Optimum cluster number: 7
# Intermediate summary sentence number: 7
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:11
# Total processing time: 01:00:36:39
# ----------------------------------
# Document: 54
# Document sentence number: 20
# Optimum cluster number: 4
# Intermediate summary sentence number: 4
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:05
# Total processing time: 01:00:36:44
# ----------------------------------
# Document: 55
# Document sentence number: 83
# Optimum cluster number: 9
# Intermediate summary sentence number: 9
# Final summary sentence number: 7
# Document processing time: 00:26
# Total processing time: 01:00:37:11
# ----------------------------------
# Document: 56
# Document sentence number: 66
# Optimum cluster number: 16
# Intermediate summary sentence number: 16
# Final summary sentence number: 7
# Document processing time: 00:18
# Total processing time: 01:00:37:30
# ----------------------------------
# Document: 57
# Document sentence number: 29
# Optimum cluster number: 7
# Intermediate summary sentence number: 7
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:00:37:38
# ----------------------------------
# Document: 58
# Document sentence number: 67
# Optimum cluster number: 14
# Intermediate summary sentence number: 14
# Final summary sentence number: 7
# Document processing time: 00:17
# Total processing time: 01:00:37:55
# ----------------------------------
# Document: 59
# Document sentence number: 309
# Optimum cluster number: 8
# Intermediate summary sentence number: 8
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 03:04
# Total processing time: 01:00:41:00
# ----------------------------------
# Document: 60
# Document sentence number: 337
# Optimum cluster number: 9
# Intermediate summary sentence number: 9
# Final summary sentence number: 7
# Document processing time: 03:28
# Total processing time: 01:00:44:28
# ----------------------------------
# Document: 61
# Document sentence number: 118
# Optimum cluster number: 8
# Intermediate summary sentence number: 8
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:55
# Total processing time: 01:00:45:23
# ----------------------------------
# Document: 62
# Document sentence number: 22
# Optimum cluster number: 5
# Intermediate summary sentence number: 5
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:06
# Total processing time: 01:00:45:29
# ----------------------------------
# Document: 63
# Document sentence number: 87
# Optimum cluster number: 14
# Intermediate summary sentence number: 14
# Final summary sentence number: 7
# Document processing time: 00:38
# Total processing time: 01:00:46:08
# ----------------------------------
# Document: 64
# Document sentence number: 100
# Optimum cluster number: 12
# Intermediate summary sentence number: 12
# Final summary sentence number: 7
# Document processing time: 00:43
# Total processing time: 01:00:46:52
# ----------------------------------
# Document: 65
# Document sentence number: 114
# Optimum cluster number: 20
# Intermediate summary sentence number: 20
# Final summary sentence number: 7
# Document processing time: 00:53
# Total processing time: 01:00:47:46
# ----------------------------------
# Document: 66
# Document sentence number: 99
# Optimum cluster number: 8
# Intermediate summary sentence number: 8
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:42
# Total processing time: 01:00:48:28
# ----------------------------------
# Document: 67
# Document sentence number: 28
# Optimum cluster number: 4
# Intermediate summary sentence number: 4
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:00:48:35
# ----------------------------------
# Document: 68
# Document sentence number: 63
# Optimum cluster number: 12
# Intermediate summary sentence number: 12
# Final summary sentence number: 7
# Document processing time: 00:16
# Total processing time: 01:00:48:52
# ----------------------------------
# Document: 69
# Document sentence number: 54
# Optimum cluster number: 7
# Intermediate summary sentence number: 7
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:12
# Total processing time: 01:00:49:04
# ----------------------------------
# Document: 70
# Document sentence number: 31
# Optimum cluster number: 6
# Intermediate summary sentence number: 6
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:00:49:12
# ----------------------------------
# Document: 71
# Document sentence number: 77
# Optimum cluster number: 5
# Intermediate summary sentence number: 5
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:19
# Total processing time: 01:00:49:31
# ----------------------------------
# Document: 72
# Document sentence number: 14
# Optimum cluster number: 3
# Intermediate summary sentence number: 3
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:04
# Total processing time: 01:00:49:36
# ----------------------------------
# Document: 73
# Document sentence number: 95
# Optimum cluster number: 16
# Intermediate summary sentence number: 16
# Final summary sentence number: 7
# Document processing time: 00:40
# Total processing time: 01:00:50:17
# ----------------------------------
# Document: 74
# Document sentence number: 111
# Optimum cluster number: 6
# Intermediate summary sentence number: 6
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:48
# Total processing time: 01:00:51:05
# ----------------------------------
# Document: 75
# Document sentence number: 36
# Optimum cluster number: 9
# Intermediate summary sentence number: 9
# Final summary sentence number: 7
# Document processing time: 00:10
# Total processing time: 01:00:51:15
# ----------------------------------
# Document: 76
# Document sentence number: 76
# Optimum cluster number: 11
# Intermediate summary sentence number: 11
# Final summary sentence number: 7
# Document processing time: 00:19
# Total processing time: 01:00:51:35
# ----------------------------------
# Document: 77
# Document sentence number: 188
# Optimum cluster number: 13
# Intermediate summary sentence number: 13
# Final summary sentence number: 7
# Document processing time: 01:36
# Total processing time: 01:00:53:12
# ----------------------------------
# Document: 78
# Document sentence number: 40
# Optimum cluster number: 5
# Intermediate summary sentence number: 5
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:09
# Total processing time: 01:00:53:22
# ----------------------------------
# Document: 79
# Document sentence number: 134
# Optimum cluster number: 15
# Intermediate summary sentence number: 15
# Final summary sentence number: 7
# Document processing time: 01:04
# Total processing time: 01:00:54:26
# ----------------------------------
# Document: 80
# Document sentence number: 162
# Optimum cluster number: 31
# Intermediate summary sentence number: 31
# Final summary sentence number: 7
# Document processing time: 01:21
# Total processing time: 01:00:55:48
# ----------------------------------
# Document: 81
# Document sentence number: 100
# Optimum cluster number: 17
# Intermediate summary sentence number: 17
# Final summary sentence number: 7
# Document processing time: 00:44
# Total processing time: 01:00:56:32
# ----------------------------------
# Document: 82
# Document sentence number: 157
# Optimum cluster number: 10
# Intermediate summary sentence number: 10
# Final summary sentence number: 7
# Document processing time: 01:19
# Total processing time: 01:00:57:52
# ----------------------------------
# Document: 83
# Document sentence number: 78
# Optimum cluster number: 11
# Intermediate summary sentence number: 11
# Final summary sentence number: 7
# Document processing time: 00:21
# Total processing time: 01:00:58:14
# ----------------------------------
# Document: 84
# Document sentence number: 52
# Optimum cluster number: 8
# Intermediate summary sentence number: 8
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:12
# Total processing time: 01:00:58:26
# ----------------------------------
# Document: 85
# Document sentence number: 24
# Optimum cluster number: 6
# Intermediate summary sentence number: 6
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:00:58:34
# ----------------------------------
# Document: 86
# Document sentence number: 112
# Optimum cluster number: 14
# Intermediate summary sentence number: 14
# Final summary sentence number: 7
# Document processing time: 00:49
# Total processing time: 01:00:59:23
# ----------------------------------
# Document: 87
# Document sentence number: 141
# Optimum cluster number: 13
# Intermediate summary sentence number: 13
# Final summary sentence number: 7
# Document processing time: 01:10
# Total processing time: 01:01:00:34
# ----------------------------------
# Document: 88
# Document sentence number: 251
# Optimum cluster number: 17
# Intermediate summary sentence number: 17
# Final summary sentence number: 7
# Document processing time: 02:22
# Total processing time: 01:01:02:57
# ----------------------------------
# Document: 89
# Document sentence number: 95
# Optimum cluster number: 9
# Intermediate summary sentence number: 9
# Final summary sentence number: 7
# Document processing time: 00:40
# Total processing time: 01:01:03:38
# ----------------------------------
# Document: 90
# Document sentence number: 115
# Optimum cluster number: 11
# Intermediate summary sentence number: 11
# Final summary sentence number: 7
# Document processing time: 00:54
# Total processing time: 01:01:04:32
# ----------------------------------
# Document: 91
# Document sentence number: 92
# Optimum cluster number: 18
# Intermediate summary sentence number: 18
# Final summary sentence number: 7
# Document processing time: 00:38
# Total processing time: 01:01:05:11
# ----------------------------------
# Document: 92
# Document sentence number: 149
# Optimum cluster number: 23
# Intermediate summary sentence number: 23
# Final summary sentence number: 7
# Document processing time: 01:13
# Total processing time: 01:01:06:25
# ----------------------------------
# Document: 93
# Document sentence number: 63
# Optimum cluster number: 11
# Intermediate summary sentence number: 11
# Final summary sentence number: 7
# Document processing time: 00:15
# Total processing time: 01:01:06:41
# ----------------------------------
# Document: 94
# Document sentence number: 75
# Optimum cluster number: 9
# Intermediate summary sentence number: 9
# Final summary sentence number: 7
# Document processing time: 00:20
# Total processing time: 01:01:07:01
# ----------------------------------
# Document: 95
# Document sentence number: 1
# Document is shorter than 9 sentences, Summarization didnt apply
# Document processing time: 00:01
# Total processing time: 01:01:07:02
# ----------------------------------
# Document: 96
# Document sentence number: 97
# Optimum cluster number: 18
# Intermediate summary sentence number: 18
# Final summary sentence number: 7
# Document processing time: 00:42
# Total processing time: 01:01:07:45
# ----------------------------------
# Document: 97
# Document sentence number: 32
# Optimum cluster number: 9
# Intermediate summary sentence number: 9
# Final summary sentence number: 7
# Document processing time: 00:09
# Total processing time: 01:01:07:54
# ----------------------------------
# Document: 98
# Document sentence number: 108
# Optimum cluster number: 14
# Intermediate summary sentence number: 14
# Final summary sentence number: 7
# Document processing time: 00:49
# Total processing time: 01:01:08:44
# ----------------------------------
# Document: 99
# Document sentence number: 148
# Optimum cluster number: 18
# Intermediate summary sentence number: 18
# Final summary sentence number: 7
# Document processing time: 01:13
# Total processing time: 01:01:09:57
# ----------------------------------
# Document: 100
# Document sentence number: 153
# Optimum cluster number: 8
# Intermediate summary sentence number: 8
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 01:17
# Total processing time: 01:01:11:15
# ----------------------------------
# Document: 101
# Document sentence number: 38
# Optimum cluster number: 6
# Intermediate summary sentence number: 6
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:09
# Total processing time: 01:01:11:24
# ----------------------------------
# Document: 102
# Document sentence number: 89
# Optimum cluster number: 15
# Intermediate summary sentence number: 15
# Final summary sentence number: 7
# Document processing time: 00:38
# Total processing time: 01:01:12:02
# ----------------------------------
# Document: 103
# Document sentence number: 211
# Optimum cluster number: 24
# Intermediate summary sentence number: 24
# Final summary sentence number: 7
# Document processing time: 01:56
# Total processing time: 01:01:13:59
# ----------------------------------
# Document: 104
# Document sentence number: 100
# Optimum cluster number: 11
# Intermediate summary sentence number: 11
# Final summary sentence number: 7
# Document processing time: 00:43
# Total processing time: 01:01:14:42
# ----------------------------------
# Document: 105
# Document sentence number: 138
# Optimum cluster number: 27
# Intermediate summary sentence number: 27
# Final summary sentence number: 7
# Document processing time: 01:08
# Total processing time: 01:01:15:51
# ----------------------------------
# Document: 106
# Document sentence number: 54
# Optimum cluster number: 4
# Intermediate summary sentence number: 4
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:12
# Total processing time: 01:01:16:04
# ----------------------------------
# Document: 107
# Document sentence number: 171
# Optimum cluster number: 28
# Intermediate summary sentence number: 28
# Final summary sentence number: 7
# Document processing time: 01:30
# Total processing time: 01:01:17:34
# ----------------------------------
# Document: 108
# Document sentence number: 63
# Optimum cluster number: 15
# Intermediate summary sentence number: 15
# Final summary sentence number: 7
# Document processing time: 00:16
# Total processing time: 01:01:17:51
# ----------------------------------
# Document: 109
# Document sentence number: 34
# Optimum cluster number: 9
# Intermediate summary sentence number: 9
# Final summary sentence number: 7
# Document processing time: 00:11
# Total processing time: 01:01:18:02
# ----------------------------------
# Document: 110
# Document sentence number: 148
# Optimum cluster number: 24
# Intermediate summary sentence number: 24
# Final summary sentence number: 7
# Document processing time: 01:13
# Total processing time: 01:01:19:16
# ----------------------------------
# Document: 111
# Document sentence number: 84
# Optimum cluster number: 6
# Intermediate summary sentence number: 6
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:27
# Total processing time: 01:01:19:43
# ----------------------------------
# Document: 112
# Document sentence number: 61
# Optimum cluster number: 18
# Intermediate summary sentence number: 18
# Final summary sentence number: 7
# Document processing time: 00:16
# Total processing time: 01:01:19:59
# ----------------------------------
# Document: 113
# Document sentence number: 152
# Optimum cluster number: 7
# Intermediate summary sentence number: 7
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 01:13
# Total processing time: 01:01:21:12
# ----------------------------------
# Document: 114
# Document sentence number: 111
# Optimum cluster number: 17
# Intermediate summary sentence number: 17
# Final summary sentence number: 7
# Document processing time: 00:53
# Total processing time: 01:01:22:05
# ----------------------------------
# Document: 115
# Document sentence number: 41
# Optimum cluster number: 10
# Intermediate summary sentence number: 10
# Final summary sentence number: 7
# Document processing time: 00:10
# Total processing time: 01:01:22:16
# ----------------------------------
# Document: 116
# Document sentence number: 119
# Optimum cluster number: 33
# Intermediate summary sentence number: 33
# Final summary sentence number: 7
# Document processing time: 00:56
# Total processing time: 01:01:23:13
# ----------------------------------
# Document: 117
# Document sentence number: 332
# Optimum cluster number: 23
# Intermediate summary sentence number: 23
# Final summary sentence number: 7
# Document processing time: 03:25
# Total processing time: 01:01:26:39
# ----------------------------------
# Document: 118
# Document sentence number: 41
# Optimum cluster number: 12
# Intermediate summary sentence number: 12
# Final summary sentence number: 7
# Document processing time: 00:11
# Total processing time: 01:01:26:50
# ----------------------------------
# Document: 119
# Document sentence number: 80
# Optimum cluster number: 7
# Intermediate summary sentence number: 7
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:23
# Total processing time: 01:01:27:13
# ----------------------------------
# Document: 120
# Document sentence number: 78
# Optimum cluster number: 16
# Intermediate summary sentence number: 16
# Final summary sentence number: 7
# Document processing time: 00:24
# Total processing time: 01:01:27:37
# ----------------------------------
# Document: 121
# Document sentence number: 90
# Optimum cluster number: 5
# Intermediate summary sentence number: 5
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:38
# Total processing time: 01:01:28:16
# ----------------------------------
# Document: 122
# Document sentence number: 154
# Optimum cluster number: 19
# Intermediate summary sentence number: 19
# Final summary sentence number: 7
# Document processing time: 01:17
# Total processing time: 01:01:29:34
# ----------------------------------
# Document: 123
# Document sentence number: 66
# Optimum cluster number: 10
# Intermediate summary sentence number: 10
# Final summary sentence number: 7
# Document processing time: 00:17
# Total processing time: 01:01:29:52
# ----------------------------------
# Document: 124
# Document sentence number: 29
# Optimum cluster number: 5
# Intermediate summary sentence number: 5
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:01:29:59
# ----------------------------------
# Document: 125
# Document sentence number: 122
# Optimum cluster number: 23
# Intermediate summary sentence number: 23
# Final summary sentence number: 7
# Document processing time: 00:59
# Total processing time: 01:01:30:58
# ----------------------------------
# Document: 126
# Document sentence number: 145
# Optimum cluster number: 22
# Intermediate summary sentence number: 22
# Final summary sentence number: 7
# Document processing time: 01:16
# Total processing time: 01:01:32:14
# ----------------------------------
# Document: 127
# Document sentence number: 115
# Optimum cluster number: 28
# Intermediate summary sentence number: 28
# Final summary sentence number: 7
# Document processing time: 00:55
# Total processing time: 01:01:33:10
# ----------------------------------
# Document: 128
# Document sentence number: 77
# Optimum cluster number: 20
# Intermediate summary sentence number: 20
# Final summary sentence number: 7
# Document processing time: 00:20
# Total processing time: 01:01:33:31
# ----------------------------------
# Document: 129
# Document sentence number: 7
# Document is shorter than 9 sentences, Summarization didnt apply
# Document processing time: 00:01
# Total processing time: 01:01:33:32
# ----------------------------------
# Document: 130
# Document sentence number: 260
# Optimum cluster number: 11
# Intermediate summary sentence number: 11
# Final summary sentence number: 7
# Document processing time: 02:25
# Total processing time: 01:01:35:57
# ----------------------------------
# Document: 131
# Document sentence number: 145
# Optimum cluster number: 9
# Intermediate summary sentence number: 9
# Final summary sentence number: 7
# Document processing time: 01:12
# Total processing time: 01:01:37:09
# ----------------------------------
# Document: 132
# Document sentence number: 242
# Optimum cluster number: 20
# Intermediate summary sentence number: 20
# Final summary sentence number: 7
# Document processing time: 02:15
# Total processing time: 01:01:39:25
# ----------------------------------
# Document: 133
# Document sentence number: 166
# Optimum cluster number: 5
# Intermediate summary sentence number: 5
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 01:24
# Total processing time: 01:01:40:49
# ----------------------------------
# Document: 134
# Document sentence number: 75
# Optimum cluster number: 10
# Intermediate summary sentence number: 10
# Final summary sentence number: 7
# Document processing time: 00:24
# Total processing time: 01:01:41:13
# ----------------------------------
# Document: 135
# Document sentence number: 120
# Optimum cluster number: 30
# Intermediate summary sentence number: 30
# Final summary sentence number: 7
# Document processing time: 00:59
# Total processing time: 01:01:42:13
# ----------------------------------
# Document: 136
# Document sentence number: 348
# Optimum cluster number: 23
# Intermediate summary sentence number: 23
# Final summary sentence number: 7
# Document processing time: 03:43
# Total processing time: 01:01:45:56
# ----------------------------------
# Document: 137
# Document sentence number: 27
# Optimum cluster number: 7
# Intermediate summary sentence number: 7
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:01:46:04
# ----------------------------------
# Document: 138
# Document sentence number: 56
# Optimum cluster number: 6
# Intermediate summary sentence number: 6
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:13
# Total processing time: 01:01:46:17
# ----------------------------------
# Document: 139
# Document sentence number: 70
# Optimum cluster number: 6
# Intermediate summary sentence number: 6
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:18
# Total processing time: 01:01:46:35
# ----------------------------------
# Document: 140
# Document sentence number: 40
# Optimum cluster number: 4
# Intermediate summary sentence number: 4
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:09
# Total processing time: 01:01:46:45
# ----------------------------------
# Document: 141
# Document sentence number: 92
# Optimum cluster number: 6
# Intermediate summary sentence number: 6
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:38
# Total processing time: 01:01:47:24
# ----------------------------------
# Document: 142
# Document sentence number: 61
# Optimum cluster number: 7
# Intermediate summary sentence number: 7
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:14
# Total processing time: 01:01:47:38
# ----------------------------------
# Document: 143
# Document sentence number: 144
# Optimum cluster number: 25
# Intermediate summary sentence number: 25
# Final summary sentence number: 7
# Document processing time: 01:17
# Total processing time: 01:01:48:55
# ----------------------------------
# Document: 144
# Document sentence number: 60
# Optimum cluster number: 13
# Intermediate summary sentence number: 13
# Final summary sentence number: 7
# Document processing time: 00:15
# Total processing time: 01:01:49:11
# ----------------------------------
# Document: 145
# Document sentence number: 224
# Optimum cluster number: 15
# Intermediate summary sentence number: 15
# Final summary sentence number: 7
# Document processing time: 02:02
# Total processing time: 01:01:51:13
# ----------------------------------
# Document: 146
# Document sentence number: 49
# Optimum cluster number: 12
# Intermediate summary sentence number: 12
# Final summary sentence number: 7
# Document processing time: 00:12
# Total processing time: 01:01:51:25
# ----------------------------------
# Document: 147
# Document sentence number: 79
# Optimum cluster number: 3
# Intermediate summary sentence number: 3
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:20
# Total processing time: 01:01:51:46
# ----------------------------------
# Document: 148
# Document sentence number: 143
# Optimum cluster number: 27
# Intermediate summary sentence number: 27
# Final summary sentence number: 7
# Document processing time: 01:10
# Total processing time: 01:01:52:56
# ----------------------------------
# Document: 149
# Document sentence number: 237
# Optimum cluster number: 15
# Intermediate summary sentence number: 15
# Final summary sentence number: 7
# Document processing time: 02:13
# Total processing time: 01:01:55:10
# ----------------------------------
# Document: 150
# Document sentence number: 40
# Optimum cluster number: 10
# Intermediate summary sentence number: 10
# Final summary sentence number: 7
# Document processing time: 00:11
# Total processing time: 01:01:55:22
# ----------------------------------
# Document: 151
# Document sentence number: 28
# Optimum cluster number: 4
# Intermediate summary sentence number: 4
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:01:55:29
# ----------------------------------
# Document: 152
# Document sentence number: 0
# Document is shorter than 9 sentences, Summarization didnt apply
# Document processing time: 00:01
# Total processing time: 01:01:55:30
# ----------------------------------
# Document: 153
# Document sentence number: 141
# Optimum cluster number: 9
# Intermediate summary sentence number: 9
# Final summary sentence number: 7
# Document processing time: 01:11
# Total processing time: 01:01:56:41
# ----------------------------------
# Document: 154
# Document sentence number: 165
# Optimum cluster number: 39
# Intermediate summary sentence number: 39
# Final summary sentence number: 7
# Document processing time: 01:26
# Total processing time: 01:01:58:08
# ----------------------------------
# Document: 155
# Document sentence number: 177
# Optimum cluster number: 37
# Intermediate summary sentence number: 37
# Final summary sentence number: 7
# Document processing time: 01:34
# Total processing time: 01:01:59:43
# ----------------------------------
# Document: 156
# Document sentence number: 1
# Document is shorter than 9 sentences, Summarization didnt apply
# Document processing time: 00:01
# Total processing time: 01:01:59:44
# ----------------------------------
# Document: 157
# Document sentence number: 43
# Optimum cluster number: 7
# Intermediate summary sentence number: 7
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:10
# Total processing time: 01:01:59:54
# ----------------------------------
# Document: 158
# Document sentence number: 85
# Optimum cluster number: 8
# Intermediate summary sentence number: 8
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:26
# Total processing time: 01:02:00:21
# ----------------------------------
# Document: 159
# Document sentence number: 48
# Optimum cluster number: 10
# Intermediate summary sentence number: 10
# Final summary sentence number: 7
# Document processing time: 00:13
# Total processing time: 01:02:00:34
# ----------------------------------
# Document: 160
# Document sentence number: 168
# Optimum cluster number: 11
# Intermediate summary sentence number: 11
# Final summary sentence number: 7
# Document processing time: 01:27
# Total processing time: 01:02:02:01
# ----------------------------------
# Document: 161
# Document sentence number: 131
# Optimum cluster number: 28
# Intermediate summary sentence number: 28
# Final summary sentence number: 7
# Document processing time: 01:04
# Total processing time: 01:02:03:06
# ----------------------------------
# Document: 162
# Document sentence number: 232
# Optimum cluster number: 29
# Intermediate summary sentence number: 29
# Final summary sentence number: 7
# Document processing time: 02:10
# Total processing time: 01:02:05:17
# ----------------------------------
# Document: 163
# Document sentence number: 115
# Optimum cluster number: 13
# Intermediate summary sentence number: 13
# Final summary sentence number: 7
# Document processing time: 00:56
# Total processing time: 01:02:06:13
# ----------------------------------
# Document: 164
# Document sentence number: 63
# Optimum cluster number: 14
# Intermediate summary sentence number: 14
# Final summary sentence number: 7
# Document processing time: 00:16
# Total processing time: 01:02:06:29
# ----------------------------------
# Document: 165
# Document sentence number: 74
# Optimum cluster number: 17
# Intermediate summary sentence number: 17
# Final summary sentence number: 7
# Document processing time: 00:19
# Total processing time: 01:02:06:49
# ----------------------------------
# Document: 166
# Document sentence number: 189
# Optimum cluster number: 43
# Intermediate summary sentence number: 43
# Final summary sentence number: 7
# Document processing time: 01:42
# Total processing time: 01:02:08:31
# ----------------------------------
# Document: 167
# Document sentence number: 204
# Optimum cluster number: 38
# Intermediate summary sentence number: 38
# Final summary sentence number: 7
# Document processing time: 01:49
# Total processing time: 01:02:10:20
# ----------------------------------
# Document: 168
# Document sentence number: 62
# Optimum cluster number: 14
# Intermediate summary sentence number: 14
# Final summary sentence number: 7
# Document processing time: 00:15
# Total processing time: 01:02:10:36
# ----------------------------------
# Document: 169
# Document sentence number: 86
# Optimum cluster number: 11
# Intermediate summary sentence number: 11
# Final summary sentence number: 7
# Document processing time: 00:35
# Total processing time: 01:02:11:12
# ----------------------------------
# Document: 170
# Document sentence number: 43
# Optimum cluster number: 11
# Intermediate summary sentence number: 11
# Final summary sentence number: 7
# Document processing time: 00:11
# Total processing time: 01:02:11:23
# ----------------------------------
# Document: 171
# Document sentence number: 76
# Optimum cluster number: 7
# Intermediate summary sentence number: 7
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:19
# Total processing time: 01:02:11:42
# ----------------------------------
# Document: 172
# Document sentence number: 304
# Optimum cluster number: 32
# Intermediate summary sentence number: 32
# Final summary sentence number: 7
# Document processing time: 03:01
# Total processing time: 01:02:14:44
# ----------------------------------
# Document: 173
# Document sentence number: 51
# Optimum cluster number: 11
# Intermediate summary sentence number: 11
# Final summary sentence number: 7
# Document processing time: 00:13
# Total processing time: 01:02:14:57
# ----------------------------------
# Document: 174
# Document sentence number: 135
# Optimum cluster number: 22
# Intermediate summary sentence number: 22
# Final summary sentence number: 7
# Document processing time: 01:08
# Total processing time: 01:02:16:06
# ----------------------------------
# Document: 175
# Document sentence number: 42
# Optimum cluster number: 7
# Intermediate summary sentence number: 7
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:10
# Total processing time: 01:02:16:17
# ----------------------------------
# Document: 176
# Document sentence number: 0
# Document is shorter than 9 sentences, Summarization didnt apply
# Document processing time: 00:01
# Total processing time: 01:02:16:18
# ----------------------------------
# Document: 177
# Document sentence number: 108
# Optimum cluster number: 19
# Intermediate summary sentence number: 19
# Final summary sentence number: 7
# Document processing time: 00:51
# Total processing time: 01:02:17:09
# ----------------------------------
# Document: 178
# Document sentence number: 200
# Optimum cluster number: 20
# Intermediate summary sentence number: 20
# Final summary sentence number: 7
# Document processing time: 01:49
# Total processing time: 01:02:18:59
# ----------------------------------
# Document: 179
# Document sentence number: 182
# Optimum cluster number: 7
# Intermediate summary sentence number: 7
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 01:33
# Total processing time: 01:02:20:33
# ----------------------------------
# Document: 180
# Document sentence number: 106
# Optimum cluster number: 19
# Intermediate summary sentence number: 19
# Final summary sentence number: 7
# Document processing time: 00:49
# Total processing time: 01:02:21:23
# ----------------------------------
# Document: 181
# Document sentence number: 305
# Optimum cluster number: 23
# Intermediate summary sentence number: 23
# Final summary sentence number: 7
# Document processing time: 03:05
# Total processing time: 01:02:24:28
# ----------------------------------
# Document: 182
# Document sentence number: 56
# Optimum cluster number: 15
# Intermediate summary sentence number: 15
# Final summary sentence number: 7
# Document processing time: 00:14
# Total processing time: 01:02:24:42
# ----------------------------------
# Document: 183
# Document sentence number: 244
# Optimum cluster number: 28
# Intermediate summary sentence number: 28
# Final summary sentence number: 7
# Document processing time: 02:21
# Total processing time: 01:02:27:03
# ----------------------------------
# Document: 184
# Document sentence number: 229
# Optimum cluster number: 16
# Intermediate summary sentence number: 16
# Final summary sentence number: 7
# Document processing time: 02:07
# Total processing time: 01:02:29:11
# ----------------------------------
# Document: 185
# Document sentence number: 327
# Optimum cluster number: 41
# Intermediate summary sentence number: 41
# Final summary sentence number: 7
# Document processing time: 03:30
# Total processing time: 01:02:32:42
# ----------------------------------
# Document: 186
# Document sentence number: 94
# Optimum cluster number: 15
# Intermediate summary sentence number: 15
# Final summary sentence number: 7
# Document processing time: 00:41
# Total processing time: 01:02:33:23
# ----------------------------------
# Document: 187
# Document sentence number: 50
# Optimum cluster number: 5
# Intermediate summary sentence number: 5
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:11
# Total processing time: 01:02:33:35
# ----------------------------------
# Document: 188
# ...
# Final summary sentence number: 7
# Document processing time: 01:17
# Total processing time: 01:05:38:59
# ----------------------------------
# Document: 439
# Document sentence number: 233
# Optimum cluster number: 17
# Intermediate summary sentence number: 17
# Final summary sentence number: 7
# Document processing time: 02:12
# Total processing time: 01:05:41:11
# ----------------------------------
# Document: 440
# Document sentence number: 54
# Optimum cluster number: 12
# Intermediate summary sentence number: 12
# Final summary sentence number: 7
# Document processing time: 00:14
# Total processing time: 01:05:41:26
# ----------------------------------
# Document: 441
# Document sentence number: 97
# Optimum cluster number: 13
# Intermediate summary sentence number: 13
# Final summary sentence number: 7
# Document processing time: 00:43
# Total processing time: 01:05:42:09
# ----------------------------------
# Document: 442
# Document sentence number: 30
# Optimum cluster number: 5
# Intermediate summary sentence number: 5
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:08
# Total processing time: 01:05:42:18
# ----------------------------------
# Document: 443
# Document sentence number: 92
# Optimum cluster number: 17
# Intermediate summary sentence number: 17
# Final summary sentence number: 7
# Document processing time: 00:40
# Total processing time: 01:05:42:58
# ----------------------------------
# Document: 444
# Document sentence number: 0
# Document is shorter than 9 sentences, Summarization didnt apply
# Document processing time: 00:01
# Total processing time: 01:05:43:00
# ----------------------------------
# Document: 445
# Document sentence number: 236
# Optimum cluster number: 20
# Intermediate summary sentence number: 20
# Final summary sentence number: 7
# Document processing time: 02:15
# Total processing time: 01:05:45:15
# ----------------------------------
# Document: 446
# Document sentence number: 132
# Optimum cluster number: 11
# Intermediate summary sentence number: 11
# Final summary sentence number: 7
# Document processing time: 01:06
# Total processing time: 01:05:46:21
# ----------------------------------
# Document: 447
# Document sentence number: 49
# Optimum cluster number: 11
# Intermediate summary sentence number: 11
# Final summary sentence number: 7
# Document processing time: 00:13
# Total processing time: 01:05:46:35
# ----------------------------------
# Document: 448
# Document sentence number: 54
# Optimum cluster number: 8
# Intermediate summary sentence number: 8
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:12
# Total processing time: 01:05:46:48
# ----------------------------------
# Document: 449
# Document sentence number: 176
# Optimum cluster number: 31
# Intermediate summary sentence number: 31
# Final summary sentence number: 7
# Document processing time: 01:32
# Total processing time: 01:05:48:21
# ----------------------------------
# Document: 450
# Document sentence number: 48
# Optimum cluster number: 10
# Intermediate summary sentence number: 10
# Final summary sentence number: 7
# Document processing time: 00:12
# Total processing time: 01:05:48:33
# ----------------------------------
# Document: 451
# Document sentence number: 122
# Optimum cluster number: 14
# Intermediate summary sentence number: 14
# Final summary sentence number: 7
# Document processing time: 00:59
# Total processing time: 01:05:49:32
# ----------------------------------
# Document: 452
# Document sentence number: 64
# Optimum cluster number: 8
# Intermediate summary sentence number: 8
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:15
# Total processing time: 01:05:49:48
# ----------------------------------
# Document: 453
# Document sentence number: 115
# Optimum cluster number: 10
# Intermediate summary sentence number: 10
# Final summary sentence number: 7
# Document processing time: 00:57
# Total processing time: 01:05:50:46
# ----------------------------------
# Document: 454
# Document sentence number: 39
# Optimum cluster number: 12
# Intermediate summary sentence number: 12
# Final summary sentence number: 7
# Document processing time: 00:11
# Total processing time: 01:05:50:57
# ----------------------------------
# Document: 455
# Document sentence number: 137
# Optimum cluster number: 10
# Intermediate summary sentence number: 10
# Final summary sentence number: 7
# Document processing time: 01:11
# Total processing time: 01:05:52:09
# ----------------------------------
# Document: 456
# Document sentence number: 73
# Optimum cluster number: 7
# Intermediate summary sentence number: 7
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:23
# Total processing time: 01:05:52:32
# ----------------------------------
# Document: 457
# Document sentence number: 5
# Document is shorter than 9 sentences, Summarization didnt apply
# Document processing time: 00:01
# Total processing time: 01:05:52:34
# ----------------------------------
# Document: 458
# Document sentence number: 128
# Optimum cluster number: 14
# Intermediate summary sentence number: 14
# Final summary sentence number: 7
# Document processing time: 01:04
# Total processing time: 01:05:53:38
# ----------------------------------
# Document: 459
# Document sentence number: 141
# Optimum cluster number: 12
# Intermediate summary sentence number: 12
# Final summary sentence number: 7
# Document processing time: 01:12
# Total processing time: 01:05:54:51
# ----------------------------------
# Document: 460
# Document sentence number: 98
# Optimum cluster number: 13
# Intermediate summary sentence number: 13
# Final summary sentence number: 7
# Document processing time: 00:42
# Total processing time: 01:05:55:34
# ----------------------------------
# Document: 461
# Document sentence number: 207
# Optimum cluster number: 22
# Intermediate summary sentence number: 22
# Final summary sentence number: 7
# Document processing time: 01:53
# Total processing time: 01:05:57:27
# ----------------------------------
# Document: 462
# Document sentence number: 254
# Optimum cluster number: 63
# Intermediate summary sentence number: 63
# Final summary sentence number: 7
# Document processing time: 02:32
# Total processing time: 01:06:00:00
# ----------------------------------
# Document: 463
# Document sentence number: 211
# Optimum cluster number: 22
# Intermediate summary sentence number: 22
# Final summary sentence number: 7
# Document processing time: 01:55
# Total processing time: 01:06:01:55
# ----------------------------------
# Document: 464
# Document sentence number: 167
# Optimum cluster number: 16
# Intermediate summary sentence number: 16
# Final summary sentence number: 7
# Document processing time: 01:28
# Total processing time: 01:06:03:24
# ----------------------------------
# Document: 465
# Document sentence number: 99
# Optimum cluster number: 13
# Intermediate summary sentence number: 13
# Final summary sentence number: 7
# Document processing time: 00:44
# Total processing time: 01:06:04:08
# ----------------------------------
# Document: 466
# Document sentence number: 280
# Optimum cluster number: 89
# Intermediate summary sentence number: 89
# Final summary sentence number: 7
# Document processing time: 02:52
# Total processing time: 01:06:07:01
# ----------------------------------
# Document: 467
# Document sentence number: 179
# Optimum cluster number: 12
# Intermediate summary sentence number: 12
# Final summary sentence number: 7
# Document processing time: 01:31
# Total processing time: 01:06:08:32
# ----------------------------------
# Document: 468
# Document sentence number: 187
# Optimum cluster number: 5
# Intermediate summary sentence number: 5
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 01:38
# Total processing time: 01:06:10:11
# ----------------------------------
# Document: 469
# Document sentence number: 23
# Optimum cluster number: 6
# Intermediate summary sentence number: 6
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:06
# Total processing time: 01:06:10:18
# ----------------------------------
# Document: 470
# Document sentence number: 59
# Optimum cluster number: 14
# Intermediate summary sentence number: 14
# Final summary sentence number: 7
# Document processing time: 00:14
# Total processing time: 01:06:10:33
# ----------------------------------
# Document: 471
# Document sentence number: 70
# Optimum cluster number: 19
# Intermediate summary sentence number: 19
# Final summary sentence number: 7
# Document processing time: 00:18
# Total processing time: 01:06:10:51
# ----------------------------------
# Document: 472
# Document sentence number: 42
# Optimum cluster number: 11
# Intermediate summary sentence number: 11
# Final summary sentence number: 7
# Document processing time: 00:11
# Total processing time: 01:06:11:03
# ----------------------------------
# Document: 473
# Document sentence number: 112
# Optimum cluster number: 32
# Intermediate summary sentence number: 32
# Final summary sentence number: 7
# Document processing time: 00:52
# Total processing time: 01:06:11:55
# ----------------------------------
# Document: 474
# Document sentence number: 78
# Optimum cluster number: 16
# Intermediate summary sentence number: 16
# Final summary sentence number: 7
# Document processing time: 00:22
# Total processing time: 01:06:12:17
# ----------------------------------
# Document: 475
# Document sentence number: 54
# Optimum cluster number: 5
# Intermediate summary sentence number: 5
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:14
# Total processing time: 01:06:12:32
# ----------------------------------
# Document: 476
# Document sentence number: 30
# Optimum cluster number: 7
# Intermediate summary sentence number: 7
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:06:12:40
# ----------------------------------
# Document: 477
# Document sentence number: 129
# Optimum cluster number: 11
# Intermediate summary sentence number: 11
# Final summary sentence number: 7
# Document processing time: 01:05
# Total processing time: 01:06:13:45
# ----------------------------------
# Document: 478
# Document sentence number: 253
# Optimum cluster number: 46
# Intermediate summary sentence number: 46
# Final summary sentence number: 7
# Document processing time: 02:28
# Total processing time: 01:06:16:14
# ----------------------------------
# Document: 479
# Document sentence number: 100
# Optimum cluster number: 8
# Intermediate summary sentence number: 8
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:43
# Total processing time: 01:06:16:57
# ----------------------------------
# Document: 480
# Document sentence number: 0
# Document is shorter than 9 sentences, Summarization didnt apply
# Document processing time: 00:01
# Total processing time: 01:06:16:58
# ----------------------------------
# Document: 481
# Document sentence number: 0
# Document is shorter than 9 sentences, Summarization didnt apply
# Document processing time: 00:01
# Total processing time: 01:06:16:59
# ----------------------------------
# Document: 482
# Document sentence number: 47
# Optimum cluster number: 9
# Intermediate summary sentence number: 9
# Final summary sentence number: 7
# Document processing time: 00:12
# Total processing time: 01:06:17:12
# ----------------------------------
# Document: 483
# Document sentence number: 29
# Optimum cluster number: 7
# Intermediate summary sentence number: 7
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:06:17:19
# ----------------------------------
# Document: 484
# Document sentence number: 158
# Optimum cluster number: 24
# Intermediate summary sentence number: 24
# Final summary sentence number: 7
# Document processing time: 01:21
# Total processing time: 01:06:18:40
# ----------------------------------
# Document: 485
# Document sentence number: 41
# Optimum cluster number: 7
# Intermediate summary sentence number: 7
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:09
# Total processing time: 01:06:18:50
# ----------------------------------
# Document: 486
# Document sentence number: 122
# Optimum cluster number: 24
# Intermediate summary sentence number: 24
# Final summary sentence number: 7
# Document processing time: 01:00
# Total processing time: 01:06:19:50
# ----------------------------------
# Document: 487
# Document sentence number: 81
# Optimum cluster number: 17
# Intermediate summary sentence number: 17
# Final summary sentence number: 7
# Document processing time: 00:27
# Total processing time: 01:06:20:18
# ----------------------------------
# Document: 488
# Document sentence number: 44
# Optimum cluster number: 10
# Intermediate summary sentence number: 10
# Final summary sentence number: 7
# Document processing time: 00:12
# Total processing time: 01:06:20:30
# ----------------------------------
# Document: 489
# Document sentence number: 58
# Optimum cluster number: 6
# Intermediate summary sentence number: 6
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:13
# Total processing time: 01:06:20:44
# ----------------------------------
# Document: 490
# Document sentence number: 30
# Optimum cluster number: 6
# Intermediate summary sentence number: 6
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:08
# Total processing time: 01:06:20:52
# ----------------------------------
# Document: 491
# Document sentence number: 60
# Optimum cluster number: 17
# Intermediate summary sentence number: 17
# Final summary sentence number: 7
# Document processing time: 00:15
# Total processing time: 01:06:21:08
# ----------------------------------
# Document: 492
# Document sentence number: 69
# Optimum cluster number: 6
# Intermediate summary sentence number: 6
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:17
# Total processing time: 01:06:21:25
# ----------------------------------
# Document: 493
# Document sentence number: 41
# Optimum cluster number: 6
# Intermediate summary sentence number: 6
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:09
# Total processing time: 01:06:21:35
# ----------------------------------
# Document: 494
# Document sentence number: 32
# Optimum cluster number: 5
# Intermediate summary sentence number: 5
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:08
# Total processing time: 01:06:21:43
# ----------------------------------
# Document: 495
# Document sentence number: 187
# Optimum cluster number: 17
# Intermediate summary sentence number: 17
# Final summary sentence number: 7
# Document processing time: 01:42
# Total processing time: 01:06:23:26
# ----------------------------------
# Document: 496
# Document sentence number: 69
# Optimum cluster number: 12
# Intermediate summary sentence number: 12
# Final summary sentence number: 7
# Document processing time: 00:19
# Total processing time: 01:06:23:46
# ----------------------------------
# Document: 497
# Document sentence number: 52
# Optimum cluster number: 7
# Intermediate summary sentence number: 7
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:13
# Total processing time: 01:06:23:59
# ----------------------------------
# Document: 498
# Document sentence number: 101
# Optimum cluster number: 12
# Intermediate summary sentence number: 12
# Final summary sentence number: 7
# Document processing time: 00:44
# Total processing time: 01:06:24:43
# ----------------------------------
# Document: 499
# Document sentence number: 185
# Optimum cluster number: 32
# Intermediate summary sentence number: 32
# Final summary sentence number: 7
# Document processing time: 01:39
# Total processing time: 01:06:26:22
# ----------------------------------
# Document: 500
# Document sentence number: 107
# Optimum cluster number: 10
# Intermediate summary sentence number: 10
# Final summary sentence number: 7
# Document processing time: 00:47
# Total processing time: 01:06:27:10
# ----------------------------------

# %%
def prepare_results(m, p, r, f):
    return '\t{}:\t{}: {:5.2f}\t{}: {:5.2f}\t{}: {:5.2f}'.format(m, 'P', 100.0 * p, 'R', 100.0 * r, 'F1', 100.0 * f)

def rougeEvaluation(all_hypothesis, all_references):

    for aggregator in ['Avg']:
        print('Evaluation with {}'.format(aggregator))
        apply_avg = aggregator == 'Avg'
        apply_best = aggregator == 'Best'

        evaluator = rouge.Rouge(metrics=['rouge-n', 'rouge-l', 'rouge-w'],
                               max_n=4,
                               limit_length=False,
                               length_limit=1000,
                               length_limit_type='words',
                               apply_avg=apply_avg,
                               apply_best=apply_best,
                               alpha=0.2, # Default F1_score
                               weight_factor=1.2,
                               stemming=True)

        scores = evaluator.get_scores(all_hypothesis, all_references)

        for metric, results in sorted(scores.items(), key=lambda x: x[0]):
            if not apply_avg and not apply_best: # value is a type of list as we evaluate each summary vs each reference
                for hypothesis_id, results_per_ref in enumerate(results):
                    nb_references = len(results_per_ref['p'])
                    for reference_id in range(nb_references):
                        print('\tHypothesis #{} & Reference #{}: '.format(hypothesis_id, reference_id))
                        print('\t' + prepare_results(metric,results_per_ref['p'][reference_id], results_per_ref['r'][reference_id], results_per_ref['f'][reference_id]))
                print()
            else:
                print(prepare_results(metric, results['p'], results['r'], results['f']))
        print()

# %%
rougeEvaluation(all_intermediate_summary, all_goldstandart)
# Out:
# Evaluation with Avg
# 	rouge-1:	P: 30.26	R: 49.78	F1: 40.49
# 	rouge-2:	P:  9.29	R: 14.82	F1: 12.04
# 	rouge-3:	P:  4.55	R:  6.35	F1:  5.34
# 	rouge-4:	P:  3.02	R:  3.71	F1:  3.22
# 	rouge-l:	P: 28.84	R: 43.33	F1: 37.05
# 	rouge-w:	P: 13.56	R: 11.13	F1: 10.74

# %%
rougeEvaluation(all_summary, all_goldstandart)
# Out:
# Evaluation with Avg
# 	rouge-1:	P: 38.11	R: 39.57	F1: 37.72
# 	rouge-2:	P: 11.25	R: 11.06	F1: 10.65
# 	rouge-3:	P:  5.36	R:  4.89	F1:  4.78
# 	rouge-4:	P:  3.46	R:  2.96	F1:  2.93
# 	rouge-l:	P: 35.61	R: 36.45	F1: 35.28
# 	rouge-w:	P: 17.36	R:  9.21	F1:  9.85

# %%
# Play an audio beep. Any audio URL will do.
from google.colab import output
output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')

# %%
# Save files

import json
import os

# Define the file path
file_path = "/content/savedDocumentsandSummaries.json"  # Replace with the desired file path

# Check if the file already exists
if os.path.exists(file_path):
    # Read the existing data from the JSON file
    with open(file_path, "r") as file:
        existing_data = json.load(file)

    # Combine the existing data with the new data (lists)
    existing_intermediate_summary = existing_data.get("all_intermediate_summary", [])
    existing_summary = existing_data.get("all_summary", [])
    existing_goldstandart = existing_data.get("all_goldstandart", [])

    # Assuming you have three new lists: new_intermediate_summary, new_summary, new_goldstandart
    # Sample new lists (replace these with your actual lists)
    new_intermediate_summary = all_intermediate_summary
    new_summary = all_summary
    new_goldstandart = all_goldstandart


    # Merge the new lists with the existing ones
    all_intermediate_summary = existing_intermediate_summary + new_intermediate_summary
    all_summary = existing_summary + new_summary
    all_goldstandart = existing_goldstandart + new_goldstandart

# Combine the lists into a dictionary for easy serialization
data = {
    "all_intermediate_summary": all_intermediate_summary,
    "all_summary": all_summary,
    "all_goldstandart": all_goldstandart
}

# Save the data to a JSON file
with open(file_path, "w") as file:
    json.dump(data, file)

print("Lists have been saved to", file_path)
# Out:
# Lists have been saved to /content/savedDocumentsandSummaries.json

# %%
print(len(data['all_summary']))
# Out:
# 500

# %%
rougeEvaluation(data['all_intermediate_summary'], data['all_goldstandart'])
# Out:
# Evaluation with Avg
# 	rouge-1:	P: 30.26	R: 49.78	F1: 40.49
# 	rouge-2:	P:  9.29	R: 14.82	F1: 12.04
# 	rouge-3:	P:  4.55	R:  6.35	F1:  5.34
# 	rouge-4:	P:  3.02	R:  3.71	F1:  3.22
# 	rouge-l:	P: 28.84	R: 43.33	F1: 37.05
# 	rouge-w:	P: 13.56	R: 11.13	F1: 10.74

# %%
rougeEvaluation(data['all_summary'], data['all_goldstandart'])
# Out:
# Evaluation with Avg
# 	rouge-1:	P: 38.11	R: 39.57	F1: 37.72
# 	rouge-2:	P: 11.25	R: 11.06	F1: 10.65
# 	rouge-3:	P:  5.36	R:  4.89	F1:  4.78
# 	rouge-4:	P:  3.46	R:  2.96	F1:  2.93
# 	rouge-l:	P: 35.61	R: 36.45	F1: 35.28
# 	rouge-w:	P: 17.36	R:  9.21	F1:  9.85

# %%
# Play an audio beep. Any audio URL will do.
from google.colab import output
output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')
