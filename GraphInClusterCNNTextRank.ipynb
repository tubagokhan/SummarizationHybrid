# %% [markdown]
# <a href="https://colab.research.google.com/github/tubagokhan/SummarizationHybrid/blob/main/GraphInClusterCNNTextRank.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# !pip install datasets
# !pip install torch
# !pip install scikit-learn
# !pip install matplotlib
# !pip install sentence_transformers
# !pip install py-rouge==1.1
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.31.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.16.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.3.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.13.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.1)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.27.1)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.65.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.2.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.8.4)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.16.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (3.12.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (4.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.0.1+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (16.0.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.25.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.41.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.25.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: sentence_transformers in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.15.2+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.25.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.11.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.16.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (3.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2.27.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (4.7.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (23.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence_transformers) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence_transformers) (16.0.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2022.10.31)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.3.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence_transformers) (8.1.6)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence_transformers) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (3.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence_transformers) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence_transformers) (2.1.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence_transformers) (1.3.0)
# Requirement already satisfied: py-rouge==1.1 in /usr/local/lib/python3.10/dist-packages (1.1)

# %%
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sentence_transformers import SentenceTransformer
from nltk import sent_tokenize,word_tokenize

from sklearn.metrics.pairwise import cosine_similarity
import networkx as nx

import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

import warnings
warnings.filterwarnings("ignore")
import re

from datasets import load_dataset
from scipy.spatial import distance

import math
from math import*

import rouge

import networkx as nx

import time
from transformers import logging
logging.set_verbosity_error()

import json
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# Preprocessing method
def preprocess_corpus(text):
    # Remove special characters and extra whitespaces
    text = re.sub(r"[^a-zA-Z0-9\s.]", "", text)
    text = re.sub(r"\s+", " ", text)
    return text

def textSentenceCount(Text):
    number_of_sentences = sent_tokenize(Text)
    count=(len(number_of_sentences))
    return count

def cosine(u, v):
    return np.dot(u, v) / (np.linalg.norm(u) * np.linalg.norm(v))

def createSummaryUsingKMeans(corpus, modelName):
    sentences = sent_tokenize(corpus)
    model = SentenceTransformer(modelName)
    sentence_embeddings = model.encode(sentences)

    optimum_clusters = find_optimum_clusters(sentence_embeddings, int(len(sentences) / 3))
    print("Optimum cluster number:", optimum_clusters)

    # Perform kmean clustering
    kmeans = KMeans(n_clusters=optimum_clusters, random_state=0, n_init='auto').fit(sentence_embeddings)

    chosen_sentence_indexes=[]
    cluster_rank=[]
    for cluster_id in range(optimum_clusters):
        cluster_indices = np.where(kmeans.labels_ == cluster_id)[0]
        cluster_weight=clusterWeight(sentence_embeddings, cluster_indices)
        cluster_rank.append(cluster_weight)
        chosen_sentence_index=text_rank(sentence_embeddings, cluster_indices)
        chosen_sentence_indexes.append(chosen_sentence_index)

    if optimum_clusters>5:
      choosen_clusters=k_highest_indices(cluster_rank, 5)
      chosen_sentence_indexes = [chosen_sentence_indexes[i] for i in choosen_clusters]

    sorted_indexes=sorted(chosen_sentence_indexes)

    chosen_sentences = []
    for chosen_sentence_index in sorted_indexes:
        chosen_sentences.append(sentences[chosen_sentence_index])

    summary = " ".join(chosen_sentences)

    return summary

#function calculates the optimal number of clusters using the elbow method. The function plots the elbow curve, which shows the inertia values for different cluster numbers. The user can visually inspect the plot to determine the elbow point, indicating the optimal number of clusters.
def find_optimum_clusters(data, max_clusters):
    inertias = []
    for k in range(1, max_clusters + 1):
        kmeans = KMeans(n_clusters=k, random_state=0).fit(data)
        inertias.append(kmeans.inertia_)

    # Plotting the elbow curve
    #plt.plot(range(1, max_clusters + 1), inertias)
    #plt.xlabel("Number of Clusters")
    #plt.ylabel("Inertia")
    #plt.title("Elbow Curve")
    #plt.show()

    # Calculate the optimal number of clusters using the elbow method
    diff = np.diff(inertias)
    acceleration = np.diff(diff)
    opt_cluster_num = acceleration.argmin() + 2  # Adding 2 to get the index of the minimum acceleration
    return opt_cluster_num

def clusterWeight(sentence_embeddings, cluster_indices):
  length=len(cluster_indices)
  sentenceGraph =np.zeros((length, length))
  for x in range(length):
    for y in range(length):
      if x>y:
        similarity= cosine(sentence_embeddings[cluster_indices[x]],sentence_embeddings[cluster_indices[y]])
        sentenceGraph[x][y]=abs(similarity)
    #print(sentenceGraph)
  SumElement=(np.concatenate(sentenceGraph).sum())
  return round(SumElement,2)

def k_highest_indices(cluster_weight_list, k):
    # Enumerate the list to keep track of original indices
    enumerated_list = list(enumerate(cluster_weight_list))

    # Sort the enumerated list in descending order based on the float values
    sorted_list = sorted(enumerated_list, key=lambda x: x[1], reverse=True)

    # Extract the indices of the k highest elements
    k_highest_indices = [item[0] for item in sorted_list[:k]]

    return k_highest_indices

def text_rank(sentence_embeddings, indexes):
    # Filter embeddings based on the input indexes
    filtered_embeddings = np.array([sentence_embeddings[i] for i in indexes])

    # Calculate cosine similarity between filtered sentence embeddings
    similarity_matrix = cosine_similarity(filtered_embeddings, filtered_embeddings)

    # Create a graph using similarity matrix
    graph = nx.from_numpy_array(similarity_matrix)
    try:
      # Apply TextRank algorithm to rank the sentences
      scores = nx.pagerank(graph, max_iter=1000)
          # Get the index of the highest-ranked sentence
      highest_ranked_index = max(scores, key=scores.get)

      # Get the original index from the list of indexes
      highest_ranked_original_index = indexes[highest_ranked_index]
      return highest_ranked_original_index
    except:
      print("######### Error with PageRank")
      return indexes[0]

# %%
modelName = 'all-mpnet-base-v2'
dataset = load_dataset('cnn_dailymail', '3.0.0')

startTimeforOverall = time.time()
all_summary = []
all_goldstandart = []

N = 400
startN = 100

for d in range(N):
    startTimeforDocument = time.time()
    print("Document:", startN + d + 1)
    corpus = dataset['train']['article'][startN + d]
    corpus = preprocess_corpus(corpus)
    print("Document sentence number:", textSentenceCount(corpus))


    if textSentenceCount(corpus) > 8:
        summary = createSummaryUsingKMeans(corpus, modelName)
        print("Summary sentence number:", textSentenceCount(summary))
        all_summary.append(summary)
    else:
      all_summary.append(corpus)
      print("Corpus is less than 9 sentence, summarization didn't apply sentence number:", textSentenceCount(corpus))

    all_goldstandart.append(dataset['train']['highlights'][startN + d])
    elapsedTimeforDocument = time.time() - startTimeforDocument
    elapsedTimeforAll = time.time() - startTimeforOverall
    print('Document processing time: '+time.strftime("%M:%S", time.gmtime(elapsedTimeforDocument)))
    print('Total processing time: '+time.strftime("%d:%H:%M:%S", time.gmtime(elapsedTimeforAll)))

    print("----------------------------------")
# Out:
# WARNING:datasets.builder:Found cached dataset cnn_dailymail (/root/.cache/huggingface/datasets/cnn_dailymail/3.0.0/3.0.0/1b3c71476f6d152c31c1730e83ccb08bcf23e348233f4fcc11e182248e6bf7de)
#   0%|          | 0/3 [00:00<?, ?it/s]
# Document: 101
# Document sentence number: 33
# Optimum cluster number: 9
# Summary sentence number: 5
# Document processing time: 00:09
# Total processing time: 01:00:00:09
# ----------------------------------
# Document: 102
# Document sentence number: 29
# Optimum cluster number: 8
# Summary sentence number: 5
# Document processing time: 00:08
# Total processing time: 01:00:00:18
# ----------------------------------
# Document: 103
# Document sentence number: 26
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:07
# Total processing time: 01:00:00:25
# ----------------------------------
# Document: 104
# Document sentence number: 28
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:08
# Total processing time: 01:00:00:34
# ----------------------------------
# Document: 105
# Document sentence number: 34
# Optimum cluster number: 7
# ######### Error with PageRank
# Summary sentence number: 5
# Document processing time: 00:09
# Total processing time: 01:00:00:43
# ----------------------------------
# Document: 106
# Document sentence number: 12
# Optimum cluster number: 2
# Summary sentence number: 2
# Document processing time: 00:05
# Total processing time: 01:00:00:48
# ----------------------------------
# Document: 107
# Document sentence number: 26
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:07
# Total processing time: 01:00:00:56
# ----------------------------------
# Document: 108
# Document sentence number: 22
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:06
# Total processing time: 01:00:01:03
# ----------------------------------
# Document: 109
# Document sentence number: 26
# Optimum cluster number: 6
# Summary sentence number: 5
# Document processing time: 00:07
# Total processing time: 01:00:01:11
# ----------------------------------
# Document: 110
# Document sentence number: 31
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:08
# Total processing time: 01:00:01:19
# ----------------------------------
# Document: 111
# Document sentence number: 26
# Optimum cluster number: 7
# Summary sentence number: 5
# Document processing time: 00:07
# Total processing time: 01:00:01:27
# ----------------------------------
# Document: 112
# Document sentence number: 36
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:09
# Total processing time: 01:00:01:37
# ----------------------------------
# Document: 113
# Document sentence number: 52
# Optimum cluster number: 10
# Summary sentence number: 5
# Document processing time: 00:13
# Total processing time: 01:00:01:50
# ----------------------------------
# Document: 114
# Document sentence number: 18
# Optimum cluster number: 3
# Summary sentence number: 3
# Document processing time: 00:06
# Total processing time: 01:00:01:56
# ----------------------------------
# Document: 115
# Document sentence number: 28
# Optimum cluster number: 8
# Summary sentence number: 5
# Document processing time: 00:08
# Total processing time: 01:00:02:04
# ----------------------------------
# Document: 116
# Document sentence number: 23
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:07
# Total processing time: 01:00:02:11
# ----------------------------------
# Document: 117
# Document sentence number: 12
# Optimum cluster number: 2
# Summary sentence number: 2
# Document processing time: 00:05
# Total processing time: 01:00:02:17
# ----------------------------------
# Document: 118
# Document sentence number: 30
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:08
# Total processing time: 01:00:02:26
# ----------------------------------
# Document: 119
# Document sentence number: 28
# Optimum cluster number: 6
# Summary sentence number: 5
# Document processing time: 00:08
# Total processing time: 01:00:02:34
# ----------------------------------
# Document: 120
# Document sentence number: 18
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:06
# Total processing time: 01:00:02:40
# ----------------------------------
# Document: 121
# Document sentence number: 32
# Optimum cluster number: 9
# Summary sentence number: 5
# Document processing time: 00:08
# Total processing time: 01:00:02:49
# ----------------------------------
# Document: 122
# Document sentence number: 11
# Optimum cluster number: 2
# Summary sentence number: 2
# Document processing time: 00:03
# Total processing time: 01:00:02:52
# ----------------------------------
# Document: 123
# Document sentence number: 27
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:08
# Total processing time: 01:00:03:01
# ----------------------------------
# Document: 124
# Document sentence number: 28
# Optimum cluster number: 3
# Summary sentence number: 3
# Document processing time: 00:08
# Total processing time: 01:00:03:09
# ----------------------------------
# Document: 125
# Document sentence number: 41
# Optimum cluster number: 3
# Summary sentence number: 3
# Document processing time: 00:10
# Total processing time: 01:00:03:19
# ----------------------------------
# Document: 126
# Document sentence number: 57
# Optimum cluster number: 8
# Summary sentence number: 5
# Document processing time: 00:14
# Total processing time: 01:00:03:33
# ----------------------------------
# Document: 127
# Document sentence number: 39
# Optimum cluster number: 5
# ######### Error with PageRank
# Summary sentence number: 5
# Document processing time: 00:10
# Total processing time: 01:00:03:44
# ----------------------------------
# Document: 128
# Document sentence number: 19
# Optimum cluster number: 3
# ######### Error with PageRank
# Summary sentence number: 3
# Document processing time: 00:06
# Total processing time: 01:00:03:50
# ----------------------------------
# Document: 129
# Document sentence number: 44
# Optimum cluster number: 9
# Summary sentence number: 5
# Document processing time: 00:11
# Total processing time: 01:00:04:02
# ----------------------------------
# Document: 130
# Document sentence number: 6
# Corpus is less than 9 sentence, summarization didn't apply sentence number: 6
# Document processing time: 00:01
# Total processing time: 01:00:04:03
# ----------------------------------
# Document: 131
# Document sentence number: 55
# Optimum cluster number: 17
# Summary sentence number: 5
# Document processing time: 00:13
# Total processing time: 01:00:04:17
# ----------------------------------
# Document: 132
# Document sentence number: 73
# Optimum cluster number: 11
# Summary sentence number: 5
# Document processing time: 00:18
# Total processing time: 01:00:04:36
# ----------------------------------
# Document: 133
# Document sentence number: 77
# Optimum cluster number: 21
# Summary sentence number: 5
# Document processing time: 00:20
# Total processing time: 01:00:04:56
# ----------------------------------
# Document: 134
# Document sentence number: 40
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:10
# Total processing time: 01:00:05:07
# ----------------------------------
# Document: 135
# Document sentence number: 44
# Optimum cluster number: 12
# Summary sentence number: 5
# Document processing time: 00:11
# Total processing time: 01:00:05:18
# ----------------------------------
# Document: 136
# Document sentence number: 55
# Optimum cluster number: 8
# Summary sentence number: 5
# Document processing time: 00:13
# Total processing time: 01:00:05:31
# ----------------------------------
# Document: 137
# Document sentence number: 39
# Optimum cluster number: 12
# Summary sentence number: 5
# Document processing time: 00:10
# Total processing time: 01:00:05:41
# ----------------------------------
# Document: 138
# Document sentence number: 44
# Optimum cluster number: 8
# Summary sentence number: 5
# Document processing time: 00:10
# Total processing time: 01:00:05:52
# ----------------------------------
# Document: 139
# Document sentence number: 15
# Optimum cluster number: 3
# Summary sentence number: 3
# Document processing time: 00:05
# Total processing time: 01:00:05:58
# ----------------------------------
# Document: 140
# Document sentence number: 60
# Optimum cluster number: 11
# Summary sentence number: 5
# Document processing time: 00:14
# Total processing time: 01:00:06:13
# ----------------------------------
# Document: 141
# Document sentence number: 14
# Optimum cluster number: 2
# ######### Error with PageRank
# Summary sentence number: 2
# Document processing time: 00:05
# Total processing time: 01:00:06:18
# ----------------------------------
# Document: 142
# Document sentence number: 31
# Optimum cluster number: 8
# Summary sentence number: 5
# Document processing time: 00:08
# Total processing time: 01:00:06:27
# ----------------------------------
# Document: 143
# Document sentence number: 11
# Optimum cluster number: 2
# Summary sentence number: 2
# Document processing time: 00:03
# Total processing time: 01:00:06:30
# ----------------------------------
# Document: 144
# Document sentence number: 10
# Optimum cluster number: 2
# Summary sentence number: 2
# Document processing time: 00:03
# Total processing time: 01:00:06:33
# ----------------------------------
# Document: 145
# Document sentence number: 38
# Optimum cluster number: 8
# Summary sentence number: 5
# Document processing time: 00:09
# Total processing time: 01:00:06:43
# ----------------------------------
# Document: 146
# Document sentence number: 51
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:12
# Total processing time: 01:00:06:56
# ----------------------------------
# Document: 147
# Document sentence number: 19
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:06
# Total processing time: 01:00:07:02
# ----------------------------------
# Document: 148
# Document sentence number: 15
# Optimum cluster number: 3
# Summary sentence number: 3
# Document processing time: 00:05
# Total processing time: 01:00:07:08
# ----------------------------------
# Document: 149
# Document sentence number: 53
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:12
# Total processing time: 01:00:07:21
# ----------------------------------
# Document: 150
# Document sentence number: 56
# Optimum cluster number: 17
# Summary sentence number: 5
# Document processing time: 00:13
# Total processing time: 01:00:07:35
# ----------------------------------
# Document: 151
# Document sentence number: 13
# Optimum cluster number: 3
# Summary sentence number: 3
# Document processing time: 00:05
# Total processing time: 01:00:07:40
# ----------------------------------
# Document: 152
# Document sentence number: 34
# Optimum cluster number: 10
# Summary sentence number: 5
# Document processing time: 00:09
# Total processing time: 01:00:07:49
# ----------------------------------
# Document: 153
# Document sentence number: 21
# Optimum cluster number: 6
# Summary sentence number: 5
# Document processing time: 00:06
# Total processing time: 01:00:07:56
# ----------------------------------
# Document: 154
# Document sentence number: 30
# Optimum cluster number: 7
# Summary sentence number: 5
# Document processing time: 00:08
# Total processing time: 01:00:08:05
# ----------------------------------
# Document: 155
# Document sentence number: 43
# Optimum cluster number: 11
# Summary sentence number: 5
# Document processing time: 00:11
# Total processing time: 01:00:08:16
# ----------------------------------
# Document: 156
# Document sentence number: 19
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:06
# Total processing time: 01:00:08:23
# ----------------------------------
# Document: 157
# Document sentence number: 27
# Optimum cluster number: 6
# Summary sentence number: 5
# Document processing time: 00:08
# Total processing time: 01:00:08:31
# ----------------------------------
# Document: 158
# Document sentence number: 24
# Optimum cluster number: 3
# Summary sentence number: 3
# Document processing time: 00:07
# Total processing time: 01:00:08:39
# ----------------------------------
# Document: 159
# Document sentence number: 26
# Optimum cluster number: 7
# Summary sentence number: 5
# Document processing time: 00:07
# Total processing time: 01:00:08:46
# ----------------------------------
# Document: 160
# Document sentence number: 74
# Optimum cluster number: 16
# Summary sentence number: 5
# Document processing time: 00:18
# Total processing time: 01:00:09:05
# ----------------------------------
# Document: 161
# Document sentence number: 18
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:06
# Total processing time: 01:00:09:12
# ----------------------------------
# Document: 162
# Document sentence number: 37
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:09
# Total processing time: 01:00:09:21
# ----------------------------------
# Document: 163
# Document sentence number: 25
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:07
# Total processing time: 01:00:09:29
# ----------------------------------
# Document: 164
# Document sentence number: 48
# Optimum cluster number: 6
# Summary sentence number: 5
# Document processing time: 00:12
# Total processing time: 01:00:09:41
# ----------------------------------
# Document: 165
# Document sentence number: 27
# Optimum cluster number: 6
# Summary sentence number: 5
# Document processing time: 00:08
# Total processing time: 01:00:09:49
# ----------------------------------
# Document: 166
# Document sentence number: 43
# Optimum cluster number: 6
# Summary sentence number: 5
# Document processing time: 00:11
# Total processing time: 01:00:10:00
# ----------------------------------
# Document: 167
# Document sentence number: 36
# Optimum cluster number: 11
# Summary sentence number: 5
# Document processing time: 00:09
# Total processing time: 01:00:10:10
# ----------------------------------
# Document: 168
# Document sentence number: 37
# Optimum cluster number: 6
# Summary sentence number: 5
# Document processing time: 00:10
# Total processing time: 01:00:10:20
# ----------------------------------
# Document: 169
# Document sentence number: 9
# Optimum cluster number: 2
# Summary sentence number: 2
# Document processing time: 00:03
# Total processing time: 01:00:10:24
# ----------------------------------
# Document: 170
# Document sentence number: 47
# Optimum cluster number: 11
# Summary sentence number: 5
# Document processing time: 00:11
# Total processing time: 01:00:10:35
# ----------------------------------
# Document: 171
# Document sentence number: 15
# Optimum cluster number: 2
# ######### Error with PageRank
# Summary sentence number: 2
# Document processing time: 00:05
# Total processing time: 01:00:10:41
# ----------------------------------
# Document: 172
# Document sentence number: 47
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:11
# Total processing time: 01:00:10:53
# ----------------------------------
# Document: 173
# Document sentence number: 26
# Optimum cluster number: 6
# Summary sentence number: 5
# Document processing time: 00:07
# Total processing time: 01:00:11:01
# ----------------------------------
# Document: 174
# Document sentence number: 26
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:07
# Total processing time: 01:00:11:09
# ----------------------------------
# Document: 175
# Document sentence number: 17
# Optimum cluster number: 3
# Summary sentence number: 3
# Document processing time: 00:05
# Total processing time: 01:00:11:15
# ----------------------------------
# Document: 176
# Document sentence number: 18
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:06
# Total processing time: 01:00:11:21
# ----------------------------------
# Document: 177
# Document sentence number: 20
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:06
# Total processing time: 01:00:11:27
# ----------------------------------
# Document: 178
# Document sentence number: 38
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:10
# Total processing time: 01:00:11:37
# ----------------------------------
# Document: 179
# Document sentence number: 18
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:06
# Total processing time: 01:00:11:44
# ----------------------------------
# Document: 180
# Document sentence number: 45
# Optimum cluster number: 14
# Summary sentence number: 5
# Document processing time: 00:11
# Total processing time: 01:00:11:56
# ----------------------------------
# Document: 181
# Document sentence number: 35
# Optimum cluster number: 10
# Summary sentence number: 5
# Document processing time: 00:09
# Total processing time: 01:00:12:05
# ----------------------------------
# Document: 182
# Document sentence number: 37
# Optimum cluster number: 10
# Summary sentence number: 5
# Document processing time: 00:10
# Total processing time: 01:00:12:15
# ----------------------------------
# Document: 183
# Document sentence number: 14
# Optimum cluster number: 3
# Summary sentence number: 3
# Document processing time: 00:05
# Total processing time: 01:00:12:20
# ----------------------------------
# Document: 184
# Document sentence number: 10
# Optimum cluster number: 2
# Summary sentence number: 2
# Document processing time: 00:04
# Total processing time: 01:00:12:24
# ----------------------------------
# Document: 185
# Document sentence number: 39
# Optimum cluster number: 10
# Summary sentence number: 5
# Document processing time: 00:10
# Total processing time: 01:00:12:35
# ----------------------------------
# Document: 186
# Document sentence number: 15
# Optimum cluster number: 3
# Summary sentence number: 3
# Document processing time: 00:05
# Total processing time: 01:00:12:41
# ----------------------------------
# Document: 187
# Document sentence number: 24
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:07
# Total processing time: 01:00:12:48
# ----------------------------------
# Document: 188
# Document sentence number: 34
# Optimum cluster number: 9
# Summary sentence number: 5
# Document processing time: 00:09
# Total processing time: 01:00:12:58
# ----------------------------------
# Document: 189
# Document sentence number: 18
# Optimum cluster number: 3
# Summary sentence number: 3
# Document processing time: 00:06
# Total processing time: 01:00:13:04
# ----------------------------------
# Document: 190
# Document sentence number: 28
# Optimum cluster number: 7
# Summary sentence number: 5
# Document processing time: 00:08
# Total processing time: 01:00:13:12
# ----------------------------------
# Document: 191
# Document sentence number: 39
# Optimum cluster number: 9
# Summary sentence number: 5
# Document processing time: 00:10
# Total processing time: 01:00:13:22
# ----------------------------------
# Document: 192
# Document sentence number: 55
# Optimum cluster number: 9
# Summary sentence number: 5
# Document processing time: 00:13
# Total processing time: 01:00:13:36
# ----------------------------------
# Document: 193
# Document sentence number: 8
# Corpus is less than 9 sentence, summarization didn't apply sentence number: 8
# Document processing time: 00:01
# Total processing time: 01:00:13:38
# ----------------------------------
# Document: 194
# Document sentence number: 23
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:08
# Total processing time: 01:00:13:46
# ----------------------------------
# Document: 195
# Document sentence number: 39
# Optimum cluster number: 12
# Summary sentence number: 5
# Document processing time: 00:10
# Total processing time: 01:00:13:56
# ----------------------------------
# Document: 196
# Document sentence number: 19
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:06
# Total processing time: 01:00:14:02
# ----------------------------------
# Document: 197
# Document sentence number: 11
# Optimum cluster number: 2
# Summary sentence number: 2
# Document processing time: 00:03
# Total processing time: 01:00:14:05
# ----------------------------------
# Document: 198
# Document sentence number: 32
# Optimum cluster number: 6
# Summary sentence number: 5
# Document processing time: 00:08
# Total processing time: 01:00:14:14
# ----------------------------------
# Document: 199
# Document sentence number: 31
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:08
# Total processing time: 01:00:14:22
# ----------------------------------
# Document: 200
# Document sentence number: 77
# Optimum cluster number: 11
# Summary sentence number: 5
# Document processing time: 00:19
# Total processing time: 01:00:14:42
# ----------------------------------
# Document: 201
# Document sentence number: 19
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:06
# Total processing time: 01:00:14:49
# ----------------------------------
# Document: 202
# Document sentence number: 11
# Optimum cluster number: 2
# Summary sentence number: 2
# Document processing time: 00:03
# Total processing time: 01:00:14:52
# ----------------------------------
# Document: 203
# Document sentence number: 10
# Optimum cluster number: 2
# Summary sentence number: 2
# Document processing time: 00:03
# Total processing time: 01:00:14:55
# ----------------------------------
# Document: 204
# Document sentence number: 34
# Optimum cluster number: 3
# Summary sentence number: 3
# Document processing time: 00:09
# Total processing time: 01:00:15:04
# ----------------------------------
# Document: 205
# Document sentence number: 14
# Optimum cluster number: 3
# Summary sentence number: 3
# Document processing time: 00:05
# Total processing time: 01:00:15:09
# ----------------------------------
# Document: 206
# Document sentence number: 27
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:08
# Total processing time: 01:00:15:17
# ----------------------------------
# Document: 207
# Document sentence number: 20
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:06
# Total processing time: 01:00:15:24
# ----------------------------------
# Document: 208
# Document sentence number: 11
# Optimum cluster number: 2
# Summary sentence number: 2
# Document processing time: 00:03
# Total processing time: 01:00:15:27
# ----------------------------------
# Document: 209
# Document sentence number: 39
# Optimum cluster number: 6
# Summary sentence number: 5
# Document processing time: 00:10
# Total processing time: 01:00:15:38
# ----------------------------------
# Document: 210
# Document sentence number: 28
# Optimum cluster number: 6
# Summary sentence number: 5
# Document processing time: 00:07
# Total processing time: 01:00:15:45
# ----------------------------------
# Document: 211
# Document sentence number: 50
# Optimum cluster number: 13
# Summary sentence number: 5
# Document processing time: 00:12
# Total processing time: 01:00:15:58
# ----------------------------------
# Document: 212
# Document sentence number: 43
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:10
# Total processing time: 01:00:16:09
# ----------------------------------
# Document: 213
# Document sentence number: 14
# Optimum cluster number: 3
# Summary sentence number: 3
# Document processing time: 00:05
# Total processing time: 01:00:16:14
# ----------------------------------
# Document: 214
# Document sentence number: 60
# Optimum cluster number: 14
# Summary sentence number: 5
# Document processing time: 00:14
# Total processing time: 01:00:16:29
# ----------------------------------
# Document: 215
# Document sentence number: 42
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:10
# Total processing time: 01:00:16:39
# ----------------------------------
# Document: 216
# Document sentence number: 45
# Optimum cluster number: 13
# Summary sentence number: 5
# Document processing time: 00:11
# Total processing time: 01:00:16:51
# ----------------------------------
# Document: 217
# Document sentence number: 38
# Optimum cluster number: 10
# Summary sentence number: 5
# Document processing time: 00:09
# Total processing time: 01:00:17:01
# ----------------------------------
# Document: 218
# Document sentence number: 15
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:05
# Total processing time: 01:00:17:07
# ----------------------------------
# Document: 219
# Document sentence number: 31
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:08
# Total processing time: 01:00:17:15
# ----------------------------------
# Document: 220
# Document sentence number: 25
# Optimum cluster number: 6
# Summary sentence number: 5
# Document processing time: 00:07
# Total processing time: 01:00:17:23
# ----------------------------------
# Document: 221
# Document sentence number: 28
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:08
# Total processing time: 01:00:17:31
# ----------------------------------
# Document: 222
# Document sentence number: 15
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:05
# Total processing time: 01:00:17:37
# ----------------------------------
# Document: 223
# Document sentence number: 26
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:07
# Total processing time: 01:00:17:44
# ----------------------------------
# Document: 224
# Document sentence number: 61
# Optimum cluster number: 12
# Summary sentence number: 5
# Document processing time: 00:14
# Total processing time: 01:00:17:59
# ----------------------------------
# Document: 225
# Document sentence number: 27
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:08
# Total processing time: 01:00:18:07
# ----------------------------------
# Document: 226
# Document sentence number: 25
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:07
# Total processing time: 01:00:18:14
# ----------------------------------
# Document: 227
# Document sentence number: 39
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:10
# Total processing time: 01:00:18:25
# ----------------------------------
# Document: 228
# Document sentence number: 49
# Optimum cluster number: 15
# Summary sentence number: 5
# Document processing time: 00:12
# Total processing time: 01:00:18:37
# ----------------------------------
# Document: 229
# Document sentence number: 23
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:06
# Total processing time: 01:00:18:44
# ----------------------------------
# Document: 230
# Document sentence number: 34
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:09
# Total processing time: 01:00:18:53
# ----------------------------------
# Document: 231
# Document sentence number: 37
# Optimum cluster number: 8
# Summary sentence number: 5
# Document processing time: 00:09
# Total processing time: 01:00:19:03
# ----------------------------------
# Document: 232
# Document sentence number: 14
# Optimum cluster number: 2
# Summary sentence number: 2
# Document processing time: 00:05
# Total processing time: 01:00:19:08
# ----------------------------------
# Document: 233
# Document sentence number: 18
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:06
# Total processing time: 01:00:19:15
# ----------------------------------
# Document: 234
# Document sentence number: 21
# Optimum cluster number: 6
# Summary sentence number: 5
# Document processing time: 00:06
# Total processing time: 01:00:19:21
# ----------------------------------
# Document: 235
# Document sentence number: 21
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:06
# Total processing time: 01:00:19:28
# ----------------------------------
# Document: 236
# Document sentence number: 51
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:12
# Total processing time: 01:00:19:41
# ----------------------------------
# Document: 237
# Document sentence number: 32
# Optimum cluster number: 8
# Summary sentence number: 5
# Document processing time: 00:08
# Total processing time: 01:00:19:49
# ----------------------------------
# Document: 238
# Document sentence number: 24
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:07
# Total processing time: 01:00:19:57
# ----------------------------------
# Document: 239
# Document sentence number: 20
# Optimum cluster number: 3
# Summary sentence number: 3
# Document processing time: 00:06
# Total processing time: 01:00:20:03
# ----------------------------------
# Document: 240
# Document sentence number: 43
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:10
# Total processing time: 01:00:20:14
# ----------------------------------
# Document: 241
# Document sentence number: 25
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:07
# Total processing time: 01:00:20:22
# ----------------------------------
# Document: 242
# Document sentence number: 21
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:07
# Total processing time: 01:00:20:29
# ----------------------------------
# Document: 243
# Document sentence number: 10
# Optimum cluster number: 2
# Summary sentence number: 2
# Document processing time: 00:03
# Total processing time: 01:00:20:32
# ----------------------------------
# Document: 244
# Document sentence number: 23
# Optimum cluster number: 3
# Summary sentence number: 3
# Document processing time: 00:06
# Total processing time: 01:00:20:39
# ----------------------------------
# Document: 245
# Document sentence number: 23
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:07
# Total processing time: 01:00:20:46
# ----------------------------------
# Document: 246
# Document sentence number: 34
# Optimum cluster number: 10
# Summary sentence number: 5
# Document processing time: 00:09
# Total processing time: 01:00:20:55
# ----------------------------------
# Document: 247
# Document sentence number: 20
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:06
# Total processing time: 01:00:21:01
# ----------------------------------
# Document: 248
# Document sentence number: 24
# Optimum cluster number: 7
# Summary sentence number: 5
# Document processing time: 00:07
# Total processing time: 01:00:21:09
# ----------------------------------
# Document: 249
# Document sentence number: 13
# Optimum cluster number: 3
# Summary sentence number: 3
# Document processing time: 00:05
# Total processing time: 01:00:21:14
# ----------------------------------
# Document: 250
# Document sentence number: 20
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:06
# Total processing time: 01:00:21:20
# ----------------------------------
# Document: 251
# Document sentence number: 17
# Optimum cluster number: 3
# Summary sentence number: 3
# Document processing time: 00:05
# Total processing time: 01:00:21:26
# ----------------------------------
# Document: 252
# Document sentence number: 27
# Optimum cluster number: 3
# Summary sentence number: 3
# Document processing time: 00:07
# Total processing time: 01:00:21:34
# ----------------------------------
# Document: 253
# Document sentence number: 6
# Corpus is less than 9 sentence, summarization didn't apply sentence number: 6
# Document processing time: 00:01
# Total processing time: 01:00:21:36
# ----------------------------------
# Document: 254
# Document sentence number: 24
# Optimum cluster number: 7
# Summary sentence number: 5
# Document processing time: 00:07
# Total processing time: 01:00:21:43
# ----------------------------------
# Document: 255
# Document sentence number: 18
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:06
# Total processing time: 01:00:21:50
# ----------------------------------
# Document: 256
# Document sentence number: 39
# Optimum cluster number: 7
# Summary sentence number: 5
# Document processing time: 00:10
# Total processing time: 01:00:22:00
# ----------------------------------
# Document: 257
# Document sentence number: 20
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:06
# Total processing time: 01:00:22:06
# ----------------------------------
# Document: 258
# Document sentence number: 64
# Optimum cluster number: 13
# Summary sentence number: 5
# Document processing time: 00:15
# Total processing time: 01:00:22:22
# ----------------------------------
# Document: 259
# Document sentence number: 24
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:07
# Total processing time: 01:00:22:29
# ----------------------------------
# Document: 260
# Document sentence number: 19
# Optimum cluster number: 5
# ######### Error with PageRank
# Summary sentence number: 5
# Document processing time: 00:06
# Total processing time: 01:00:22:36
# ----------------------------------
# Document: 261
# Document sentence number: 47
# Optimum cluster number: 12
# Summary sentence number: 5
# Document processing time: 00:11
# Total processing time: 01:00:22:47
# ----------------------------------
# Document: 262
# Document sentence number: 73
# Optimum cluster number: 11
# Summary sentence number: 5
# Document processing time: 00:19
# Total processing time: 01:00:23:06
# ----------------------------------
# Document: 263
# Document sentence number: 18
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:06
# Total processing time: 01:00:23:13
# ----------------------------------
# Document: 264
# Document sentence number: 42
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:11
# Total processing time: 01:00:23:24
# ----------------------------------
# Document: 265
# Document sentence number: 17
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:05
# Total processing time: 01:00:23:29
# ----------------------------------
# Document: 266
# Document sentence number: 36
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:09
# Total processing time: 01:00:23:39
# ----------------------------------
# Document: 267
# Document sentence number: 16
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:05
# Total processing time: 01:00:23:45
# ----------------------------------
# Document: 268
# Document sentence number: 34
# Optimum cluster number: 10
# Summary sentence number: 5
# Document processing time: 00:09
# Total processing time: 01:00:23:54
# ----------------------------------
# Document: 269
# Document sentence number: 25
# Optimum cluster number: 6
# Summary sentence number: 5
# Document processing time: 00:07
# Total processing time: 01:00:24:02
# ----------------------------------
# Document: 270
# Document sentence number: 29
# Optimum cluster number: 6
# Summary sentence number: 5
# Document processing time: 00:08
# Total processing time: 01:00:24:10
# ----------------------------------
# Document: 271
# Document sentence number: 17
# Optimum cluster number: 2
# ######### Error with PageRank
# Summary sentence number: 2
# Document processing time: 00:05
# Total processing time: 01:00:24:16
# ----------------------------------
# Document: 272
# Document sentence number: 43
# Optimum cluster number: 6
# Summary sentence number: 5
# Document processing time: 00:11
# Total processing time: 01:00:24:27
# ----------------------------------
# Document: 273
# Document sentence number: 29
# Optimum cluster number: 6
# Summary sentence number: 5
# Document processing time: 00:07
# Total processing time: 01:00:24:35
# ----------------------------------
# Document: 274
# Document sentence number: 33
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:09
# Total processing time: 01:00:24:44
# ----------------------------------
# Document: 275
# Document sentence number: 61
# Optimum cluster number: 6
# Summary sentence number: 5
# Document processing time: 00:14
# Total processing time: 01:00:24:59
# ----------------------------------
# Document: 276
# Document sentence number: 21
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:06
# Total processing time: 01:00:25:06
# ----------------------------------
# Document: 277
# Document sentence number: 35
# Optimum cluster number: 9
# Summary sentence number: 5
# Document processing time: 00:09
# Total processing time: 01:00:25:15
# ----------------------------------
# Document: 278
# Document sentence number: 18
# Optimum cluster number: 3
# Summary sentence number: 3
# Document processing time: 00:06
# Total processing time: 01:00:25:21
# ----------------------------------
# Document: 279
# Document sentence number: 17
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:05
# Total processing time: 01:00:25:27
# ----------------------------------
# Document: 280
# Document sentence number: 22
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:06
# Total processing time: 01:00:25:34
# ----------------------------------
# Document: 281
# Document sentence number: 41
# Optimum cluster number: 12
# Summary sentence number: 5
# Document processing time: 00:10
# Total processing time: 01:00:25:44
# ----------------------------------
# Document: 282
# Document sentence number: 53
# Optimum cluster number: 9
# Summary sentence number: 5
# Document processing time: 00:12
# Total processing time: 01:00:25:57
# ----------------------------------
# Document: 283
# Document sentence number: 63
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:15
# Total processing time: 01:00:26:12
# ----------------------------------
# Document: 284
# Document sentence number: 49
# Optimum cluster number: 9
# Summary sentence number: 5
# Document processing time: 00:12
# Total processing time: 01:00:26:25
# ----------------------------------
# Document: 285
# Document sentence number: 16
# Optimum cluster number: 2
# Summary sentence number: 2
# Document processing time: 00:05
# Total processing time: 01:00:26:30
# ----------------------------------
# Document: 286
# Document sentence number: 26
# Optimum cluster number: 7
# Summary sentence number: 5
# Document processing time: 00:07
# Total processing time: 01:00:26:38
# ----------------------------------
# Document: 287
# Document sentence number: 17
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:05
# Total processing time: 01:00:26:44
# ----------------------------------
# Document: 288
# Document sentence number: 11
# Optimum cluster number: 2
# Summary sentence number: 2
# Document processing time: 00:03
# Total processing time: 01:00:26:47
# ----------------------------------
# Document: 289
# Document sentence number: 23
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:06
# Total processing time: 01:00:26:54
# ----------------------------------
# Document: 290
# Document sentence number: 39
# Optimum cluster number: 8
# Summary sentence number: 5
# Document processing time: 00:10
# Total processing time: 01:00:27:05
# ----------------------------------
# Document: 291
# Document sentence number: 17
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:05
# Total processing time: 01:00:27:10
# ----------------------------------
# Document: 292
# Document sentence number: 32
# Optimum cluster number: 7
# ######### Error with PageRank
# Summary sentence number: 5
# Document processing time: 00:08
# Total processing time: 01:00:27:19
# ----------------------------------
# Document: 293
# Document sentence number: 24
# Optimum cluster number: 7
# Summary sentence number: 5
# Document processing time: 00:07
# Total processing time: 01:00:27:26
# ----------------------------------
# Document: 294
# Document sentence number: 1
# Corpus is less than 9 sentence, summarization didn't apply sentence number: 1
# Document processing time: 00:01
# Total processing time: 01:00:27:28
# ----------------------------------
# Document: 295
# Document sentence number: 48
# Optimum cluster number: 11
# Summary sentence number: 5
# Document processing time: 00:12
# Total processing time: 01:00:27:40
# ----------------------------------
# Document: 296
# Document sentence number: 24
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:07
# Total processing time: 01:00:27:48
# ----------------------------------
# Document: 297
# Document sentence number: 49
# Optimum cluster number: 14
# Summary sentence number: 5
# Document processing time: 00:12
# Total processing time: 01:00:28:00
# ----------------------------------
# Document: 298
# Document sentence number: 51
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:12
# Total processing time: 01:00:28:13
# ----------------------------------
# Document: 299
# Document sentence number: 46
# Optimum cluster number: 7
# Summary sentence number: 5
# Document processing time: 00:11
# Total processing time: 01:00:28:24
# ----------------------------------
# Document: 300
# Document sentence number: 20
# Optimum cluster number: 3
# Summary sentence number: 3
# Document processing time: 00:06
# Total processing time: 01:00:28:31
# ----------------------------------
# Document: 301
# Document sentence number: 16
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:05
# Total processing time: 01:00:28:36
# ----------------------------------
# Document: 302
# Document sentence number: 31
# Optimum cluster number: 6
# Summary sentence number: 5
# Document processing time: 00:08
# Total processing time: 01:00:28:45
# ----------------------------------
# Document: 303
# Document sentence number: 19
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:06
# Total processing time: 01:00:28:51
# ----------------------------------
# Document: 304
# Document sentence number: 14
# Optimum cluster number: 3
# Summary sentence number: 3
# Document processing time: 00:05
# Total processing time: 01:00:28:56
# ----------------------------------
# Document: 305
# Document sentence number: 48
# Optimum cluster number: 10
# Summary sentence number: 5
# Document processing time: 00:12
# Total processing time: 01:00:29:09
# ----------------------------------
# Document: 306
# Document sentence number: 26
# Optimum cluster number: 6
# Summary sentence number: 5
# Document processing time: 00:07
# Total processing time: 01:00:29:16
# ----------------------------------
# Document: 307
# Document sentence number: 29
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:08
# Total processing time: 01:00:29:24
# ----------------------------------
# Document: 308
# Document sentence number: 25
# Optimum cluster number: 6
# Summary sentence number: 5
# Document processing time: 00:07
# Total processing time: 01:00:29:32
# ----------------------------------
# Document: 309
# Document sentence number: 34
# Optimum cluster number: 9
# Summary sentence number: 5
# Document processing time: 00:09
# Total processing time: 01:00:29:41
# ----------------------------------
# Document: 310
# Document sentence number: 43
# Optimum cluster number: 11
# Summary sentence number: 5
# Document processing time: 00:11
# Total processing time: 01:00:29:52
# ----------------------------------
# Document: 311
# Document sentence number: 44
# Optimum cluster number: 11
# Summary sentence number: 5
# Document processing time: 00:11
# Total processing time: 01:00:30:03
# ----------------------------------
# Document: 312
# Document sentence number: 52
# Optimum cluster number: 13
# Summary sentence number: 5
# Document processing time: 00:12
# Total processing time: 01:00:30:16
# ----------------------------------
# Document: 313
# Document sentence number: 51
# Optimum cluster number: 15
# Summary sentence number: 5
# Document processing time: 00:13
# Total processing time: 01:00:30:30
# ----------------------------------
# Document: 314
# Document sentence number: 12
# Optimum cluster number: 3
# Summary sentence number: 3
# Document processing time: 00:05
# Total processing time: 01:00:30:35
# ----------------------------------
# Document: 315
# Document sentence number: 102
# Optimum cluster number: 18
# Summary sentence number: 5
# Document processing time: 00:45
# Total processing time: 01:00:31:20
# ----------------------------------
# Document: 316
# Document sentence number: 27
# Optimum cluster number: 3
# Summary sentence number: 3
# Document processing time: 00:08
# Total processing time: 01:00:31:28
# ----------------------------------
# Document: 317
# Document sentence number: 17
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:05
# Total processing time: 01:00:31:34
# ----------------------------------
# Document: 318
# Document sentence number: 23
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:06
# Total processing time: 01:00:31:41
# ----------------------------------
# Document: 319
# Document sentence number: 28
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:07
# Total processing time: 01:00:31:49
# ----------------------------------
# Document: 320
# Document sentence number: 33
# Optimum cluster number: 7
# Summary sentence number: 5
# Document processing time: 00:09
# Total processing time: 01:00:31:58
# ----------------------------------
# Document: 321
# Document sentence number: 23
# Optimum cluster number: 6
# Summary sentence number: 5
# Document processing time: 00:07
# Total processing time: 01:00:32:05
# ----------------------------------
# Document: 322
# Document sentence number: 17
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:05
# Total processing time: 01:00:32:11
# ----------------------------------
# Document: 323
# Document sentence number: 10
# Optimum cluster number: 2
# Summary sentence number: 2
# Document processing time: 00:03
# Total processing time: 01:00:32:14
# ----------------------------------
# Document: 324
# Document sentence number: 21
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:06
# Total processing time: 01:00:32:21
# ----------------------------------
# Document: 325
# Document sentence number: 44
# Optimum cluster number: 12
# Summary sentence number: 5
# Document processing time: 00:11
# Total processing time: 01:00:32:32
# ----------------------------------
# Document: 326
# Document sentence number: 53
# Optimum cluster number: 16
# Summary sentence number: 5
# Document processing time: 00:12
# Total processing time: 01:00:32:45
# ----------------------------------
# Document: 327
# Document sentence number: 49
# Optimum cluster number: 6
# Summary sentence number: 5
# Document processing time: 00:11
# Total processing time: 01:00:32:57
# ----------------------------------
# Document: 328
# Document sentence number: 34
# Optimum cluster number: 8
# Summary sentence number: 5
# Document processing time: 00:09
# Total processing time: 01:00:33:06
# ----------------------------------
# Document: 329
# Document sentence number: 30
# Optimum cluster number: 6
# Summary sentence number: 5
# Document processing time: 00:08
# Total processing time: 01:00:33:15
# ----------------------------------
# Document: 330
# Document sentence number: 70
# Optimum cluster number: 8
# Summary sentence number: 5
# Document processing time: 00:18
# Total processing time: 01:00:33:33
# ----------------------------------
# Document: 331
# Document sentence number: 23
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:06
# Total processing time: 01:00:33:40
# ----------------------------------
# Document: 332
# Document sentence number: 15
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:05
# Total processing time: 01:00:33:46
# ----------------------------------
# Document: 333
# Document sentence number: 22
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:06
# Total processing time: 01:00:33:53
# ----------------------------------
# Document: 334
# Document sentence number: 31
# Optimum cluster number: 9
# Summary sentence number: 5
# Document processing time: 00:08
# Total processing time: 01:00:34:01
# ----------------------------------
# Document: 335
# Document sentence number: 16
# Optimum cluster number: 3
# Summary sentence number: 3
# Document processing time: 00:05
# Total processing time: 01:00:34:07
# ----------------------------------
# Document: 336
# Document sentence number: 18
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:06
# Total processing time: 01:00:34:13
# ----------------------------------
# Document: 337
# Document sentence number: 47
# Optimum cluster number: 8
# Summary sentence number: 5
# Document processing time: 00:11
# Total processing time: 01:00:34:25
# ----------------------------------
# Document: 338
# Document sentence number: 23
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:06
# Total processing time: 01:00:34:31
# ----------------------------------
# Document: 339
# Document sentence number: 46
# Optimum cluster number: 7
# Summary sentence number: 5
# Document processing time: 00:11
# Total processing time: 01:00:34:43
# ----------------------------------
# Document: 340
# Document sentence number: 45
# Optimum cluster number: 11
# ...
# Summary sentence number: 5
# Document processing time: 00:13
# Total processing time: 01:00:47:00
# ----------------------------------
# Document: 421
# Document sentence number: 9
# Optimum cluster number: 2
# Summary sentence number: 2
# Document processing time: 00:03
# Total processing time: 01:00:47:03
# ----------------------------------
# Document: 422
# Document sentence number: 38
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:09
# Total processing time: 01:00:47:13
# ----------------------------------
# Document: 423
# Document sentence number: 20
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:06
# Total processing time: 01:00:47:19
# ----------------------------------
# Document: 424
# Document sentence number: 16
# Optimum cluster number: 3
# Summary sentence number: 3
# Document processing time: 00:05
# Total processing time: 01:00:47:25
# ----------------------------------
# Document: 425
# Document sentence number: 13
# Optimum cluster number: 3
# Summary sentence number: 3
# Document processing time: 00:05
# Total processing time: 01:00:47:30
# ----------------------------------
# Document: 426
# Document sentence number: 41
# Optimum cluster number: 6
# Summary sentence number: 5
# Document processing time: 00:10
# Total processing time: 01:00:47:40
# ----------------------------------
# Document: 427
# Document sentence number: 13
# Optimum cluster number: 2
# Summary sentence number: 2
# Document processing time: 00:05
# Total processing time: 01:00:47:46
# ----------------------------------
# Document: 428
# Document sentence number: 31
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:08
# Total processing time: 01:00:47:54
# ----------------------------------
# Document: 429
# Document sentence number: 34
# Optimum cluster number: 7
# Summary sentence number: 5
# Document processing time: 00:09
# Total processing time: 01:00:48:03
# ----------------------------------
# Document: 430
# Document sentence number: 45
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:11
# Total processing time: 01:00:48:15
# ----------------------------------
# Document: 431
# Document sentence number: 17
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:05
# Total processing time: 01:00:48:21
# ----------------------------------
# Document: 432
# Document sentence number: 42
# Optimum cluster number: 9
# Summary sentence number: 5
# Document processing time: 00:10
# Total processing time: 01:00:48:32
# ----------------------------------
# Document: 433
# Document sentence number: 23
# Optimum cluster number: 6
# Summary sentence number: 5
# Document processing time: 00:06
# Total processing time: 01:00:48:39
# ----------------------------------
# Document: 434
# Document sentence number: 67
# Optimum cluster number: 12
# Summary sentence number: 5
# Document processing time: 00:16
# Total processing time: 01:00:48:55
# ----------------------------------
# Document: 435
# Document sentence number: 9
# Optimum cluster number: 2
# Summary sentence number: 2
# Document processing time: 00:03
# Total processing time: 01:00:48:58
# ----------------------------------
# Document: 436
# Document sentence number: 58
# Optimum cluster number: 17
# Summary sentence number: 5
# Document processing time: 00:14
# Total processing time: 01:00:49:12
# ----------------------------------
# Document: 437
# Document sentence number: 41
# Optimum cluster number: 12
# Summary sentence number: 5
# Document processing time: 00:10
# Total processing time: 01:00:49:23
# ----------------------------------
# Document: 438
# Document sentence number: 27
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:07
# Total processing time: 01:00:49:31
# ----------------------------------
# Document: 439
# Document sentence number: 29
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:08
# Total processing time: 01:00:49:39
# ----------------------------------
# Document: 440
# Document sentence number: 37
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:09
# Total processing time: 01:00:49:49
# ----------------------------------
# Document: 441
# Document sentence number: 19
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:06
# Total processing time: 01:00:49:55
# ----------------------------------
# Document: 442
# Document sentence number: 21
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:06
# Total processing time: 01:00:50:02
# ----------------------------------
# Document: 443
# Document sentence number: 67
# Optimum cluster number: 12
# Summary sentence number: 5
# Document processing time: 00:16
# Total processing time: 01:00:50:18
# ----------------------------------
# Document: 444
# Document sentence number: 39
# Optimum cluster number: 7
# Summary sentence number: 5
# Document processing time: 00:10
# Total processing time: 01:00:50:29
# ----------------------------------
# Document: 445
# Document sentence number: 62
# Optimum cluster number: 10
# Summary sentence number: 5
# Document processing time: 00:15
# Total processing time: 01:00:50:44
# ----------------------------------
# Document: 446
# Document sentence number: 21
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:06
# Total processing time: 01:00:50:51
# ----------------------------------
# Document: 447
# Document sentence number: 53
# Optimum cluster number: 14
# Summary sentence number: 5
# Document processing time: 00:12
# Total processing time: 01:00:51:04
# ----------------------------------
# Document: 448
# Document sentence number: 16
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:05
# Total processing time: 01:00:51:09
# ----------------------------------
# Document: 449
# Document sentence number: 14
# Optimum cluster number: 2
# Summary sentence number: 2
# Document processing time: 00:05
# Total processing time: 01:00:51:15
# ----------------------------------
# Document: 450
# Document sentence number: 48
# Optimum cluster number: 8
# Summary sentence number: 5
# Document processing time: 00:12
# Total processing time: 01:00:51:27
# ----------------------------------
# Document: 451
# Document sentence number: 25
# Optimum cluster number: 7
# Summary sentence number: 5
# Document processing time: 00:07
# Total processing time: 01:00:51:34
# ----------------------------------
# Document: 452
# Document sentence number: 45
# Optimum cluster number: 6
# Summary sentence number: 5
# Document processing time: 00:11
# Total processing time: 01:00:51:46
# ----------------------------------
# Document: 453
# Document sentence number: 58
# Optimum cluster number: 15
# Summary sentence number: 5
# Document processing time: 00:14
# Total processing time: 01:00:52:00
# ----------------------------------
# Document: 454
# Document sentence number: 35
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:09
# Total processing time: 01:00:52:09
# ----------------------------------
# Document: 455
# Document sentence number: 49
# Optimum cluster number: 14
# Summary sentence number: 5
# Document processing time: 00:12
# Total processing time: 01:00:52:22
# ----------------------------------
# Document: 456
# Document sentence number: 13
# Optimum cluster number: 3
# Summary sentence number: 3
# Document processing time: 00:05
# Total processing time: 01:00:52:27
# ----------------------------------
# Document: 457
# Document sentence number: 12
# Optimum cluster number: 2
# Summary sentence number: 2
# Document processing time: 00:05
# Total processing time: 01:00:52:32
# ----------------------------------
# Document: 458
# Document sentence number: 27
# Optimum cluster number: 8
# Summary sentence number: 5
# Document processing time: 00:07
# Total processing time: 01:00:52:40
# ----------------------------------
# Document: 459
# Document sentence number: 47
# Optimum cluster number: 9
# Summary sentence number: 5
# Document processing time: 00:11
# Total processing time: 01:00:52:52
# ----------------------------------
# Document: 460
# Document sentence number: 37
# Optimum cluster number: 6
# Summary sentence number: 5
# Document processing time: 00:09
# Total processing time: 01:00:53:01
# ----------------------------------
# Document: 461
# Document sentence number: 58
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:13
# Total processing time: 01:00:53:15
# ----------------------------------
# Document: 462
# Document sentence number: 35
# Optimum cluster number: 10
# Summary sentence number: 5
# Document processing time: 00:09
# Total processing time: 01:00:53:25
# ----------------------------------
# Document: 463
# Document sentence number: 25
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:07
# Total processing time: 01:00:53:32
# ----------------------------------
# Document: 464
# Document sentence number: 42
# Optimum cluster number: 13
# Summary sentence number: 5
# Document processing time: 00:10
# Total processing time: 01:00:53:43
# ----------------------------------
# Document: 465
# Document sentence number: 27
# Optimum cluster number: 6
# Summary sentence number: 5
# Document processing time: 00:08
# Total processing time: 01:00:53:52
# ----------------------------------
# Document: 466
# Document sentence number: 46
# Optimum cluster number: 6
# Summary sentence number: 5
# Document processing time: 00:11
# Total processing time: 01:00:54:03
# ----------------------------------
# Document: 467
# Document sentence number: 26
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:07
# Total processing time: 01:00:54:11
# ----------------------------------
# Document: 468
# Document sentence number: 23
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:06
# Total processing time: 01:00:54:18
# ----------------------------------
# Document: 469
# Document sentence number: 31
# Optimum cluster number: 7
# Summary sentence number: 5
# Document processing time: 00:08
# Total processing time: 01:00:54:26
# ----------------------------------
# Document: 470
# Document sentence number: 43
# Optimum cluster number: 12
# Summary sentence number: 5
# Document processing time: 00:11
# Total processing time: 01:00:54:37
# ----------------------------------
# Document: 471
# Document sentence number: 14
# Optimum cluster number: 3
# Summary sentence number: 3
# Document processing time: 00:05
# Total processing time: 01:00:54:42
# ----------------------------------
# Document: 472
# Document sentence number: 21
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:06
# Total processing time: 01:00:54:49
# ----------------------------------
# Document: 473
# Document sentence number: 19
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:06
# Total processing time: 01:00:54:56
# ----------------------------------
# Document: 474
# Document sentence number: 21
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:06
# Total processing time: 01:00:55:02
# ----------------------------------
# Document: 475
# Document sentence number: 15
# Optimum cluster number: 2
# Summary sentence number: 2
# Document processing time: 00:05
# Total processing time: 01:00:55:08
# ----------------------------------
# Document: 476
# Document sentence number: 57
# Optimum cluster number: 11
# Summary sentence number: 5
# Document processing time: 00:14
# Total processing time: 01:00:55:22
# ----------------------------------
# Document: 477
# Document sentence number: 12
# Optimum cluster number: 3
# Summary sentence number: 3
# Document processing time: 00:05
# Total processing time: 01:00:55:27
# ----------------------------------
# Document: 478
# Document sentence number: 34
# Optimum cluster number: 6
# Summary sentence number: 5
# Document processing time: 00:09
# Total processing time: 01:00:55:37
# ----------------------------------
# Document: 479
# Document sentence number: 29
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:08
# Total processing time: 01:00:55:45
# ----------------------------------
# Document: 480
# Document sentence number: 37
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:09
# Total processing time: 01:00:55:55
# ----------------------------------
# Document: 481
# Document sentence number: 15
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:05
# Total processing time: 01:00:56:00
# ----------------------------------
# Document: 482
# Document sentence number: 48
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:12
# Total processing time: 01:00:56:13
# ----------------------------------
# Document: 483
# Document sentence number: 37
# Optimum cluster number: 11
# Summary sentence number: 5
# Document processing time: 00:09
# Total processing time: 01:00:56:22
# ----------------------------------
# Document: 484
# Document sentence number: 25
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:07
# Total processing time: 01:00:56:30
# ----------------------------------
# Document: 485
# Document sentence number: 48
# Optimum cluster number: 6
# Summary sentence number: 5
# Document processing time: 00:12
# Total processing time: 01:00:56:42
# ----------------------------------
# Document: 486
# Document sentence number: 11
# Optimum cluster number: 2
# Summary sentence number: 2
# Document processing time: 00:03
# Total processing time: 01:00:56:45
# ----------------------------------
# Document: 487
# Document sentence number: 59
# Optimum cluster number: 10
# Summary sentence number: 5
# Document processing time: 00:14
# Total processing time: 01:00:56:59
# ----------------------------------
# Document: 488
# Document sentence number: 76
# Optimum cluster number: 7
# Summary sentence number: 5
# Document processing time: 00:20
# Total processing time: 01:00:57:19
# ----------------------------------
# Document: 489
# Document sentence number: 37
# Optimum cluster number: 9
# Summary sentence number: 5
# Document processing time: 00:09
# Total processing time: 01:00:57:29
# ----------------------------------
# Document: 490
# Document sentence number: 25
# Optimum cluster number: 7
# Summary sentence number: 5
# Document processing time: 00:07
# Total processing time: 01:00:57:37
# ----------------------------------
# Document: 491
# Document sentence number: 23
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:06
# Total processing time: 01:00:57:43
# ----------------------------------
# Document: 492
# Document sentence number: 17
# Optimum cluster number: 2
# Summary sentence number: 2
# Document processing time: 00:05
# Total processing time: 01:00:57:49
# ----------------------------------
# Document: 493
# Document sentence number: 12
# Optimum cluster number: 3
# Summary sentence number: 3
# Document processing time: 00:05
# Total processing time: 01:00:57:54
# ----------------------------------
# Document: 494
# Document sentence number: 20
# Optimum cluster number: 3
# Summary sentence number: 3
# Document processing time: 00:06
# Total processing time: 01:00:58:01
# ----------------------------------
# Document: 495
# Document sentence number: 48
# Optimum cluster number: 6
# Summary sentence number: 5
# Document processing time: 00:12
# Total processing time: 01:00:58:13
# ----------------------------------
# Document: 496
# Document sentence number: 38
# Optimum cluster number: 7
# Summary sentence number: 5
# Document processing time: 00:09
# Total processing time: 01:00:58:22
# ----------------------------------
# Document: 497
# Document sentence number: 16
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:05
# Total processing time: 01:00:58:28
# ----------------------------------
# Document: 498
# Document sentence number: 90
# Optimum cluster number: 14
# Summary sentence number: 5
# Document processing time: 00:40
# Total processing time: 01:00:59:08
# ----------------------------------
# Document: 499
# Document sentence number: 43
# Optimum cluster number: 4
# Summary sentence number: 4
# Document processing time: 00:11
# Total processing time: 01:00:59:20
# ----------------------------------
# Document: 500
# Document sentence number: 22
# Optimum cluster number: 5
# Summary sentence number: 5
# Document processing time: 00:06
# Total processing time: 01:00:59:27
# ----------------------------------

# %%
def prepare_results(m, p, r, f):
    return '\t{}:\t{}: {:5.2f}\t{}: {:5.2f}\t{}: {:5.2f}'.format(m, 'P', 100.0 * p, 'R', 100.0 * r, 'F1', 100.0 * f)

def rougeEvaluation(all_hypothesis, all_references):

    for aggregator in ['Avg']:
        print('Evaluation with {}'.format(aggregator))
        apply_avg = aggregator == 'Avg'
        apply_best = aggregator == 'Best'

        evaluator = rouge.Rouge(metrics=['rouge-n', 'rouge-l', 'rouge-w'],
                               max_n=4,
                               limit_length=False,
                               length_limit=1000,
                               length_limit_type='words',
                               apply_avg=apply_avg,
                               apply_best=apply_best,
                               alpha=0.2, # Default F1_score
                               weight_factor=1.2,
                               stemming=True)

        scores = evaluator.get_scores(all_hypothesis, all_references)

        for metric, results in sorted(scores.items(), key=lambda x: x[0]):
            if not apply_avg and not apply_best: # value is a type of list as we evaluate each summary vs each reference
                for hypothesis_id, results_per_ref in enumerate(results):
                    nb_references = len(results_per_ref['p'])
                    for reference_id in range(nb_references):
                        print('\tHypothesis #{} & Reference #{}: '.format(hypothesis_id, reference_id))
                        print('\t' + prepare_results(metric,results_per_ref['p'][reference_id], results_per_ref['r'][reference_id], results_per_ref['f'][reference_id]))
                print()
            else:
                print(prepare_results(metric, results['p'], results['r'], results['f']))
        print()

# %%
len(all_goldstandart)
# Out:
# 400

# %%
rougeEvaluation(all_summary[:200], all_goldstandart[:200])
# Out:
# Evaluation with Avg
# 	rouge-1:	P: 20.01	R: 40.96	F1: 32.57
# 	rouge-2:	P:  5.66	R: 11.67	F1:  9.21
# 	rouge-3:	P:  2.44	R:  5.13	F1:  4.00
# 	rouge-4:	P:  1.34	R:  2.87	F1:  2.21
# 	rouge-l:	P: 21.66	R: 39.41	F1: 32.98
# 	rouge-w:	P: 12.06	R: 15.11	F1: 13.89

# %%
# Play an audio beep. Any audio URL will do.
from google.colab import output
output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')

# %%
# Save files

import json
import os

# Define the file path
file_path = "/content/savedDocumentsandSummaries.json"  # Replace with the desired file path

# Check if the file already exists
if os.path.exists(file_path):
    # Read the existing data from the JSON file
    with open(file_path, "r") as file:
        existing_data = json.load(file)

    # Combine the existing data with the new data (lists)
    existing_summary = existing_data.get("all_summary", [])
    existing_goldstandart = existing_data.get("all_goldstandart", [])

    # Assuming you have three new lists: new_intermediate_summary, new_summary, new_goldstandart
    # Sample new lists (replace these with your actual lists)
    new_summary = all_summary
    new_goldstandart = all_goldstandart


    # Merge the new lists with the existing ones
    all_summary = existing_summary + new_summary
    all_goldstandart = existing_goldstandart + new_goldstandart

# Combine the lists into a dictionary for easy serialization
data = {
    "all_summary": all_summary,
    "all_goldstandart": all_goldstandart
}

# Save the data to a JSON file
with open(file_path, "w") as file:
    json.dump(data, file)

print("Lists have been saved to", file_path)
# Out:
# Lists have been saved to /content/savedDocumentsandSummaries.json

# %%
print(len(data['all_summary']))
# Out:
# 500

# %%
rougeEvaluation(data['all_summary'], data['all_goldstandart'])
# Out:
# Evaluation with Avg
# 	rouge-1:	P: 20.10	R: 39.78	F1: 31.76
# 	rouge-2:	P:  5.81	R: 10.91	F1:  8.77
# 	rouge-3:	P:  2.73	R:  4.83	F1:  3.90
# 	rouge-4:	P:  1.62	R:  2.71	F1:  2.21
# 	rouge-l:	P: 21.87	R: 38.66	F1: 32.47
# 	rouge-w:	P: 12.34	R: 14.74	F1: 13.63

# %%
# Play an audio beep. Any audio URL will do.
from google.colab import output
output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')

# %%
sentencenumber=0
for i in range(len(all_summary)):
  sentencenumber=sentencenumber+textSentenceCount(all_summary[i])

avg=sentencenumber/len(all_summary)

# %%
avg
# Out:
# 4.276

# %%
sentencenumber=0
for i in range(len(all_goldstandart)):
  sentencenumber=sentencenumber+textSentenceCount(all_goldstandart[i])

avg=sentencenumber/len(all_goldstandart)

# %%
avg
# Out:
# 3.502
