# %% [markdown]
# <a href="https://colab.research.google.com/github/tubagokhan/SummarizationHybrid/blob/main/GraphandClusterCNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# !pip install datasets
# !pip install torch
# !pip install scikit-learn
# !pip install matplotlib
# !pip install sentence_transformers
# !pip install py-rouge==1.1
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.31.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.16.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.3.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.13.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.22.4)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Requirement already satisfied: dill<0.3.7,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.27.1)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.65.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.2.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.14)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.8.4)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.16.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (3.12.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (4.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.0.1+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (16.0.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.22.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.41.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: sentence_transformers in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.15.2+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.22.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.10.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.16.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (3.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2.27.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (4.7.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (23.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence_transformers) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence_transformers) (16.0.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2022.10.31)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.3.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence_transformers) (8.1.4)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence_transformers) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence_transformers) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence_transformers) (2.1.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence_transformers) (1.3.0)
# Requirement already satisfied: py-rouge==1.1 in /usr/local/lib/python3.10/dist-packages (1.1)

# %%
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sentence_transformers import SentenceTransformer
from nltk import sent_tokenize,word_tokenize

import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

import warnings
warnings.filterwarnings("ignore")
import re

from datasets import load_dataset
from scipy.spatial import distance

import math
from math import*

import rouge

import networkx as nx

import time
from transformers import logging
logging.set_verbosity_error()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# Preprocessing method
def preprocess_corpus(text):
    # Remove special characters and extra whitespaces
    text = re.sub(r"[^a-zA-Z0-9\s.]", "", text)
    text = re.sub(r"\s+", " ", text)
    return text

# %% [markdown]
# ## CLUSTER

# %%
#function calculates the optimal number of clusters using the elbow method. The function plots the elbow curve, which shows the inertia values for different cluster numbers. The user can visually inspect the plot to determine the elbow point, indicating the optimal number of clusters.
def find_optimum_clusters(data, max_clusters):
    inertias = []
    for k in range(1, max_clusters + 1):
        kmeans = KMeans(n_clusters=k, random_state=0).fit(data)
        inertias.append(kmeans.inertia_)

    # Plotting the elbow curve
    #plt.plot(range(1, max_clusters + 1), inertias)
    #plt.xlabel("Number of Clusters")
    #plt.ylabel("Inertia")
    #plt.title("Elbow Curve")
    #plt.show()

    # Calculate the optimal number of clusters using the elbow method
    diff = np.diff(inertias)
    acceleration = np.diff(diff)
    opt_cluster_num = acceleration.argmin() + 2  # Adding 2 to get the index of the minimum acceleration
    return opt_cluster_num

# %%
def createSummaryUsingKMeans(corpus, modelName):
    sentences = sent_tokenize(corpus)
    model = SentenceTransformer(modelName)
    sentence_embeddings = model.encode(sentences)

    optimum_clusters = find_optimum_clusters(sentence_embeddings, int(len(sentences) / 3))
    print("Optimum cluster number:", optimum_clusters)

    # Perform kmean clustering
    kmeans = KMeans(n_clusters=optimum_clusters, random_state=0, n_init='auto').fit(sentence_embeddings)

    chosen_sentence_indexes=[]
    for cluster_id in range(optimum_clusters):
        cluster_indices = np.where(kmeans.labels_ == cluster_id)[0]
        sorted_cluster_indices = sorted(cluster_indices, key=lambda x: sentences[x])
        chosen_sentence_index = sorted_cluster_indices[0]  # Select the first sentence from the sorted indices
        chosen_sentence_indexes.append(chosen_sentence_index)

    sorted_indexes=sorted(chosen_sentence_indexes)

    chosen_sentences = []
    for chosen_sentence_index in sorted_indexes:
        chosen_sentences.append(sentences[chosen_sentence_index])

    summary = " ".join(chosen_sentences)

    return summary

# %% [markdown]
# ## GRAPH NODE WEIGHTS

# %%
def allCorpusSentenceRanking(tokenizedCorpus,corpus):
    sentenceRankList=[]
    for i in range(len(tokenizedCorpus)):
        value=sentenceRanking(tokenizedCorpus[i],i,corpus)
        value=round(value,5)
        sentenceRankList.append(value)
    return sentenceRankList

def sentenceRanking(sentence,location,corpus):
    value=0
    value=sentencePosition(sentence,location,corpus)
    value=value+sentenceLength(sentence,corpus)
    value=value+properNoun(sentence,corpus)
    value=value+numericalToken(sentence,corpus)
    return value

def textWordCount(Text):
    number_of_words = word_tokenize(Text)
    count=(len(number_of_words))
    return count

def textSentenceCount(Text):
    number_of_sentences = sent_tokenize(Text)
    count=(len(number_of_sentences))
    return count

def longestSentenceLenght(Text):
    text=sent_tokenize(Text)
    temp=0
    for i in range(len(text)):
        if temp<textWordCount(text[i]):
            temp=textWordCount(text[i])
    return temp

def sentencePosition(sentence,location,corpus):
    N=textSentenceCount(corpus)
    if location+1 == N:
        return 1.0
    elif location==0:
        return 1.0
    else:
        value=(N-location)/N
        return value

def sentenceLength(sentence,corpus):
    return textWordCount(sentence)/longestSentenceLenght(corpus)

def properNoun(sentence,corpus):
    text = nltk.word_tokenize(sentence)
    tagged=nltk.pos_tag(text)
    noProperNoun=0
    #print(tagged)
    for word in tagged:
        if word[1]=='NNP':
            noProperNoun=noProperNoun+1
    #print(noProperNoun)
    return noProperNoun/len(text)

def numericalToken(sentence,corpus):
    text = nltk.word_tokenize(sentence)
    tagged=nltk.pos_tag(text)
    noNumericalToken=0
    #print(tagged)
    for word in tagged:
        if word[1]=='CD':
            noNumericalToken=noNumericalToken+1
  #print(noProperNoun)
    return 1-(noNumericalToken/len(text))

# %% [markdown]
# ## GRAPH

# %%
def cosine(u, v):
    return np.dot(u, v) / (np.linalg.norm(u) * np.linalg.norm(v))

def createGraph(sentences, modelName):
    model = SentenceTransformer(modelName)
    sentence_embeddings = model.encode(sentences)
    sentenceGraph =np.zeros((len(sentences), len(sentences)))
    temp = np.arange(len(sentences))
    for x in range(len(sentences)):
        newTemp= np.delete(temp, x)
        for y in newTemp:
            similarity= cosine(sentence_embeddings[x],sentence_embeddings[y]) # You can change the vector similarity measurement method used when creating graphs. Cosine, euclidean, manhattan and minkowski methods are defined.
            sentenceGraph[x][y]=abs(similarity)
    return sentenceGraph

def findHighestSimilarityRank(similarityMatrix, initialRank):
    newRank=[0] * len(similarityMatrix)
    temp=0
    for i in range(len(similarityMatrix)):
        for j in range(len(similarityMatrix)):
            temp=temp+similarityMatrix[i][j] # sum of total similarity of sentences
        newRank[i]=temp*initialRank[i]
        temp=0

    return newRank

def findHighestSimilarityRankNoWRANK(similarityMatrix, initialRank):

    nodeWeightLSARanks = initialRank

    for x in range(len(initialRank)):
        for y in range(len(initialRank)):
            temp=initialRank[x]+initialRank[y]
            similarityMatrix[x][y]=similarityMatrix[x][y]+temp*0.01
    G = nx.Graph()
    for x in range(len(initialRank)):
        for y in range(len(initialRank)):
            G.add_node(x)
            G.add_edge(x, y, weight=similarityMatrix[x,y] )
    eigenVectorCentrality = nx.eigenvector_centrality(G, max_iter=100, tol=1.0e-6, nstart=None, weight='weight')

    edgeWeightEigenVectorRanks=[0]*len(eigenVectorCentrality)
    for i in range (len(eigenVectorCentrality)):
        edgeWeightEigenVectorRanks[i]=eigenVectorCentrality[i]

    return edgeWeightEigenVectorRanks

def createSummaryUsingGraph(corpus,modelName):
  sentences = sent_tokenize(corpus)
  summaryAmmount= int(len(sentences)*0.2)
  initialRank=allCorpusSentenceRanking(sentences,corpus)
  similarityMatrix=createGraph(sentences,modelName)
  sentencesRank=findHighestSimilarityRankNoWRANK(similarityMatrix, initialRank)

  temp=sorted(sentencesRank)
  threshold=temp[-summaryAmmount]
  summarySentencesIndexes=[]

  for i in range(len(sentencesRank)):
      if sentencesRank[i]>=threshold:
        summarySentencesIndexes.append(i)

  #print(summarySentencesIndexes)
  summary=""
  for i in range(len(summarySentencesIndexes)):
    summary=summary + ' ' +sentences[summarySentencesIndexes[i]]
  return summary

# %%
#MAIN
modelName='all-mpnet-base-v2'

dataset = load_dataset('cnn_dailymail', '3.0.0')
#corpus = dataset['train']['article'][50]


#dataset = load_dataset("ccdv/govreport-summarization")


startTimeforOverall = time.time()
all_intermediate_summary=[]
all_summary=[]
all_goldstandart=[]

N=1000
startN=0

for d in range(N):
    startTimeforDocument = time.time()
    print("Document:",startN+d+1)
    corpus=dataset['train']['article'][startN+d]
    corpus = preprocess_corpus(corpus)
    #print(corpus)
    print("Document sentence number:",textSentenceCount(corpus))
    all_goldstandart.append(dataset['train']['highlights'][startN+d])

    if (textSentenceCount(corpus)>8):
      intermadiatesummary=createSummaryUsingGraph(corpus, modelName)
      print("Intermediate summary sentence number:",textSentenceCount(intermadiatesummary))
      all_intermediate_summary.append(intermadiatesummary)

      if (textSentenceCount(intermadiatesummary)>8):
        summary=createSummaryUsingKMeans(intermadiatesummary, modelName)
        print("Final summary sentence number:",textSentenceCount(summary))
        all_summary.append(summary)

      else:
        print("Intermediate summary is shorter than 9 sentences, Second step didn't applied")
        all_summary.append(intermadiatesummary)


    else:
      print("Document is shorter than 9 sentences, Summarization didnt apply")
      all_intermediate_summary.append(corpus)
      all_summary.append(corpus)



    elapsedTimeforDocument = time.time() - startTimeforDocument
    elapsedTimeforAll = time.time() - startTimeforOverall
    print('Document processing time: '+time.strftime("%M:%S", time.gmtime(elapsedTimeforDocument)))
    print('Total processing time: '+time.strftime("%d:%H:%M:%S", time.gmtime(elapsedTimeforAll)))

    print("----------------------------------")
# Out:
# WARNING:datasets.builder:Found cached dataset cnn_dailymail (/root/.cache/huggingface/datasets/cnn_dailymail/3.0.0/3.0.0/1b3c71476f6d152c31c1730e83ccb08bcf23e348233f4fcc11e182248e6bf7de)
#   0%|          | 0/3 [00:00<?, ?it/s]
# Streaming output truncated to the last 5000 lines.
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:12
# Total processing time: 01:00:43:38
# ----------------------------------
# Document: 306
# Document sentence number: 26
# Intermediate summary sentence number: 5
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:09
# Total processing time: 01:00:43:47
# ----------------------------------
# Document: 307
# Document sentence number: 29
# Intermediate summary sentence number: 5
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:00:43:54
# ----------------------------------
# Document: 308
# Document sentence number: 25
# Intermediate summary sentence number: 5
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:09
# Total processing time: 01:00:44:04
# ----------------------------------
# Document: 309
# Document sentence number: 34
# Intermediate summary sentence number: 6
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:09
# Total processing time: 01:00:44:13
# ----------------------------------
# Document: 310
# Document sentence number: 43
# Intermediate summary sentence number: 8
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:13
# Total processing time: 01:00:44:27
# ----------------------------------
# Document: 311
# Document sentence number: 44
# Intermediate summary sentence number: 8
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:10
# Total processing time: 01:00:44:38
# ----------------------------------
# Document: 312
# Document sentence number: 52
# Intermediate summary sentence number: 9
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:14
# Total processing time: 01:00:44:52
# ----------------------------------
# Document: 313
# Document sentence number: 51
# Intermediate summary sentence number: 10
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:16
# Total processing time: 01:00:45:09
# ----------------------------------
# Document: 314
# Document sentence number: 12
# Intermediate summary sentence number: 2
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:06
# Total processing time: 01:00:45:15
# ----------------------------------
# Document: 315
# Document sentence number: 102
# Intermediate summary sentence number: 20
# Optimum cluster number: 3
# Final summary sentence number: 3
# Document processing time: 00:20
# Total processing time: 01:00:45:35
# ----------------------------------
# Document: 316
# Document sentence number: 27
# Intermediate summary sentence number: 5
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:09
# Total processing time: 01:00:45:44
# ----------------------------------
# Document: 317
# Document sentence number: 17
# Intermediate summary sentence number: 3
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:05
# Total processing time: 01:00:45:49
# ----------------------------------
# Document: 318
# Document sentence number: 23
# Intermediate summary sentence number: 4
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:00:45:57
# ----------------------------------
# Document: 319
# Document sentence number: 28
# Intermediate summary sentence number: 5
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:00:46:04
# ----------------------------------
# Document: 320
# Document sentence number: 33
# Intermediate summary sentence number: 6
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:09
# Total processing time: 01:00:46:13
# ----------------------------------
# Document: 321
# Document sentence number: 23
# Intermediate summary sentence number: 4
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:06
# Total processing time: 01:00:46:20
# ----------------------------------
# Document: 322
# Document sentence number: 17
# Intermediate summary sentence number: 3
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:06
# Total processing time: 01:00:46:27
# ----------------------------------
# Document: 323
# Document sentence number: 10
# Intermediate summary sentence number: 2
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:04
# Total processing time: 01:00:46:31
# ----------------------------------
# Document: 324
# Document sentence number: 21
# Intermediate summary sentence number: 4
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:00:46:39
# ----------------------------------
# Document: 325
# Document sentence number: 44
# Intermediate summary sentence number: 8
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:08
# Total processing time: 01:00:46:47
# ----------------------------------
# Document: 326
# Document sentence number: 53
# Intermediate summary sentence number: 10
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:12
# Total processing time: 01:00:47:00
# ----------------------------------
# Document: 327
# Document sentence number: 49
# Intermediate summary sentence number: 9
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:11
# Total processing time: 01:00:47:11
# ----------------------------------
# Document: 328
# Document sentence number: 34
# Intermediate summary sentence number: 6
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:00:47:19
# ----------------------------------
# Document: 329
# Document sentence number: 30
# Intermediate summary sentence number: 6
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:08
# Total processing time: 01:00:47:27
# ----------------------------------
# Document: 330
# Document sentence number: 70
# Intermediate summary sentence number: 14
# Optimum cluster number: 3
# Final summary sentence number: 3
# Document processing time: 00:19
# Total processing time: 01:00:47:46
# ----------------------------------
# Document: 331
# Document sentence number: 23
# Intermediate summary sentence number: 4
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:09
# Total processing time: 01:00:47:56
# ----------------------------------
# Document: 332
# Document sentence number: 15
# Intermediate summary sentence number: 3
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:04
# Total processing time: 01:00:48:01
# ----------------------------------
# Document: 333
# Document sentence number: 22
# Intermediate summary sentence number: 4
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:00:48:09
# ----------------------------------
# Document: 334
# Document sentence number: 31
# Intermediate summary sentence number: 6
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:00:48:16
# ----------------------------------
# Document: 335
# Document sentence number: 16
# Intermediate summary sentence number: 3
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:00:48:23
# ----------------------------------
# Document: 336
# Document sentence number: 18
# Intermediate summary sentence number: 3
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:06
# Total processing time: 01:00:48:30
# ----------------------------------
# Document: 337
# Document sentence number: 47
# Intermediate summary sentence number: 9
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:11
# Total processing time: 01:00:48:41
# ----------------------------------
# Document: 338
# Document sentence number: 23
# Intermediate summary sentence number: 4
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:06
# Total processing time: 01:00:48:47
# ----------------------------------
# Document: 339
# Document sentence number: 46
# Intermediate summary sentence number: 9
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:12
# Total processing time: 01:00:48:59
# ----------------------------------
# Document: 340
# Document sentence number: 45
# Intermediate summary sentence number: 9
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:12
# Total processing time: 01:00:49:12
# ----------------------------------
# Document: 341
# Document sentence number: 28
# Intermediate summary sentence number: 5
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:08
# Total processing time: 01:00:49:21
# ----------------------------------
# Document: 342
# Document sentence number: 45
# Intermediate summary sentence number: 9
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:14
# Total processing time: 01:00:49:35
# ----------------------------------
# Document: 343
# Document sentence number: 59
# Intermediate summary sentence number: 11
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:14
# Total processing time: 01:00:49:50
# ----------------------------------
# Document: 344
# Document sentence number: 68
# Intermediate summary sentence number: 13
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:17
# Total processing time: 01:00:50:07
# ----------------------------------
# Document: 345
# Document sentence number: 22
# Intermediate summary sentence number: 4
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:06
# Total processing time: 01:00:50:13
# ----------------------------------
# Document: 346
# Document sentence number: 30
# Intermediate summary sentence number: 6
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:10
# Total processing time: 01:00:50:23
# ----------------------------------
# Document: 347
# Document sentence number: 14
# Intermediate summary sentence number: 2
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:05
# Total processing time: 01:00:50:29
# ----------------------------------
# Document: 348
# Document sentence number: 13
# Intermediate summary sentence number: 2
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:04
# Total processing time: 01:00:50:33
# ----------------------------------
# Document: 349
# Document sentence number: 17
# Intermediate summary sentence number: 3
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:00:50:40
# ----------------------------------
# Document: 350
# Document sentence number: 32
# Intermediate summary sentence number: 6
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:06
# Total processing time: 01:00:50:47
# ----------------------------------
# Document: 351
# Document sentence number: 9
# Intermediate summary sentence number: 1
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:05
# Total processing time: 01:00:50:53
# ----------------------------------
# Document: 352
# Document sentence number: 66
# Intermediate summary sentence number: 13
# Optimum cluster number: 3
# Final summary sentence number: 3
# Document processing time: 00:16
# Total processing time: 01:00:51:10
# ----------------------------------
# Document: 353
# Document sentence number: 32
# Intermediate summary sentence number: 6
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:00:51:17
# ----------------------------------
# Document: 354
# Document sentence number: 24
# Intermediate summary sentence number: 4
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:00:51:25
# ----------------------------------
# Document: 355
# Document sentence number: 16
# Intermediate summary sentence number: 3
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:05
# Total processing time: 01:00:51:31
# ----------------------------------
# Document: 356
# Document sentence number: 13
# Intermediate summary sentence number: 2
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:05
# Total processing time: 01:00:51:36
# ----------------------------------
# Document: 357
# Document sentence number: 19
# Intermediate summary sentence number: 3
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:06
# Total processing time: 01:00:51:43
# ----------------------------------
# Document: 358
# Document sentence number: 38
# Intermediate summary sentence number: 7
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:08
# Total processing time: 01:00:51:52
# ----------------------------------
# Document: 359
# Document sentence number: 54
# Intermediate summary sentence number: 10
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:15
# Total processing time: 01:00:52:07
# ----------------------------------
# Document: 360
# Document sentence number: 17
# Intermediate summary sentence number: 3
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:05
# Total processing time: 01:00:52:13
# ----------------------------------
# Document: 361
# Document sentence number: 47
# Intermediate summary sentence number: 9
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:12
# Total processing time: 01:00:52:25
# ----------------------------------
# Document: 362
# Document sentence number: 25
# Intermediate summary sentence number: 5
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:06
# Total processing time: 01:00:52:32
# ----------------------------------
# Document: 363
# Document sentence number: 15
# Intermediate summary sentence number: 3
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:06
# Total processing time: 01:00:52:38
# ----------------------------------
# Document: 364
# Document sentence number: 10
# Intermediate summary sentence number: 2
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:04
# Total processing time: 01:00:52:43
# ----------------------------------
# Document: 365
# Document sentence number: 23
# Intermediate summary sentence number: 4
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:00:52:50
# ----------------------------------
# Document: 366
# Document sentence number: 42
# Intermediate summary sentence number: 8
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:08
# Total processing time: 01:00:52:58
# ----------------------------------
# Document: 367
# Document sentence number: 31
# Intermediate summary sentence number: 6
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:09
# Total processing time: 01:00:53:08
# ----------------------------------
# Document: 368
# Document sentence number: 23
# Intermediate summary sentence number: 4
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:05
# Total processing time: 01:00:53:13
# ----------------------------------
# Document: 369
# Document sentence number: 33
# Intermediate summary sentence number: 6
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:09
# Total processing time: 01:00:53:22
# ----------------------------------
# Document: 370
# Document sentence number: 57
# Intermediate summary sentence number: 11
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:15
# Total processing time: 01:00:53:38
# ----------------------------------
# Document: 371
# Document sentence number: 13
# Intermediate summary sentence number: 2
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:04
# Total processing time: 01:00:53:43
# ----------------------------------
# Document: 372
# Document sentence number: 41
# Intermediate summary sentence number: 8
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:09
# Total processing time: 01:00:53:53
# ----------------------------------
# Document: 373
# Document sentence number: 52
# Intermediate summary sentence number: 10
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:12
# Total processing time: 01:00:54:05
# ----------------------------------
# Document: 374
# Document sentence number: 14
# Intermediate summary sentence number: 2
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:04
# Total processing time: 01:00:54:10
# ----------------------------------
# Document: 375
# Document sentence number: 65
# Intermediate summary sentence number: 13
# Optimum cluster number: 3
# Final summary sentence number: 3
# Document processing time: 00:15
# Total processing time: 01:00:54:25
# ----------------------------------
# Document: 376
# Document sentence number: 28
# Intermediate summary sentence number: 5
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:00:54:33
# ----------------------------------
# Document: 377
# Document sentence number: 9
# Intermediate summary sentence number: 1
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:04
# Total processing time: 01:00:54:37
# ----------------------------------
# Document: 378
# Document sentence number: 14
# Intermediate summary sentence number: 2
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:05
# Total processing time: 01:00:54:42
# ----------------------------------
# Document: 379
# Document sentence number: 40
# Intermediate summary sentence number: 8
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:09
# Total processing time: 01:00:54:52
# ----------------------------------
# Document: 380
# Document sentence number: 35
# Intermediate summary sentence number: 7
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:00:55:00
# ----------------------------------
# Document: 381
# Document sentence number: 22
# Intermediate summary sentence number: 4
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:06
# Total processing time: 01:00:55:07
# ----------------------------------
# Document: 382
# Document sentence number: 18
# Intermediate summary sentence number: 3
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:05
# Total processing time: 01:00:55:12
# ----------------------------------
# Document: 383
# Document sentence number: 38
# Intermediate summary sentence number: 7
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:11
# Total processing time: 01:00:55:23
# ----------------------------------
# Document: 384
# Document sentence number: 12
# Intermediate summary sentence number: 2
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:04
# Total processing time: 01:00:55:28
# ----------------------------------
# Document: 385
# Document sentence number: 49
# Intermediate summary sentence number: 9
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:11
# Total processing time: 01:00:55:39
# ----------------------------------
# Document: 386
# Document sentence number: 30
# Intermediate summary sentence number: 6
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:08
# Total processing time: 01:00:55:48
# ----------------------------------
# Document: 387
# Document sentence number: 24
# Intermediate summary sentence number: 4
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:00:55:55
# ----------------------------------
# Document: 388
# Document sentence number: 26
# Intermediate summary sentence number: 5
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:08
# Total processing time: 01:00:56:03
# ----------------------------------
# Document: 389
# Document sentence number: 25
# Intermediate summary sentence number: 5
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:06
# Total processing time: 01:00:56:09
# ----------------------------------
# Document: 390
# Document sentence number: 28
# Intermediate summary sentence number: 5
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:08
# Total processing time: 01:00:56:18
# ----------------------------------
# Document: 391
# Document sentence number: 57
# Intermediate summary sentence number: 10
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:16
# Total processing time: 01:00:56:34
# ----------------------------------
# Document: 392
# Document sentence number: 104
# Intermediate summary sentence number: 20
# Optimum cluster number: 3
# Final summary sentence number: 3
# Document processing time: 00:19
# Total processing time: 01:00:56:54
# ----------------------------------
# Document: 393
# Document sentence number: 36
# Intermediate summary sentence number: 7
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:09
# Total processing time: 01:00:57:03
# ----------------------------------
# Document: 394
# Document sentence number: 10
# Intermediate summary sentence number: 2
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:04
# Total processing time: 01:00:57:08
# ----------------------------------
# Document: 395
# Document sentence number: 38
# Intermediate summary sentence number: 7
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:09
# Total processing time: 01:00:57:18
# ----------------------------------
# Document: 396
# Document sentence number: 18
# Intermediate summary sentence number: 3
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:06
# Total processing time: 01:00:57:24
# ----------------------------------
# Document: 397
# Document sentence number: 18
# Intermediate summary sentence number: 3
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:00:57:31
# ----------------------------------
# Document: 398
# Document sentence number: 32
# Intermediate summary sentence number: 6
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:00:57:38
# ----------------------------------
# Document: 399
# Document sentence number: 44
# Intermediate summary sentence number: 8
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:09
# Total processing time: 01:00:57:48
# ----------------------------------
# Document: 400
# Document sentence number: 14
# Intermediate summary sentence number: 2
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:04
# Total processing time: 01:00:57:52
# ----------------------------------
# Document: 401
# Document sentence number: 32
# Intermediate summary sentence number: 6
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:09
# Total processing time: 01:00:58:02
# ----------------------------------
# Document: 402
# Document sentence number: 17
# Intermediate summary sentence number: 3
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:05
# Total processing time: 01:00:58:07
# ----------------------------------
# Document: 403
# Document sentence number: 11
# Intermediate summary sentence number: 2
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:05
# Total processing time: 01:00:58:13
# ----------------------------------
# Document: 404
# Document sentence number: 12
# Intermediate summary sentence number: 2
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:04
# Total processing time: 01:00:58:17
# ----------------------------------
# Document: 405
# Document sentence number: 68
# Intermediate summary sentence number: 13
# Optimum cluster number: 3
# Final summary sentence number: 3
# Document processing time: 00:16
# Total processing time: 01:00:58:34
# ----------------------------------
# Document: 406
# Document sentence number: 64
# Intermediate summary sentence number: 12
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:13
# Total processing time: 01:00:58:47
# ----------------------------------
# Document: 407
# Document sentence number: 62
# Intermediate summary sentence number: 12
# Optimum cluster number: 3
# Final summary sentence number: 3
# Document processing time: 00:14
# Total processing time: 01:00:59:01
# ----------------------------------
# Document: 408
# Document sentence number: 13
# Intermediate summary sentence number: 2
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:05
# Total processing time: 01:00:59:07
# ----------------------------------
# Document: 409
# Document sentence number: 53
# Intermediate summary sentence number: 10
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:13
# Total processing time: 01:00:59:20
# ----------------------------------
# Document: 410
# Document sentence number: 34
# Intermediate summary sentence number: 6
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:08
# Total processing time: 01:00:59:29
# ----------------------------------
# Document: 411
# Document sentence number: 17
# Intermediate summary sentence number: 3
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:05
# Total processing time: 01:00:59:34
# ----------------------------------
# Document: 412
# Document sentence number: 82
# Intermediate summary sentence number: 16
# Optimum cluster number: 4
# Final summary sentence number: 4
# Document processing time: 00:17
# Total processing time: 01:00:59:51
# ----------------------------------
# Document: 413
# Document sentence number: 26
# Intermediate summary sentence number: 5
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:08
# Total processing time: 01:01:00:00
# ----------------------------------
# Document: 414
# Document sentence number: 30
# Intermediate summary sentence number: 6
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:08
# Total processing time: 01:01:00:08
# ----------------------------------
# Document: 415
# Document sentence number: 10
# Intermediate summary sentence number: 2
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:05
# Total processing time: 01:01:00:13
# ----------------------------------
# Document: 416
# Document sentence number: 23
# Intermediate summary sentence number: 4
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:06
# Total processing time: 01:01:00:20
# ----------------------------------
# Document: 417
# Document sentence number: 14
# Intermediate summary sentence number: 2
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:06
# Total processing time: 01:01:00:26
# ----------------------------------
# Document: 418
# Document sentence number: 18
# Intermediate summary sentence number: 3
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:05
# Total processing time: 01:01:00:31
# ----------------------------------
# Document: 419
# Document sentence number: 11
# Intermediate summary sentence number: 2
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:05
# Total processing time: 01:01:00:36
# ----------------------------------
# Document: 420
# Document sentence number: 56
# Intermediate summary sentence number: 11
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:13
# Total processing time: 01:01:00:49
# ----------------------------------
# Document: 421
# Document sentence number: 9
# Intermediate summary sentence number: 1
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:06
# Total processing time: 01:01:00:55
# ----------------------------------
# Document: 422
# Document sentence number: 38
# Intermediate summary sentence number: 7
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:08
# Total processing time: 01:01:01:03
# ----------------------------------
# Document: 423
# Document sentence number: 20
# Intermediate summary sentence number: 4
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:08
# Total processing time: 01:01:01:12
# ----------------------------------
# Document: 424
# Document sentence number: 16
# Intermediate summary sentence number: 3
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:05
# Total processing time: 01:01:01:17
# ----------------------------------
# Document: 425
# Document sentence number: 13
# Intermediate summary sentence number: 2
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:05
# Total processing time: 01:01:01:22
# ----------------------------------
# Document: 426
# Document sentence number: 41
# Intermediate summary sentence number: 8
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:09
# Total processing time: 01:01:01:31
# ----------------------------------
# Document: 427
# Document sentence number: 13
# Intermediate summary sentence number: 2
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:05
# Total processing time: 01:01:01:37
# ----------------------------------
# Document: 428
# Document sentence number: 31
# Intermediate summary sentence number: 6
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:01:01:45
# ----------------------------------
# Document: 429
# Document sentence number: 34
# Intermediate summary sentence number: 6
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:09
# Total processing time: 01:01:01:55
# ----------------------------------
# Document: 430
# Document sentence number: 45
# Intermediate summary sentence number: 9
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:12
# Total processing time: 01:01:02:07
# ----------------------------------
# Document: 431
# Document sentence number: 17
# Intermediate summary sentence number: 3
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:05
# Total processing time: 01:01:02:13
# ----------------------------------
# Document: 432
# Document sentence number: 42
# Intermediate summary sentence number: 8
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:12
# Total processing time: 01:01:02:25
# ----------------------------------
# Document: 433
# Document sentence number: 23
# Intermediate summary sentence number: 4
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:01:02:32
# ----------------------------------
# Document: 434
# Document sentence number: 67
# Intermediate summary sentence number: 13
# Optimum cluster number: 3
# Final summary sentence number: 3
# Document processing time: 00:17
# Total processing time: 01:01:02:49
# ----------------------------------
# Document: 435
# Document sentence number: 9
# Intermediate summary sentence number: 1
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:04
# Total processing time: 01:01:02:54
# ----------------------------------
# Document: 436
# Document sentence number: 58
# Intermediate summary sentence number: 11
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:15
# Total processing time: 01:01:03:09
# ----------------------------------
# Document: 437
# Document sentence number: 41
# Intermediate summary sentence number: 8
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:01:03:17
# ----------------------------------
# Document: 438
# Document sentence number: 27
# Intermediate summary sentence number: 5
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:08
# Total processing time: 01:01:03:25
# ----------------------------------
# Document: 439
# Document sentence number: 29
# Intermediate summary sentence number: 5
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:08
# Total processing time: 01:01:03:34
# ----------------------------------
# Document: 440
# Document sentence number: 37
# Intermediate summary sentence number: 7
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:09
# Total processing time: 01:01:03:44
# ----------------------------------
# Document: 441
# Document sentence number: 19
# Intermediate summary sentence number: 3
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:06
# Total processing time: 01:01:03:51
# ----------------------------------
# Document: 442
# Document sentence number: 21
# Intermediate summary sentence number: 4
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:06
# Total processing time: 01:01:03:57
# ----------------------------------
# Document: 443
# Document sentence number: 67
# Intermediate summary sentence number: 13
# Optimum cluster number: 3
# Final summary sentence number: 3
# Document processing time: 00:16
# Total processing time: 01:01:04:13
# ----------------------------------
# Document: 444
# Document sentence number: 39
# Intermediate summary sentence number: 7
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:09
# Total processing time: 01:01:04:23
# ----------------------------------
# Document: 445
# Document sentence number: 62
# Intermediate summary sentence number: 12
# Optimum cluster number: 3
# Final summary sentence number: 3
# Document processing time: 00:17
# Total processing time: 01:01:04:40
# ----------------------------------
# Document: 446
# Document sentence number: 21
# Intermediate summary sentence number: 4
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:01:04:47
# ----------------------------------
# Document: 447
# Document sentence number: 53
# Intermediate summary sentence number: 10
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:11
# Total processing time: 01:01:04:59
# ----------------------------------
# Document: 448
# Document sentence number: 16
# Intermediate summary sentence number: 3
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:01:05:06
# ----------------------------------
# Document: 449
# Document sentence number: 14
# Intermediate summary sentence number: 2
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:04
# Total processing time: 01:01:05:11
# ----------------------------------
# Document: 450
# Document sentence number: 48
# Intermediate summary sentence number: 9
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:12
# Total processing time: 01:01:05:24
# ----------------------------------
# Document: 451
# Document sentence number: 25
# Intermediate summary sentence number: 5
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:08
# Total processing time: 01:01:05:32
# ----------------------------------
# Document: 452
# Document sentence number: 45
# Intermediate summary sentence number: 9
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:13
# Total processing time: 01:01:05:46
# ----------------------------------
# Document: 453
# Document sentence number: 58
# Intermediate summary sentence number: 11
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:12
# Total processing time: 01:01:05:58
# ----------------------------------
# Document: 454
# Document sentence number: 35
# Intermediate summary sentence number: 7
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:09
# Total processing time: 01:01:06:07
# ----------------------------------
# Document: 455
# Document sentence number: 49
# Intermediate summary sentence number: 9
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:11
# Total processing time: 01:01:06:19
# ----------------------------------
# Document: 456
# Document sentence number: 13
# Intermediate summary sentence number: 2
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:04
# Total processing time: 01:01:06:24
# ----------------------------------
# Document: 457
# Document sentence number: 12
# Intermediate summary sentence number: 2
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:05
# Total processing time: 01:01:06:29
# ----------------------------------
# Document: 458
# Document sentence number: 27
# Intermediate summary sentence number: 5
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:01:06:36
# ----------------------------------
# Document: 459
# Document sentence number: 47
# Intermediate summary sentence number: 9
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:12
# Total processing time: 01:01:06:49
# ----------------------------------
# Document: 460
# Document sentence number: 37
# Intermediate summary sentence number: 7
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:01:06:56
# ----------------------------------
# Document: 461
# Document sentence number: 58
# Intermediate summary sentence number: 11
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:14
# Total processing time: 01:01:07:10
# ----------------------------------
# Document: 462
# Document sentence number: 35
# Intermediate summary sentence number: 7
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:10
# Total processing time: 01:01:07:20
# ----------------------------------
# Document: 463
# Document sentence number: 25
# Intermediate summary sentence number: 5
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:01:07:27
# ----------------------------------
# Document: 464
# Document sentence number: 42
# Intermediate summary sentence number: 8
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:01:07:35
# ----------------------------------
# Document: 465
# Document sentence number: 27
# Intermediate summary sentence number: 5
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:11
# Total processing time: 01:01:07:46
# ----------------------------------
# Document: 466
# Document sentence number: 46
# Intermediate summary sentence number: 9
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:12
# Total processing time: 01:01:07:58
# ----------------------------------
# Document: 467
# Document sentence number: 26
# Intermediate summary sentence number: 5
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:06
# Total processing time: 01:01:08:05
# ----------------------------------
# Document: 468
# Document sentence number: 23
# Intermediate summary sentence number: 4
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:06
# Total processing time: 01:01:08:12
# ----------------------------------
# Document: 469
# Document sentence number: 31
# Intermediate summary sentence number: 6
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:09
# Total processing time: 01:01:08:21
# ----------------------------------
# Document: 470
# Document sentence number: 43
# Intermediate summary sentence number: 8
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:10
# Total processing time: 01:01:08:32
# ----------------------------------
# Document: 471
# Document sentence number: 14
# Intermediate summary sentence number: 2
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:04
# Total processing time: 01:01:08:36
# ----------------------------------
# Document: 472
# Document sentence number: 21
# Intermediate summary sentence number: 4
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:06
# Total processing time: 01:01:08:42
# ----------------------------------
# Document: 473
# Document sentence number: 19
# Intermediate summary sentence number: 3
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:06
# Total processing time: 01:01:08:48
# ----------------------------------
# Document: 474
# Document sentence number: 21
# Intermediate summary sentence number: 4
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:05
# Total processing time: 01:01:08:54
# ----------------------------------
# Document: 475
# Document sentence number: 15
# Intermediate summary sentence number: 3
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:06
# Total processing time: 01:01:09:01
# ----------------------------------
# Document: 476
# Document sentence number: 57
# Intermediate summary sentence number: 11
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:14
# Total processing time: 01:01:09:16
# ----------------------------------
# Document: 477
# Document sentence number: 12
# Intermediate summary sentence number: 2
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:04
# Total processing time: 01:01:09:20
# ----------------------------------
# Document: 478
# Document sentence number: 34
# Intermediate summary sentence number: 6
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:11
# Total processing time: 01:01:09:32
# ----------------------------------
# Document: 479
# Document sentence number: 29
# Intermediate summary sentence number: 5
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:01:09:39
# ----------------------------------
# Document: 480
# Document sentence number: 37
# Intermediate summary sentence number: 7
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:10
# Total processing time: 01:01:09:49
# ----------------------------------
# Document: 481
# Document sentence number: 15
# Intermediate summary sentence number: 3
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:06
# Total processing time: 01:01:09:55
# ----------------------------------
# Document: 482
# Document sentence number: 48
# Intermediate summary sentence number: 9
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:11
# Total processing time: 01:01:10:06
# ----------------------------------
# Document: 483
# Document sentence number: 37
# Intermediate summary sentence number: 7
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:09
# Total processing time: 01:01:10:16
# ----------------------------------
# Document: 484
# Document sentence number: 25
# Intermediate summary sentence number: 5
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:05
# Total processing time: 01:01:10:22
# ----------------------------------
# Document: 485
# Document sentence number: 48
# Intermediate summary sentence number: 9
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:13
# Total processing time: 01:01:10:35
# ----------------------------------
# Document: 486
# Document sentence number: 11
# Intermediate summary sentence number: 2
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:06
# Total processing time: 01:01:10:42
# ----------------------------------
# Document: 487
# Document sentence number: 59
# Intermediate summary sentence number: 11
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:14
# Total processing time: 01:01:10:56
# ----------------------------------
# Document: 488
# Document sentence number: 76
# Intermediate summary sentence number: 15
# Optimum cluster number: 4
# Final summary sentence number: 4
# Document processing time: 00:15
# Total processing time: 01:01:11:12
# ----------------------------------
# Document: 489
# Document sentence number: 37
# Intermediate summary sentence number: 7
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:01:11:19
# ----------------------------------
# Document: 490
# Document sentence number: 25
# Intermediate summary sentence number: 5
# ...
# Document: 939
# Document sentence number: 14
# Intermediate summary sentence number: 2
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:05
# Total processing time: 01:02:15:46
# ----------------------------------
# Document: 940
# Document sentence number: 17
# Intermediate summary sentence number: 3
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:06
# Total processing time: 01:02:15:52
# ----------------------------------
# Document: 941
# Document sentence number: 81
# Intermediate summary sentence number: 15
# Optimum cluster number: 4
# Final summary sentence number: 4
# Document processing time: 00:21
# Total processing time: 01:02:16:14
# ----------------------------------
# Document: 942
# Document sentence number: 37
# Intermediate summary sentence number: 7
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:09
# Total processing time: 01:02:16:24
# ----------------------------------
# Document: 943
# Document sentence number: 34
# Intermediate summary sentence number: 6
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:20
# Total processing time: 01:02:16:44
# ----------------------------------
# Document: 944
# Document sentence number: 37
# Intermediate summary sentence number: 7
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:10
# Total processing time: 01:02:16:54
# ----------------------------------
# Document: 945
# Document sentence number: 39
# Intermediate summary sentence number: 7
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:09
# Total processing time: 01:02:17:04
# ----------------------------------
# Document: 946
# Document sentence number: 17
# Intermediate summary sentence number: 3
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:05
# Total processing time: 01:02:17:09
# ----------------------------------
# Document: 947
# Document sentence number: 9
# Intermediate summary sentence number: 1
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:04
# Total processing time: 01:02:17:13
# ----------------------------------
# Document: 948
# Document sentence number: 10
# Intermediate summary sentence number: 2
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:06
# Total processing time: 01:02:17:20
# ----------------------------------
# Document: 949
# Document sentence number: 68
# Intermediate summary sentence number: 13
# Optimum cluster number: 3
# Final summary sentence number: 3
# Document processing time: 00:13
# Total processing time: 01:02:17:33
# ----------------------------------
# Document: 950
# Document sentence number: 18
# Intermediate summary sentence number: 3
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:06
# Total processing time: 01:02:17:39
# ----------------------------------
# Document: 951
# Document sentence number: 52
# Intermediate summary sentence number: 10
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:13
# Total processing time: 01:02:17:52
# ----------------------------------
# Document: 952
# Document sentence number: 53
# Intermediate summary sentence number: 10
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:14
# Total processing time: 01:02:18:07
# ----------------------------------
# Document: 953
# Document sentence number: 21
# Intermediate summary sentence number: 4
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:05
# Total processing time: 01:02:18:12
# ----------------------------------
# Document: 954
# Document sentence number: 13
# Intermediate summary sentence number: 2
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:06
# Total processing time: 01:02:18:18
# ----------------------------------
# Document: 955
# Document sentence number: 32
# Intermediate summary sentence number: 6
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:02:18:25
# ----------------------------------
# Document: 956
# Document sentence number: 13
# Intermediate summary sentence number: 2
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:05
# Total processing time: 01:02:18:31
# ----------------------------------
# Document: 957
# Document sentence number: 44
# Intermediate summary sentence number: 8
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:10
# Total processing time: 01:02:18:42
# ----------------------------------
# Document: 958
# Document sentence number: 12
# Intermediate summary sentence number: 2
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:06
# Total processing time: 01:02:18:48
# ----------------------------------
# Document: 959
# Document sentence number: 67
# Intermediate summary sentence number: 13
# Optimum cluster number: 3
# Final summary sentence number: 3
# Document processing time: 00:15
# Total processing time: 01:02:19:04
# ----------------------------------
# Document: 960
# Document sentence number: 45
# Intermediate summary sentence number: 9
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:13
# Total processing time: 01:02:19:17
# ----------------------------------
# Document: 961
# Document sentence number: 20
# Intermediate summary sentence number: 4
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:06
# Total processing time: 01:02:19:23
# ----------------------------------
# Document: 962
# Document sentence number: 33
# Intermediate summary sentence number: 6
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:09
# Total processing time: 01:02:19:32
# ----------------------------------
# Document: 963
# Document sentence number: 13
# Intermediate summary sentence number: 2
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:04
# Total processing time: 01:02:19:37
# ----------------------------------
# Document: 964
# Document sentence number: 15
# Intermediate summary sentence number: 3
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:05
# Total processing time: 01:02:19:42
# ----------------------------------
# Document: 965
# Document sentence number: 72
# Intermediate summary sentence number: 14
# Optimum cluster number: 3
# Final summary sentence number: 3
# Document processing time: 00:21
# Total processing time: 01:02:20:04
# ----------------------------------
# Document: 966
# Document sentence number: 48
# Intermediate summary sentence number: 9
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:14
# Total processing time: 01:02:20:18
# ----------------------------------
# Document: 967
# Document sentence number: 28
# Intermediate summary sentence number: 5
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:10
# Total processing time: 01:02:20:28
# ----------------------------------
# Document: 968
# Document sentence number: 61
# Intermediate summary sentence number: 12
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:15
# Total processing time: 01:02:20:43
# ----------------------------------
# Document: 969
# Document sentence number: 29
# Intermediate summary sentence number: 5
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:08
# Total processing time: 01:02:20:51
# ----------------------------------
# Document: 970
# Document sentence number: 22
# Intermediate summary sentence number: 4
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:02:20:59
# ----------------------------------
# Document: 971
# Document sentence number: 58
# Intermediate summary sentence number: 11
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:15
# Total processing time: 01:02:21:15
# ----------------------------------
# Document: 972
# Document sentence number: 56
# Intermediate summary sentence number: 11
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:14
# Total processing time: 01:02:21:29
# ----------------------------------
# Document: 973
# Document sentence number: 39
# Intermediate summary sentence number: 7
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:02:21:37
# ----------------------------------
# Document: 974
# Document sentence number: 17
# Intermediate summary sentence number: 3
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:06
# Total processing time: 01:02:21:43
# ----------------------------------
# Document: 975
# Document sentence number: 43
# Intermediate summary sentence number: 8
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:09
# Total processing time: 01:02:21:53
# ----------------------------------
# Document: 976
# Document sentence number: 10
# Intermediate summary sentence number: 2
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:06
# Total processing time: 01:02:21:59
# ----------------------------------
# Document: 977
# Document sentence number: 13
# Intermediate summary sentence number: 2
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:05
# Total processing time: 01:02:22:04
# ----------------------------------
# Document: 978
# Document sentence number: 16
# Intermediate summary sentence number: 3
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:05
# Total processing time: 01:02:22:09
# ----------------------------------
# Document: 979
# Document sentence number: 43
# Intermediate summary sentence number: 8
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:09
# Total processing time: 01:02:22:19
# ----------------------------------
# Document: 980
# Document sentence number: 40
# Intermediate summary sentence number: 8
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:09
# Total processing time: 01:02:22:29
# ----------------------------------
# Document: 981
# Document sentence number: 40
# Intermediate summary sentence number: 8
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:02:22:36
# ----------------------------------
# Document: 982
# Document sentence number: 40
# Intermediate summary sentence number: 8
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:10
# Total processing time: 01:02:22:46
# ----------------------------------
# Document: 983
# Document sentence number: 22
# Intermediate summary sentence number: 4
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:06
# Total processing time: 01:02:22:53
# ----------------------------------
# Document: 984
# Document sentence number: 66
# Intermediate summary sentence number: 13
# Optimum cluster number: 3
# Final summary sentence number: 3
# Document processing time: 00:15
# Total processing time: 01:02:23:09
# ----------------------------------
# Document: 985
# Document sentence number: 18
# Intermediate summary sentence number: 3
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:02:23:16
# ----------------------------------
# Document: 986
# Document sentence number: 14
# Intermediate summary sentence number: 2
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:05
# Total processing time: 01:02:23:22
# ----------------------------------
# Document: 987
# Document sentence number: 18
# Intermediate summary sentence number: 3
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:02:23:30
# ----------------------------------
# Document: 988
# Document sentence number: 40
# Intermediate summary sentence number: 8
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:02:23:37
# ----------------------------------
# Document: 989
# Document sentence number: 13
# Intermediate summary sentence number: 2
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:06
# Total processing time: 01:02:23:44
# ----------------------------------
# Document: 990
# Document sentence number: 16
# Intermediate summary sentence number: 3
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:04
# Total processing time: 01:02:23:48
# ----------------------------------
# Document: 991
# Document sentence number: 32
# Intermediate summary sentence number: 6
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:10
# Total processing time: 01:02:23:59
# ----------------------------------
# Document: 992
# Document sentence number: 27
# Intermediate summary sentence number: 5
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:07
# Total processing time: 01:02:24:06
# ----------------------------------
# Document: 993
# Document sentence number: 23
# Intermediate summary sentence number: 4
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:08
# Total processing time: 01:02:24:15
# ----------------------------------
# Document: 994
# Document sentence number: 9
# Intermediate summary sentence number: 1
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:04
# Total processing time: 01:02:24:19
# ----------------------------------
# Document: 995
# Document sentence number: 28
# Intermediate summary sentence number: 5
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:09
# Total processing time: 01:02:24:29
# ----------------------------------
# Document: 996
# Document sentence number: 23
# Intermediate summary sentence number: 4
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:05
# Total processing time: 01:02:24:35
# ----------------------------------
# Document: 997
# Document sentence number: 54
# Intermediate summary sentence number: 10
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:14
# Total processing time: 01:02:24:49
# ----------------------------------
# Document: 998
# Document sentence number: 49
# Intermediate summary sentence number: 9
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:13
# Total processing time: 01:02:25:03
# ----------------------------------
# Document: 999
# Document sentence number: 51
# Intermediate summary sentence number: 10
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:14
# Total processing time: 01:02:25:17
# ----------------------------------
# Document: 1000
# Document sentence number: 109
# Intermediate summary sentence number: 21
# Optimum cluster number: 3
# Final summary sentence number: 3
# Document processing time: 00:24
# Total processing time: 01:02:25:42
# ----------------------------------

# %%
def prepare_results(m, p, r, f):
    return '\t{}:\t{}: {:5.2f}\t{}: {:5.2f}\t{}: {:5.2f}'.format(m, 'P', 100.0 * p, 'R', 100.0 * r, 'F1', 100.0 * f)

def rougeEvaluation(all_hypothesis, all_references):

    for aggregator in ['Avg']:
        print('Evaluation with {}'.format(aggregator))
        apply_avg = aggregator == 'Avg'
        apply_best = aggregator == 'Best'

        evaluator = rouge.Rouge(metrics=['rouge-n', 'rouge-l', 'rouge-w'],
                               max_n=4,
                               limit_length=False,
                               length_limit=1000,
                               length_limit_type='words',
                               apply_avg=apply_avg,
                               apply_best=apply_best,
                               alpha=0.2, # Default F1_score
                               weight_factor=1.2,
                               stemming=True)

        scores = evaluator.get_scores(all_hypothesis, all_references)

        for metric, results in sorted(scores.items(), key=lambda x: x[0]):
            if not apply_avg and not apply_best: # value is a type of list as we evaluate each summary vs each reference
                for hypothesis_id, results_per_ref in enumerate(results):
                    nb_references = len(results_per_ref['p'])
                    for reference_id in range(nb_references):
                        print('\tHypothesis #{} & Reference #{}: '.format(hypothesis_id, reference_id))
                        print('\t' + prepare_results(metric,results_per_ref['p'][reference_id], results_per_ref['r'][reference_id], results_per_ref['f'][reference_id]))
                print()
            else:
                print(prepare_results(metric, results['p'], results['r'], results['f']))
        print()

# %%
rougeEvaluation(all_intermediate_summary, all_goldstandart)
# Out:
# Evaluation with Avg
# 	rouge-1:	P: 18.90	R: 52.56	F1: 35.89
# 	rouge-2:	P:  6.77	R: 17.95	F1: 12.42
# 	rouge-3:	P:  3.40	R:  8.58	F1:  6.02
# 	rouge-4:	P:  2.05	R:  4.94	F1:  3.50
# 	rouge-l:	P: 21.10	R: 49.84	F1: 37.16
# 	rouge-w:	P: 11.78	R: 19.73	F1: 16.20

# %%
rougeEvaluation(all_summary, all_goldstandart)
# Out:
# Evaluation with Avg
# 	rouge-1:	P: 21.35	R: 46.90	F1: 35.22
# 	rouge-2:	P:  7.22	R: 15.77	F1: 11.86
# 	rouge-3:	P:  3.55	R:  7.52	F1:  5.70
# 	rouge-4:	P:  2.13	R:  4.35	F1:  3.31
# 	rouge-l:	P: 23.45	R: 45.21	F1: 36.31
# 	rouge-w:	P: 13.38	R: 17.75	F1: 15.67

# %%
# Play an audio beep. Any audio URL will do.
from google.colab import output
output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')
