# %% [markdown]
# <a href="https://colab.research.google.com/github/tubagokhan/SummarizationHybrid/blob/main/GraphandClusterGovReportNoWRank.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# !pip install datasets
# !pip install torch
# !pip install scikit-learn
# !pip install matplotlib
# !pip install sentence_transformers
# !pip install py-rouge==1.1
# Out:
# Collecting transformers
#   Downloading transformers-4.31.0-py3-none-any.whl (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 15.9 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers)
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 20.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 33.4 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 39.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Installing collected packages: tokenizers, safetensors, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.16.4 safetensors-0.3.1 tokenizers-0.13.3 transformers-4.31.0
# Collecting datasets
#   Downloading datasets-2.13.1-py3-none-any.whl (486 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.2/486.2 kB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.1)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Collecting dill<0.3.7,>=0.3.0 (from datasets)
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.27.1)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.65.0)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 8.8 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.14-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.8.4)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.16.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (3.12.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.11.0->datasets) (4.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, dill, multiprocess, datasets
# Successfully installed datasets-2.13.1 dill-0.3.6 multiprocess-0.70.14 xxhash-3.2.0
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.0.1+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (16.0.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.25.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.41.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.25.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Collecting sentence_transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 2.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.15.2+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.25.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.11.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (3.8.1)
# Collecting sentencepiece (from sentence_transformers)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 25.5 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.16.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (3.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2.27.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (4.7.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (23.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence_transformers) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence_transformers) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence_transformers) (16.0.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2022.10.31)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.3.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence_transformers) (8.1.4)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence_transformers) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence_transformers) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence_transformers) (2.1.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence_transformers) (1.3.0)
# Building wheels for collected packages: sentence_transformers
#   Building wheel for sentence_transformers (setup.py) ... done
#   Created wheel for sentence_transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125926 sha256=284460d32c0154c41dce7a990a26dc7bf8763547e6e71d503f17129ee35e1a5e
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence_transformers
# Installing collected packages: sentencepiece, sentence_transformers
# Successfully installed sentence_transformers-2.2.2 sentencepiece-0.1.99
# Collecting py-rouge==1.1
#   Downloading py_rouge-1.1-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 1.6 MB/s eta 0:00:00
# Installing collected packages: py-rouge
# Successfully installed py-rouge-1.1

# %%
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sentence_transformers import SentenceTransformer
from nltk import sent_tokenize,word_tokenize

import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')

import warnings
warnings.filterwarnings("ignore")
import re

from datasets import load_dataset
from scipy.spatial import distance

import math
from math import*

import rouge

import networkx as nx

import time
from transformers import logging
logging.set_verbosity_error()

import json
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
# Preprocessing method
def preprocess_corpus(text):
    # Remove special characters and extra whitespaces
    text = re.sub(r"[^a-zA-Z0-9\s.]", "", text)
    text = re.sub(r"\s+", " ", text)
    return text

# %% [markdown]
# ## CLUSTER

# %%
#function calculates the optimal number of clusters using the elbow method. The function plots the elbow curve, which shows the inertia values for different cluster numbers. The user can visually inspect the plot to determine the elbow point, indicating the optimal number of clusters.
def find_optimum_clusters(data, max_clusters):
    inertias = []
    for k in range(1, max_clusters + 1):
        kmeans = KMeans(n_clusters=k, random_state=0).fit(data)
        inertias.append(kmeans.inertia_)

    # Plotting the elbow curve
    #plt.plot(range(1, max_clusters + 1), inertias)
    #plt.xlabel("Number of Clusters")
    #plt.ylabel("Inertia")
    #plt.title("Elbow Curve")
    #plt.show()

    # Calculate the optimal number of clusters using the elbow method
    diff = np.diff(inertias)
    acceleration = np.diff(diff)
    opt_cluster_num = acceleration.argmin() + 2  # Adding 2 to get the index of the minimum acceleration
    return opt_cluster_num

# %%
def createSummaryUsingKMeans(corpus, modelName):
    sentences = sent_tokenize(corpus)
    model = SentenceTransformer(modelName)
    sentence_embeddings = model.encode(sentences)

    optimum_clusters = find_optimum_clusters(sentence_embeddings, int(len(sentences) / 3))
    print("Optimum cluster number:", optimum_clusters)

    # Perform kmean clustering
    kmeans = KMeans(n_clusters=optimum_clusters, random_state=0, n_init='auto').fit(sentence_embeddings)

    chosen_sentence_indexes=[]
    for cluster_id in range(optimum_clusters):
        cluster_indices = np.where(kmeans.labels_ == cluster_id)[0]
        sorted_cluster_indices = sorted(cluster_indices, key=lambda x: sentences[x])
        chosen_sentence_index = sorted_cluster_indices[0]  # Select the first sentence from the sorted indices
        chosen_sentence_indexes.append(chosen_sentence_index)

    sorted_indexes=sorted(chosen_sentence_indexes)

    chosen_sentences = []
    for chosen_sentence_index in sorted_indexes:
        chosen_sentences.append(sentences[chosen_sentence_index])

    summary = " ".join(chosen_sentences)

    return summary

# %% [markdown]
# ## GRAPH NODE WEIGHTS

# %%
def allCorpusSentenceRanking(tokenizedCorpus,corpus):
    sentenceRankList=[]
    for i in range(len(tokenizedCorpus)):
        value=sentenceRanking(tokenizedCorpus[i],i,corpus)
        value=round(value,5)
        sentenceRankList.append(value)
    return sentenceRankList

def sentenceRanking(sentence,location,corpus):
    value=0
    value=sentencePosition(sentence,location,corpus)
    value=value+sentenceLength(sentence,corpus)
    value=value+properNoun(sentence,corpus)
    value=value+numericalToken(sentence,corpus)
    return value

def textWordCount(Text):
    number_of_words = word_tokenize(Text)
    count=(len(number_of_words))
    return count

def textSentenceCount(Text):
    number_of_sentences = sent_tokenize(Text)
    count=(len(number_of_sentences))
    return count

def longestSentenceLenght(Text):
    text=sent_tokenize(Text)
    temp=0
    for i in range(len(text)):
        if temp<textWordCount(text[i]):
            temp=textWordCount(text[i])
    return temp

def sentencePosition(sentence,location,corpus):
    N=textSentenceCount(corpus)
    if location+1 == N:
        return 1.0
    elif location==0:
        return 1.0
    else:
        value=(N-location)/N
        return value

def sentenceLength(sentence,corpus):
    return textWordCount(sentence)/longestSentenceLenght(corpus)

def properNoun(sentence,corpus):
    text = nltk.word_tokenize(sentence)
    tagged=nltk.pos_tag(text)
    noProperNoun=0
    #print(tagged)
    for word in tagged:
        if word[1]=='NNP':
            noProperNoun=noProperNoun+1
    #print(noProperNoun)
    return noProperNoun/len(text)

def numericalToken(sentence,corpus):
    text = nltk.word_tokenize(sentence)
    tagged=nltk.pos_tag(text)
    noNumericalToken=0
    #print(tagged)
    for word in tagged:
        if word[1]=='CD':
            noNumericalToken=noNumericalToken+1
  #print(noProperNoun)
    return 1-(noNumericalToken/len(text))

# %% [markdown]
# ## GRAPH

# %%
def cosine(u, v):
    return np.dot(u, v) / (np.linalg.norm(u) * np.linalg.norm(v))

def createGraph(sentences, modelName):
    model = SentenceTransformer(modelName)
    sentence_embeddings = model.encode(sentences)
    sentenceGraph =np.zeros((len(sentences), len(sentences)))
    temp = np.arange(len(sentences))
    for x in range(len(sentences)):
        newTemp= np.delete(temp, x)
        for y in newTemp:
            similarity= cosine(sentence_embeddings[x],sentence_embeddings[y]) # You can change the vector similarity measurement method used when creating graphs. Cosine, euclidean, manhattan and minkowski methods are defined.
            sentenceGraph[x][y]=abs(similarity)
    return sentenceGraph

def findHighestSimilarityRank(similarityMatrix, initialRank):
    newRank=[0] * len(similarityMatrix)
    temp=0
    for i in range(len(similarityMatrix)):
        for j in range(len(similarityMatrix)):
            temp=temp+similarityMatrix[i][j] # sum of total similarity of sentences
        newRank[i]=temp*initialRank[i]
        temp=0

    return newRank

def findHighestSimilarityRankNoWRANK(similarityMatrix, initialRank):

    nodeWeightLSARanks = initialRank

    for x in range(len(initialRank)):
        for y in range(len(initialRank)):
            temp=initialRank[x]+initialRank[y]
            similarityMatrix[x][y]=similarityMatrix[x][y]+temp*0.01
    G = nx.Graph()
    for x in range(len(initialRank)):
        for y in range(len(initialRank)):
            G.add_node(x)
            G.add_edge(x, y, weight=similarityMatrix[x,y] )
    eigenVectorCentrality = nx.eigenvector_centrality(G, max_iter=100, tol=1.0e-6, nstart=None, weight='weight')

    edgeWeightEigenVectorRanks=[0]*len(eigenVectorCentrality)
    for i in range (len(eigenVectorCentrality)):
        edgeWeightEigenVectorRanks[i]=eigenVectorCentrality[i]

    return edgeWeightEigenVectorRanks

def createSummaryUsingGraph(corpus,modelName):
  sentences = sent_tokenize(corpus)
  summaryAmmount= int(len(sentences)*0.2)
  initialRank=allCorpusSentenceRanking(sentences,corpus)
  similarityMatrix=createGraph(sentences,modelName)
  sentencesRank=findHighestSimilarityRankNoWRANK(similarityMatrix, initialRank)

  temp=sorted(sentencesRank)
  threshold=temp[-summaryAmmount]
  summarySentencesIndexes=[]

  for i in range(len(sentencesRank)):
      if sentencesRank[i]>=threshold:
        summarySentencesIndexes.append(i)

  #print(summarySentencesIndexes)
  summary=""
  for i in range(len(summarySentencesIndexes)):
    summary=summary + ' ' +sentences[summarySentencesIndexes[i]]
  return summary

# %%
#MAIN
modelName='all-mpnet-base-v2'

#dataset = load_dataset('cnn_dailymail', '3.0.0')
#corpus = dataset['train']['article'][50]


dataset = load_dataset("ccdv/govreport-summarization")


startTimeforOverall = time.time()
all_intermediate_summary=[]
all_summary=[]
all_goldstandart=[]

N=500
startN=0

for d in range(N):
    startTimeforDocument = time.time()
    print("Document:",startN+d+1)
    corpus=dataset['train']['report'][startN+d]
    corpus = preprocess_corpus(corpus)
    #print(corpus)
    print("Document sentence number:",textSentenceCount(corpus))
    all_goldstandart.append(dataset['train']['summary'][startN+d])

    if (textSentenceCount(corpus)>8):
      intermadiatesummary=createSummaryUsingGraph(corpus, modelName)
      print("Intermediate summary sentence number:",textSentenceCount(intermadiatesummary))
      all_intermediate_summary.append(intermadiatesummary)

      if (textSentenceCount(intermadiatesummary)>8):
        summary=createSummaryUsingKMeans(intermadiatesummary, modelName)
        print("Final summary sentence number:",textSentenceCount(summary))
        all_summary.append(summary)

      else:
        print("Intermediate summary is shorter than 9 sentences, Second step didn't applied")
        all_summary.append(intermadiatesummary)


    else:
      print("Document is shorter than 9 sentences, Summarization didnt apply")
      all_intermediate_summary.append(corpus)
      all_summary.append(corpus)



    elapsedTimeforDocument = time.time() - startTimeforDocument
    elapsedTimeforAll = time.time() - startTimeforOverall
    print('Document processing time: '+time.strftime("%M:%S", time.gmtime(elapsedTimeforDocument)))
    print('Total processing time: '+time.strftime("%d:%H:%M:%S", time.gmtime(elapsedTimeforAll)))

    print("----------------------------------")
# Out:
# Downloading builder script:   0%|          | 0.00/3.22k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/1.63k [00:00<?, ?B/s]
# WARNING:datasets.builder:No config specified, defaulting to: govreport-summarization/document
# Downloading and preparing dataset govreport-summarization/document to /root/.cache/huggingface/datasets/ccdv___govreport-summarization/document/1.0.0/57ca3042de9c40c218cc94084cbc80a99a161036134bfc88112c57d251443590...
# Downloading data:   0%|          | 0.00/271M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/15.4M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/14.2M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Dataset govreport-summarization downloaded and prepared to /root/.cache/huggingface/datasets/ccdv___govreport-summarization/document/1.0.0/57ca3042de9c40c218cc94084cbc80a99a161036134bfc88112c57d251443590. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]
# Document: 1
# Document sentence number: 286
# Downloading (…)a8e1d/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)b20bca8e1d/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)0bca8e1d/config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)e1d/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading (…)a8e1d/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# Downloading (…)8e1d/train_script.py:   0%|          | 0.00/13.1k [00:00<?, ?B/s]
# Downloading (…)b20bca8e1d/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)bca8e1d/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Intermediate summary sentence number: 57
# Optimum cluster number: 13
# Final summary sentence number: 13
# Document processing time: 00:47
# Total processing time: 01:00:00:47
# ----------------------------------
# Document: 2
# Document sentence number: 366
# Intermediate summary sentence number: 72
# Optimum cluster number: 8
# Final summary sentence number: 8
# Document processing time: 00:55
# Total processing time: 01:00:01:42
# ----------------------------------
# Document: 3
# Document sentence number: 212
# Intermediate summary sentence number: 42
# Optimum cluster number: 6
# Final summary sentence number: 6
# Document processing time: 00:23
# Total processing time: 01:00:02:06
# ----------------------------------
# Document: 4
# Document sentence number: 151
# Intermediate summary sentence number: 30
# Optimum cluster number: 8
# Final summary sentence number: 8
# Document processing time: 00:15
# Total processing time: 01:00:02:21
# ----------------------------------
# Document: 5
# Document sentence number: 125
# Intermediate summary sentence number: 25
# Optimum cluster number: 7
# Final summary sentence number: 7
# Document processing time: 00:12
# Total processing time: 01:00:02:34
# ----------------------------------
# Document: 6
# Document sentence number: 161
# Intermediate summary sentence number: 32
# Optimum cluster number: 9
# Final summary sentence number: 9
# Document processing time: 00:17
# Total processing time: 01:00:02:51
# ----------------------------------
# Document: 7
# Document sentence number: 117
# Intermediate summary sentence number: 23
# Optimum cluster number: 6
# Final summary sentence number: 6
# Document processing time: 00:12
# Total processing time: 01:00:03:04
# ----------------------------------
# Document: 8
# Document sentence number: 303
# Intermediate summary sentence number: 60
# Optimum cluster number: 8
# Final summary sentence number: 8
# Document processing time: 00:44
# Total processing time: 01:00:03:48
# ----------------------------------
# Document: 9
# Document sentence number: 166
# Intermediate summary sentence number: 33
# Optimum cluster number: 10
# Final summary sentence number: 10
# Document processing time: 00:17
# Total processing time: 01:00:04:06
# ----------------------------------
# Document: 10
# Document sentence number: 334
# Intermediate summary sentence number: 66
# Optimum cluster number: 17
# Final summary sentence number: 17
# Document processing time: 00:48
# Total processing time: 01:00:04:54
# ----------------------------------
# Document: 11
# Document sentence number: 363
# Intermediate summary sentence number: 72
# Optimum cluster number: 12
# Final summary sentence number: 12
# Document processing time: 00:54
# Total processing time: 01:00:05:49
# ----------------------------------
# Document: 12
# Document sentence number: 111
# Intermediate summary sentence number: 22
# Optimum cluster number: 4
# Final summary sentence number: 4
# Document processing time: 00:13
# Total processing time: 01:00:06:02
# ----------------------------------
# Document: 13
# Document sentence number: 126
# Intermediate summary sentence number: 25
# Optimum cluster number: 5
# Final summary sentence number: 5
# Document processing time: 00:13
# Total processing time: 01:00:06:15
# ----------------------------------
# Document: 14
# Document sentence number: 464
# Intermediate summary sentence number: 92
# Optimum cluster number: 19
# Final summary sentence number: 19
# Document processing time: 01:37
# Total processing time: 01:00:07:53
# ----------------------------------
# Document: 15
# Document sentence number: 159
# Intermediate summary sentence number: 31
# Optimum cluster number: 7
# Final summary sentence number: 7
# Document processing time: 00:17
# Total processing time: 01:00:08:11
# ----------------------------------
# Document: 16
# Document sentence number: 144
# Intermediate summary sentence number: 28
# Optimum cluster number: 5
# Final summary sentence number: 5
# Document processing time: 00:15
# Total processing time: 01:00:08:26
# ----------------------------------
# Document: 17
# Document sentence number: 321
# Intermediate summary sentence number: 63
# Optimum cluster number: 20
# Final summary sentence number: 20
# Document processing time: 00:43
# Total processing time: 01:00:09:09
# ----------------------------------
# Document: 18
# Document sentence number: 574
# Intermediate summary sentence number: 114
# Optimum cluster number: 33
# Final summary sentence number: 33
# Document processing time: 02:19
# Total processing time: 01:00:11:28
# ----------------------------------
# Document: 19
# Document sentence number: 292
# Intermediate summary sentence number: 58
# Optimum cluster number: 10
# Final summary sentence number: 10
# Document processing time: 00:37
# Total processing time: 01:00:12:05
# ----------------------------------
# Document: 20
# Document sentence number: 300
# Intermediate summary sentence number: 60
# Optimum cluster number: 15
# Final summary sentence number: 15
# Document processing time: 00:39
# Total processing time: 01:00:12:45
# ----------------------------------
# Document: 21
# Document sentence number: 207
# Intermediate summary sentence number: 40
# Optimum cluster number: 9
# Final summary sentence number: 9
# Document processing time: 00:22
# Total processing time: 01:00:13:07
# ----------------------------------
# Document: 22
# Document sentence number: 398
# Intermediate summary sentence number: 79
# Optimum cluster number: 20
# Final summary sentence number: 20
# Document processing time: 01:02
# Total processing time: 01:00:14:10
# ----------------------------------
# Document: 23
# Document sentence number: 353
# Intermediate summary sentence number: 70
# Optimum cluster number: 19
# Final summary sentence number: 19
# Document processing time: 00:50
# Total processing time: 01:00:15:00
# ----------------------------------
# Document: 24
# Document sentence number: 242
# Intermediate summary sentence number: 48
# Optimum cluster number: 14
# Final summary sentence number: 14
# Document processing time: 00:29
# Total processing time: 01:00:15:29
# ----------------------------------
# Document: 25
# Document sentence number: 343
# Intermediate summary sentence number: 68
# Optimum cluster number: 20
# Final summary sentence number: 20
# Document processing time: 00:49
# Total processing time: 01:00:16:18
# ----------------------------------
# Document: 26
# Document sentence number: 236
# Intermediate summary sentence number: 47
# Optimum cluster number: 11
# Final summary sentence number: 11
# Document processing time: 00:25
# Total processing time: 01:00:16:44
# ----------------------------------
# Document: 27
# Document sentence number: 689
# Intermediate summary sentence number: 137
# Optimum cluster number: 20
# Final summary sentence number: 20
# Document processing time: 02:40
# Total processing time: 01:00:19:24
# ----------------------------------
# Document: 28
# Document sentence number: 585
# Intermediate summary sentence number: 117
# Optimum cluster number: 26
# Final summary sentence number: 26
# Document processing time: 02:18
# Total processing time: 01:00:21:43
# ----------------------------------
# Document: 29
# Document sentence number: 477
# Intermediate summary sentence number: 95
# Optimum cluster number: 22
# Final summary sentence number: 22
# Document processing time: 01:34
# Total processing time: 01:00:23:17
# ----------------------------------
# Document: 30
# Document sentence number: 193
# Intermediate summary sentence number: 38
# Optimum cluster number: 5
# Final summary sentence number: 5
# Document processing time: 00:23
# Total processing time: 01:00:23:40
# ----------------------------------
# Document: 31
# Document sentence number: 143
# Intermediate summary sentence number: 28
# Optimum cluster number: 6
# Final summary sentence number: 6
# Document processing time: 00:13
# Total processing time: 01:00:23:54
# ----------------------------------
# Document: 32
# Document sentence number: 249
# Intermediate summary sentence number: 49
# Optimum cluster number: 7
# Final summary sentence number: 7
# Document processing time: 00:30
# Total processing time: 01:00:24:24
# ----------------------------------
# Document: 33
# Document sentence number: 205
# Intermediate summary sentence number: 41
# Optimum cluster number: 6
# Final summary sentence number: 6
# Document processing time: 00:23
# Total processing time: 01:00:24:47
# ----------------------------------
# Document: 34
# Document sentence number: 149
# Intermediate summary sentence number: 29
# Optimum cluster number: 8
# Final summary sentence number: 8
# Document processing time: 00:14
# Total processing time: 01:00:25:02
# ----------------------------------
# Document: 35
# Document sentence number: 710
# Intermediate summary sentence number: 142
# Optimum cluster number: 18
# Final summary sentence number: 18
# Document processing time: 02:54
# Total processing time: 01:00:27:57
# ----------------------------------
# Document: 36
# Document sentence number: 217
# Intermediate summary sentence number: 43
# Optimum cluster number: 9
# Final summary sentence number: 9
# Document processing time: 00:25
# Total processing time: 01:00:28:22
# ----------------------------------
# Document: 37
# Document sentence number: 156
# Intermediate summary sentence number: 31
# Optimum cluster number: 6
# Final summary sentence number: 6
# Document processing time: 00:16
# Total processing time: 01:00:28:38
# ----------------------------------
# Document: 38
# Document sentence number: 260
# Intermediate summary sentence number: 52
# Optimum cluster number: 6
# Final summary sentence number: 6
# Document processing time: 00:42
# Total processing time: 01:00:29:20
# ----------------------------------
# Document: 39
# Document sentence number: 215
# Intermediate summary sentence number: 43
# Optimum cluster number: 13
# Final summary sentence number: 13
# Document processing time: 00:24
# Total processing time: 01:00:29:44
# ----------------------------------
# Document: 40
# Document sentence number: 203
# Intermediate summary sentence number: 40
# Optimum cluster number: 11
# Final summary sentence number: 11
# Document processing time: 00:23
# Total processing time: 01:00:30:08
# ----------------------------------
# Document: 41
# Document sentence number: 89
# Intermediate summary sentence number: 17
# Optimum cluster number: 3
# Final summary sentence number: 3
# Document processing time: 00:08
# Total processing time: 01:00:30:17
# ----------------------------------
# Document: 42
# Document sentence number: 127
# Intermediate summary sentence number: 25
# Optimum cluster number: 5
# Final summary sentence number: 5
# Document processing time: 00:12
# Total processing time: 01:00:30:30
# ----------------------------------
# Document: 43
# Document sentence number: 237
# Intermediate summary sentence number: 47
# Optimum cluster number: 10
# Final summary sentence number: 10
# Document processing time: 00:27
# Total processing time: 01:00:30:58
# ----------------------------------
# Document: 44
# Document sentence number: 112
# Intermediate summary sentence number: 22
# Optimum cluster number: 4
# Final summary sentence number: 4
# Document processing time: 00:13
# Total processing time: 01:00:31:12
# ----------------------------------
# Document: 45
# Document sentence number: 120
# Intermediate summary sentence number: 24
# Optimum cluster number: 7
# Final summary sentence number: 7
# Document processing time: 00:12
# Total processing time: 01:00:31:24
# ----------------------------------
# Document: 46
# Document sentence number: 400
# Intermediate summary sentence number: 80
# Optimum cluster number: 11
# Final summary sentence number: 11
# Document processing time: 01:04
# Total processing time: 01:00:32:28
# ----------------------------------
# Document: 47
# Document sentence number: 361
# Intermediate summary sentence number: 72
# Optimum cluster number: 13
# Final summary sentence number: 13
# Document processing time: 00:54
# Total processing time: 01:00:33:22
# ----------------------------------
# Document: 48
# Document sentence number: 423
# Intermediate summary sentence number: 84
# Optimum cluster number: 14
# Final summary sentence number: 14
# Document processing time: 01:10
# Total processing time: 01:00:34:33
# ----------------------------------
# Document: 49
# Document sentence number: 158
# Intermediate summary sentence number: 31
# Optimum cluster number: 4
# Final summary sentence number: 4
# Document processing time: 00:16
# Total processing time: 01:00:34:49
# ----------------------------------
# Document: 50
# Document sentence number: 172
# Intermediate summary sentence number: 34
# Optimum cluster number: 8
# Final summary sentence number: 8
# Document processing time: 00:17
# Total processing time: 01:00:35:06
# ----------------------------------
# Document: 51
# Document sentence number: 187
# Intermediate summary sentence number: 37
# Optimum cluster number: 11
# Final summary sentence number: 11
# Document processing time: 00:21
# Total processing time: 01:00:35:28
# ----------------------------------
# Document: 52
# Document sentence number: 327
# Intermediate summary sentence number: 65
# Optimum cluster number: 7
# Final summary sentence number: 7
# Document processing time: 00:41
# Total processing time: 01:00:36:10
# ----------------------------------
# Document: 53
# Document sentence number: 119
# Intermediate summary sentence number: 23
# Optimum cluster number: 6
# Final summary sentence number: 6
# Document processing time: 00:11
# Total processing time: 01:00:36:22
# ----------------------------------
# Document: 54
# Document sentence number: 75
# Intermediate summary sentence number: 15
# Optimum cluster number: 4
# Final summary sentence number: 4
# Document processing time: 00:08
# Total processing time: 01:00:36:30
# ----------------------------------
# Document: 55
# Document sentence number: 83
# Intermediate summary sentence number: 16
# Optimum cluster number: 4
# Final summary sentence number: 4
# Document processing time: 00:08
# Total processing time: 01:00:36:39
# ----------------------------------
# Document: 56
# Document sentence number: 252
# Intermediate summary sentence number: 50
# Optimum cluster number: 6
# Final summary sentence number: 6
# Document processing time: 00:30
# Total processing time: 01:00:37:10
# ----------------------------------
# Document: 57
# Document sentence number: 121
# Intermediate summary sentence number: 24
# Optimum cluster number: 7
# Final summary sentence number: 7
# Document processing time: 00:13
# Total processing time: 01:00:37:23
# ----------------------------------
# Document: 58
# Document sentence number: 691
# Intermediate summary sentence number: 138
# Optimum cluster number: 36
# Final summary sentence number: 36
# Document processing time: 03:12
# Total processing time: 01:00:40:36
# ----------------------------------
# Document: 59
# Document sentence number: 247
# Intermediate summary sentence number: 49
# Optimum cluster number: 11
# Final summary sentence number: 11
# Document processing time: 00:29
# Total processing time: 01:00:41:05
# ----------------------------------
# Document: 60
# Document sentence number: 168
# Intermediate summary sentence number: 33
# Optimum cluster number: 6
# Final summary sentence number: 6
# Document processing time: 00:17
# Total processing time: 01:00:41:23
# ----------------------------------
# Document: 61
# Document sentence number: 452
# Intermediate summary sentence number: 90
# Optimum cluster number: 28
# Final summary sentence number: 28
# Document processing time: 01:30
# Total processing time: 01:00:42:54
# ----------------------------------
# Document: 62
# Document sentence number: 237
# Intermediate summary sentence number: 47
# Optimum cluster number: 11
# Final summary sentence number: 11
# Document processing time: 00:26
# Total processing time: 01:00:43:20
# ----------------------------------
# Document: 63
# Document sentence number: 369
# Intermediate summary sentence number: 73
# Optimum cluster number: 7
# Final summary sentence number: 7
# Document processing time: 00:52
# Total processing time: 01:00:44:13
# ----------------------------------
# Document: 64
# Document sentence number: 229
# Intermediate summary sentence number: 45
# Optimum cluster number: 13
# Final summary sentence number: 13
# Document processing time: 00:27
# Total processing time: 01:00:44:40
# ----------------------------------
# Document: 65
# Document sentence number: 90
# Intermediate summary sentence number: 18
# Optimum cluster number: 3
# Final summary sentence number: 3
# Document processing time: 00:11
# Total processing time: 01:00:44:52
# ----------------------------------
# Document: 66
# Document sentence number: 300
# Intermediate summary sentence number: 60
# Optimum cluster number: 12
# Final summary sentence number: 12
# Document processing time: 00:39
# Total processing time: 01:00:45:31
# ----------------------------------
# Document: 67
# Document sentence number: 182
# Intermediate summary sentence number: 36
# Optimum cluster number: 8
# Final summary sentence number: 8
# Document processing time: 00:18
# Total processing time: 01:00:45:50
# ----------------------------------
# Document: 68
# Document sentence number: 183
# Intermediate summary sentence number: 36
# Optimum cluster number: 9
# Final summary sentence number: 9
# Document processing time: 00:19
# Total processing time: 01:00:46:09
# ----------------------------------
# Document: 69
# Document sentence number: 181
# Intermediate summary sentence number: 35
# Optimum cluster number: 8
# Final summary sentence number: 8
# Document processing time: 00:18
# Total processing time: 01:00:46:27
# ----------------------------------
# Document: 70
# Document sentence number: 247
# Intermediate summary sentence number: 49
# Optimum cluster number: 11
# Final summary sentence number: 11
# Document processing time: 00:28
# Total processing time: 01:00:46:55
# ----------------------------------
# Document: 71
# Document sentence number: 114
# Intermediate summary sentence number: 22
# Optimum cluster number: 6
# Final summary sentence number: 6
# Document processing time: 00:12
# Total processing time: 01:00:47:08
# ----------------------------------
# Document: 72
# Document sentence number: 680
# Intermediate summary sentence number: 135
# Optimum cluster number: 13
# Final summary sentence number: 13
# Document processing time: 03:01
# Total processing time: 01:00:50:09
# ----------------------------------
# Document: 73
# Document sentence number: 236
# Intermediate summary sentence number: 47
# Optimum cluster number: 13
# Final summary sentence number: 13
# Document processing time: 00:26
# Total processing time: 01:00:50:35
# ----------------------------------
# Document: 74
# Document sentence number: 389
# Intermediate summary sentence number: 77
# Optimum cluster number: 4
# Final summary sentence number: 4
# Document processing time: 00:56
# Total processing time: 01:00:51:32
# ----------------------------------
# Document: 75
# Document sentence number: 442
# Intermediate summary sentence number: 88
# Optimum cluster number: 24
# Final summary sentence number: 24
# Document processing time: 01:24
# Total processing time: 01:00:52:57
# ----------------------------------
# Document: 76
# Document sentence number: 112
# Intermediate summary sentence number: 22
# Optimum cluster number: 5
# Final summary sentence number: 5
# Document processing time: 00:10
# Total processing time: 01:00:53:07
# ----------------------------------
# Document: 77
# Document sentence number: 158
# Intermediate summary sentence number: 31
# Optimum cluster number: 5
# Final summary sentence number: 5
# Document processing time: 00:17
# Total processing time: 01:00:53:24
# ----------------------------------
# Document: 78
# Document sentence number: 89
# Intermediate summary sentence number: 17
# Optimum cluster number: 3
# Final summary sentence number: 3
# Document processing time: 00:09
# Total processing time: 01:00:53:34
# ----------------------------------
# Document: 79
# Document sentence number: 265
# Intermediate summary sentence number: 53
# Optimum cluster number: 13
# Final summary sentence number: 13
# Document processing time: 00:33
# Total processing time: 01:00:54:07
# ----------------------------------
# Document: 80
# Document sentence number: 191
# Intermediate summary sentence number: 38
# Optimum cluster number: 11
# Final summary sentence number: 11
# Document processing time: 00:18
# Total processing time: 01:00:54:26
# ----------------------------------
# Document: 81
# Document sentence number: 107
# Intermediate summary sentence number: 21
# Optimum cluster number: 5
# Final summary sentence number: 5
# Document processing time: 00:10
# Total processing time: 01:00:54:37
# ----------------------------------
# Document: 82
# Document sentence number: 256
# Intermediate summary sentence number: 51
# Optimum cluster number: 12
# Final summary sentence number: 12
# Document processing time: 00:30
# Total processing time: 01:00:55:07
# ----------------------------------
# Document: 83
# Document sentence number: 493
# Intermediate summary sentence number: 98
# Optimum cluster number: 19
# Final summary sentence number: 19
# Document processing time: 01:38
# Total processing time: 01:00:56:46
# ----------------------------------
# Document: 84
# Document sentence number: 396
# Intermediate summary sentence number: 79
# Optimum cluster number: 8
# Final summary sentence number: 8
# Document processing time: 01:00
# Total processing time: 01:00:57:46
# ----------------------------------
# Document: 85
# Document sentence number: 321
# Intermediate summary sentence number: 64
# Optimum cluster number: 17
# Final summary sentence number: 17
# Document processing time: 00:41
# Total processing time: 01:00:58:28
# ----------------------------------
# Document: 86
# Document sentence number: 147
# Intermediate summary sentence number: 29
# Optimum cluster number: 4
# Final summary sentence number: 4
# Document processing time: 00:14
# Total processing time: 01:00:58:42
# ----------------------------------
# Document: 87
# Document sentence number: 769
# Intermediate summary sentence number: 153
# Optimum cluster number: 21
# Final summary sentence number: 21
# Document processing time: 03:42
# Total processing time: 01:01:02:25
# ----------------------------------
# Document: 88
# Document sentence number: 373
# Intermediate summary sentence number: 74
# Optimum cluster number: 13
# Final summary sentence number: 13
# Document processing time: 00:55
# Total processing time: 01:01:03:20
# ----------------------------------
# Document: 89
# Document sentence number: 856
# Intermediate summary sentence number: 170
# Optimum cluster number: 10
# Final summary sentence number: 10
# Document processing time: 04:13
# Total processing time: 01:01:07:34
# ----------------------------------
# Document: 90
# Document sentence number: 95
# Intermediate summary sentence number: 19
# Optimum cluster number: 3
# Final summary sentence number: 3
# Document processing time: 00:09
# Total processing time: 01:01:07:44
# ----------------------------------
# Document: 91
# Document sentence number: 362
# Intermediate summary sentence number: 72
# Optimum cluster number: 6
# Final summary sentence number: 6
# Document processing time: 00:52
# Total processing time: 01:01:08:37
# ----------------------------------
# Document: 92
# Document sentence number: 122
# Intermediate summary sentence number: 24
# Optimum cluster number: 6
# Final summary sentence number: 6
# Document processing time: 00:14
# Total processing time: 01:01:08:52
# ----------------------------------
# Document: 93
# Document sentence number: 130
# Intermediate summary sentence number: 26
# Optimum cluster number: 4
# Final summary sentence number: 4
# Document processing time: 00:13
# Total processing time: 01:01:09:05
# ----------------------------------
# Document: 94
# Document sentence number: 366
# Intermediate summary sentence number: 73
# Optimum cluster number: 7
# Final summary sentence number: 7
# Document processing time: 00:54
# Total processing time: 01:01:10:00
# ----------------------------------
# Document: 95
# Document sentence number: 317
# Intermediate summary sentence number: 63
# Optimum cluster number: 6
# Final summary sentence number: 6
# Document processing time: 00:41
# Total processing time: 01:01:10:41
# ----------------------------------
# Document: 96
# Document sentence number: 409
# Intermediate summary sentence number: 81
# Optimum cluster number: 26
# Final summary sentence number: 26
# Document processing time: 01:07
# Total processing time: 01:01:11:49
# ----------------------------------
# Document: 97
# Document sentence number: 317
# Intermediate summary sentence number: 63
# Optimum cluster number: 8
# Final summary sentence number: 8
# Document processing time: 00:40
# Total processing time: 01:01:12:30
# ----------------------------------
# Document: 98
# Document sentence number: 126
# Intermediate summary sentence number: 25
# Optimum cluster number: 3
# Final summary sentence number: 3
# Document processing time: 00:12
# Total processing time: 01:01:12:43
# ----------------------------------
# Document: 99
# Document sentence number: 191
# Intermediate summary sentence number: 38
# Optimum cluster number: 3
# Final summary sentence number: 3
# Document processing time: 00:19
# Total processing time: 01:01:13:02
# ----------------------------------
# Document: 100
# Document sentence number: 367
# Intermediate summary sentence number: 73
# Optimum cluster number: 20
# Final summary sentence number: 20
# Document processing time: 00:51
# Total processing time: 01:01:13:53
# ----------------------------------
# Document: 101
# Document sentence number: 237
# Intermediate summary sentence number: 47
# Optimum cluster number: 5
# Final summary sentence number: 5
# Document processing time: 00:27
# Total processing time: 01:01:14:21
# ----------------------------------
# Document: 102
# Document sentence number: 291
# Intermediate summary sentence number: 58
# Optimum cluster number: 10
# Final summary sentence number: 10
# Document processing time: 00:36
# Total processing time: 01:01:14:58
# ----------------------------------
# Document: 103
# Document sentence number: 142
# Intermediate summary sentence number: 28
# Optimum cluster number: 7
# Final summary sentence number: 7
# Document processing time: 00:14
# Total processing time: 01:01:15:12
# ----------------------------------
# Document: 104
# Document sentence number: 221
# Intermediate summary sentence number: 44
# Optimum cluster number: 7
# Final summary sentence number: 7
# Document processing time: 00:23
# Total processing time: 01:01:15:35
# ----------------------------------
# Document: 105
# Document sentence number: 330
# Intermediate summary sentence number: 66
# Optimum cluster number: 10
# Final summary sentence number: 10
# Document processing time: 00:43
# Total processing time: 01:01:16:19
# ----------------------------------
# Document: 106
# Document sentence number: 281
# Intermediate summary sentence number: 56
# Optimum cluster number: 15
# Final summary sentence number: 15
# Document processing time: 00:34
# Total processing time: 01:01:16:53
# ----------------------------------
# Document: 107
# Document sentence number: 177
# Intermediate summary sentence number: 35
# Optimum cluster number: 10
# Final summary sentence number: 10
# Document processing time: 00:18
# Total processing time: 01:01:17:11
# ----------------------------------
# Document: 108
# Document sentence number: 124
# Intermediate summary sentence number: 24
# Optimum cluster number: 7
# Final summary sentence number: 7
# Document processing time: 00:13
# Total processing time: 01:01:17:25
# ----------------------------------
# Document: 109
# Document sentence number: 268
# Intermediate summary sentence number: 53
# Optimum cluster number: 4
# Final summary sentence number: 4
# Document processing time: 00:32
# Total processing time: 01:01:17:57
# ----------------------------------
# Document: 110
# Document sentence number: 156
# Intermediate summary sentence number: 31
# Optimum cluster number: 3
# Final summary sentence number: 3
# Document processing time: 00:15
# Total processing time: 01:01:18:13
# ----------------------------------
# Document: 111
# Document sentence number: 247
# Intermediate summary sentence number: 49
# Optimum cluster number: 11
# Final summary sentence number: 11
# Document processing time: 00:29
# Total processing time: 01:01:18:43
# ----------------------------------
# Document: 112
# Document sentence number: 282
# Intermediate summary sentence number: 56
# Optimum cluster number: 15
# Final summary sentence number: 15
# Document processing time: 00:32
# Total processing time: 01:01:19:16
# ----------------------------------
# Document: 113
# Document sentence number: 129
# Intermediate summary sentence number: 25
# Optimum cluster number: 5
# Final summary sentence number: 5
# Document processing time: 00:12
# Total processing time: 01:01:19:28
# ----------------------------------
# Document: 114
# Document sentence number: 221
# Intermediate summary sentence number: 44
# Optimum cluster number: 10
# Final summary sentence number: 10
# Document processing time: 00:23
# Total processing time: 01:01:19:52
# ----------------------------------
# Document: 115
# Document sentence number: 294
# Intermediate summary sentence number: 58
# Optimum cluster number: 13
# Final summary sentence number: 13
# Document processing time: 00:37
# Total processing time: 01:01:20:29
# ----------------------------------
# Document: 116
# Document sentence number: 126
# Intermediate summary sentence number: 25
# Optimum cluster number: 6
# Final summary sentence number: 6
# Document processing time: 00:12
# Total processing time: 01:01:20:41
# ----------------------------------
# Document: 117
# Document sentence number: 308
# Intermediate summary sentence number: 61
# Optimum cluster number: 5
# Final summary sentence number: 5
# Document processing time: 00:37
# Total processing time: 01:01:21:19
# ----------------------------------
# Document: 118
# Document sentence number: 576
# Intermediate summary sentence number: 113
# Optimum cluster number: 22
# Final summary sentence number: 22
# Document processing time: 02:08
# Total processing time: 01:01:23:28
# ----------------------------------
# Document: 119
# Document sentence number: 257
# Intermediate summary sentence number: 51
# Optimum cluster number: 5
# Final summary sentence number: 5
# Document processing time: 00:29
# Total processing time: 01:01:23:57
# ----------------------------------
# Document: 120
# Document sentence number: 65
# Intermediate summary sentence number: 13
# Optimum cluster number: 3
# Final summary sentence number: 3
# Document processing time: 00:07
# Total processing time: 01:01:24:05
# ----------------------------------
# Document: 121
# Document sentence number: 544
# Intermediate summary sentence number: 108
# Optimum cluster number: 21
# Final summary sentence number: 21
# Document processing time: 02:00
# Total processing time: 01:01:26:06
# ----------------------------------
# Document: 122
# Document sentence number: 526
# Intermediate summary sentence number: 105
# Optimum cluster number: 10
# Final summary sentence number: 10
# Document processing time: 01:50
# Total processing time: 01:01:27:56
# ----------------------------------
# Document: 123
# Document sentence number: 588
# Intermediate summary sentence number: 117
# Optimum cluster number: 11
# Final summary sentence number: 11
# Document processing time: 02:08
# Total processing time: 01:01:30:04
# ----------------------------------
# Document: 124
# Document sentence number: 363
# Intermediate summary sentence number: 72
# Optimum cluster number: 18
# Final summary sentence number: 18
# Document processing time: 00:51
# Total processing time: 01:01:30:56
# ----------------------------------
# Document: 125
# Document sentence number: 203
# Intermediate summary sentence number: 40
# Optimum cluster number: 7
# Final summary sentence number: 7
# Document processing time: 00:21
# Total processing time: 01:01:31:17
# ----------------------------------
# Document: 126
# Document sentence number: 331
# Intermediate summary sentence number: 66
# Optimum cluster number: 15
# Final summary sentence number: 15
# Document processing time: 00:45
# Total processing time: 01:01:32:03
# ----------------------------------
# Document: 127
# Document sentence number: 65
# Intermediate summary sentence number: 13
# Optimum cluster number: 3
# Final summary sentence number: 3
# Document processing time: 00:07
# Total processing time: 01:01:32:11
# ----------------------------------
# Document: 128
# Document sentence number: 141
# Intermediate summary sentence number: 28
# Optimum cluster number: 4
# Final summary sentence number: 4
# Document processing time: 00:13
# Total processing time: 01:01:32:24
# ----------------------------------
# Document: 129
# Document sentence number: 127
# Intermediate summary sentence number: 25
# Optimum cluster number: 7
# Final summary sentence number: 7
# Document processing time: 00:12
# Total processing time: 01:01:32:36
# ----------------------------------
# Document: 130
# Document sentence number: 312
# Intermediate summary sentence number: 62
# Optimum cluster number: 8
# Final summary sentence number: 8
# Document processing time: 00:42
# Total processing time: 01:01:33:19
# ----------------------------------
# Document: 131
# Document sentence number: 339
# Intermediate summary sentence number: 67
# Optimum cluster number: 16
# Final summary sentence number: 16
# Document processing time: 00:45
# Total processing time: 01:01:34:04
# ----------------------------------
# Document: 132
# Document sentence number: 300
# Intermediate summary sentence number: 60
# Optimum cluster number: 15
# Final summary sentence number: 15
# Document processing time: 00:39
# Total processing time: 01:01:34:43
# ----------------------------------
# Document: 133
# Document sentence number: 354
# Intermediate summary sentence number: 70
# Optimum cluster number: 8
# Final summary sentence number: 8
# Document processing time: 00:49
# Total processing time: 01:01:35:33
# ----------------------------------
# Document: 134
# Document sentence number: 561
# Intermediate summary sentence number: 112
# Optimum cluster number: 23
# Final summary sentence number: 23
# Document processing time: 02:00
# Total processing time: 01:01:37:34
# ----------------------------------
# Document: 135
# Document sentence number: 113
# Intermediate summary sentence number: 22
# Optimum cluster number: 6
# Final summary sentence number: 6
# Document processing time: 00:11
# Total processing time: 01:01:37:45
# ----------------------------------
# Document: 136
# Document sentence number: 257
# Intermediate summary sentence number: 51
# Optimum cluster number: 6
# Final summary sentence number: 6
# Document processing time: 00:30
# Total processing time: 01:01:38:15
# ----------------------------------
# Document: 137
# Document sentence number: 255
# Intermediate summary sentence number: 51
# Optimum cluster number: 16
# Final summary sentence number: 16
# Document processing time: 00:31
# Total processing time: 01:01:38:47
# ----------------------------------
# Document: 138
# Document sentence number: 135
# Intermediate summary sentence number: 27
# Optimum cluster number: 6
# Final summary sentence number: 6
# Document processing time: 00:15
# Total processing time: 01:01:39:02
# ----------------------------------
# Document: 139
# Document sentence number: 310
# Intermediate summary sentence number: 62
# Optimum cluster number: 10
# Final summary sentence number: 10
# Document processing time: 00:43
# Total processing time: 01:01:39:45
# ----------------------------------
# Document: 140
# Document sentence number: 445
# Intermediate summary sentence number: 89
# Optimum cluster number: 15
# Final summary sentence number: 15
# Document processing time: 01:22
# Total processing time: 01:01:41:08
# ----------------------------------
# Document: 141
# Document sentence number: 183
# Intermediate summary sentence number: 36
# Optimum cluster number: 4
# Final summary sentence number: 4
# Document processing time: 00:18
# Total processing time: 01:01:41:26
# ----------------------------------
# Document: 142
# Document sentence number: 97
# Intermediate summary sentence number: 19
# Optimum cluster number: 5
# Final summary sentence number: 5
# Document processing time: 00:09
# Total processing time: 01:01:41:36
# ----------------------------------
# Document: 143
# Document sentence number: 454
# Intermediate summary sentence number: 90
# Optimum cluster number: 19
# Final summary sentence number: 19
# Document processing time: 01:26
# Total processing time: 01:01:43:03
# ----------------------------------
# Document: 144
# Document sentence number: 67
# Intermediate summary sentence number: 13
# Optimum cluster number: 3
# Final summary sentence number: 3
# Document processing time: 00:08
# Total processing time: 01:01:43:12
# ----------------------------------
# Document: 145
# Document sentence number: 276
# Intermediate summary sentence number: 55
# Optimum cluster number: 11
# Final summary sentence number: 11
# Document processing time: 00:32
# Total processing time: 01:01:43:44
# ----------------------------------
# Document: 146
# Document sentence number: 458
# Intermediate summary sentence number: 91
# Optimum cluster number: 20
# Final summary sentence number: 20
# Document processing time: 01:26
# Total processing time: 01:01:45:10
# ----------------------------------
# Document: 147
# Document sentence number: 187
# Intermediate summary sentence number: 37
# Optimum cluster number: 9
# Final summary sentence number: 9
# Document processing time: 00:19
# Total processing time: 01:01:45:30
# ----------------------------------
# Document: 148
# Document sentence number: 295
# Intermediate summary sentence number: 59
# Optimum cluster number: 7
# Final summary sentence number: 7
# Document processing time: 00:39
# Total processing time: 01:01:46:09
# ----------------------------------
# Document: 149
# Document sentence number: 210
# Intermediate summary sentence number: 42
# Optimum cluster number: 5
# Final summary sentence number: 5
# Document processing time: 00:26
# Total processing time: 01:01:46:35
# ----------------------------------
# Document: 150
# Document sentence number: 298
# Intermediate summary sentence number: 59
# Optimum cluster number: 10
# Final summary sentence number: 10
# Document processing time: 00:35
# Total processing time: 01:01:47:11
# ----------------------------------
# Document: 151
# Document sentence number: 80
# Intermediate summary sentence number: 16
# Optimum cluster number: 3
# Final summary sentence number: 3
# Document processing time: 00:09
# Total processing time: 01:01:47:20
# ----------------------------------
# Document: 152
# Document sentence number: 349
# Intermediate summary sentence number: 69
# Optimum cluster number: 8
# Final summary sentence number: 8
# Document processing time: 00:44
# Total processing time: 01:01:48:05
# ----------------------------------
# Document: 153
# Document sentence number: 569
# Intermediate summary sentence number: 113
# Optimum cluster number: 10
# Final summary sentence number: 10
# Document processing time: 02:16
# Total processing time: 01:01:50:21
# ----------------------------------
# Document: 154
# Document sentence number: 432
# Intermediate summary sentence number: 86
# Optimum cluster number: 13
# Final summary sentence number: 13
# Document processing time: 01:22
# Total processing time: 01:01:51:44
# ----------------------------------
# Document: 155
# Document sentence number: 149
# Intermediate summary sentence number: 29
# Optimum cluster number: 7
# Final summary sentence number: 7
# Document processing time: 00:13
# Total processing time: 01:01:51:58
# ----------------------------------
# Document: 156
# Document sentence number: 621
# Intermediate summary sentence number: 124
# Optimum cluster number: 10
# Final summary sentence number: 10
# Document processing time: 02:25
# Total processing time: 01:01:54:24
# ----------------------------------
# Document: 157
# Document sentence number: 85
# Intermediate summary sentence number: 17
# Optimum cluster number: 4
# Final summary sentence number: 4
# Document processing time: 00:09
# Total processing time: 01:01:54:33
# ----------------------------------
# Document: 158
# Document sentence number: 90
# Intermediate summary sentence number: 18
# Optimum cluster number: 5
# Final summary sentence number: 5
# Document processing time: 00:09
# Total processing time: 01:01:54:42
# ----------------------------------
# Document: 159
# Document sentence number: 130
# Intermediate summary sentence number: 26
# Optimum cluster number: 6
# Final summary sentence number: 6
# Document processing time: 00:12
# Total processing time: 01:01:54:55
# ----------------------------------
# Document: 160
# Document sentence number: 316
# Intermediate summary sentence number: 63
# Optimum cluster number: 15
# Final summary sentence number: 15
# Document processing time: 00:42
# Total processing time: 01:01:55:38
# ----------------------------------
# Document: 161
# Document sentence number: 726
# Intermediate summary sentence number: 145
# Optimum cluster number: 34
# Final summary sentence number: 34
# Document processing time: 03:03
# Total processing time: 01:01:58:41
# ----------------------------------
# Document: 162
# Document sentence number: 113
# Intermediate summary sentence number: 22
# Optimum cluster number: 6
# Final summary sentence number: 6
# Document processing time: 00:11
# Total processing time: 01:01:58:53
# ----------------------------------
# Document: 163
# Document sentence number: 73
# Intermediate summary sentence number: 14
# Optimum cluster number: 3
# Final summary sentence number: 3
# Document processing time: 00:08
# Total processing time: 01:01:59:01
# ----------------------------------
# Document: 164
# Document sentence number: 316
# Intermediate summary sentence number: 63
# Optimum cluster number: 20
# Final summary sentence number: 20
# Document processing time: 00:45
# Total processing time: 01:01:59:46
# ----------------------------------
# Document: 165
# Document sentence number: 261
# Intermediate summary sentence number: 52
# Optimum cluster number: 12
# Final summary sentence number: 12
# Document processing time: 00:30
# Total processing time: 01:02:00:16
# ----------------------------------
# Document: 166
# Document sentence number: 117
# Intermediate summary sentence number: 23
# Optimum cluster number: 6
# Final summary sentence number: 6
# Document processing time: 00:10
# Total processing time: 01:02:00:27
# ----------------------------------
# Document: 167
# Document sentence number: 415
# Intermediate summary sentence number: 82
# Optimum cluster number: 21
# Final summary sentence number: 21
# Document processing time: 01:11
# Total processing time: 01:02:01:39
# ----------------------------------
# Document: 168
# Document sentence number: 101
# Intermediate summary sentence number: 20
# Optimum cluster number: 5
# Final summary sentence number: 5
# Document processing time: 00:09
# Total processing time: 01:02:01:48
# ----------------------------------
# Document: 169
# Document sentence number: 273
# Intermediate summary sentence number: 54
# Optimum cluster number: 7
# Final summary sentence number: 7
# Document processing time: 00:33
# Total processing time: 01:02:02:22
# ----------------------------------
# Document: 170
# Document sentence number: 71
# Intermediate summary sentence number: 14
# Optimum cluster number: 3
# Final summary sentence number: 3
# Document processing time: 00:07
# Total processing time: 01:02:02:29
# ----------------------------------
# Document: 171
# Document sentence number: 148
# Intermediate summary sentence number: 29
# Optimum cluster number: 4
# Final summary sentence number: 4
# Document processing time: 00:15
# Total processing time: 01:02:02:44
# ----------------------------------
# Document: 172
# Document sentence number: 528
# Intermediate summary sentence number: 105
# Optimum cluster number: 20
# Final summary sentence number: 20
# Document processing time: 01:55
# Total processing time: 01:02:04:40
# ----------------------------------
# Document: 173
# Document sentence number: 167
# Intermediate summary sentence number: 33
# Optimum cluster number: 9
# Final summary sentence number: 9
# Document processing time: 00:17
# Total processing time: 01:02:04:58
# ----------------------------------
# Document: 174
# Document sentence number: 115
# Intermediate summary sentence number: 23
# Optimum cluster number: 6
# Final summary sentence number: 6
# Document processing time: 00:10
# Total processing time: 01:02:05:08
# ----------------------------------
# Document: 175
# Document sentence number: 196
# Intermediate summary sentence number: 39
# Optimum cluster number: 3
# Final summary sentence number: 3
# Document processing time: 00:19
# Total processing time: 01:02:05:28
# ----------------------------------
# Document: 176
# Document sentence number: 344
# Intermediate summary sentence number: 68
# Optimum cluster number: 11
# Final summary sentence number: 11
# Document processing time: 00:47
# Total processing time: 01:02:06:16
# ----------------------------------
# Document: 177
# Document sentence number: 416
# Intermediate summary sentence number: 83
# Optimum cluster number: 7
# Final summary sentence number: 7
# Document processing time: 01:05
# Total processing time: 01:02:07:22
# ----------------------------------
# Document: 178
# Document sentence number: 350
# Intermediate summary sentence number: 70
# Optimum cluster number: 10
# Final summary sentence number: 10
# Document processing time: 00:48
# Total processing time: 01:02:08:10
# ----------------------------------
# Document: 179
# Document sentence number: 257
# Intermediate summary sentence number: 51
# Optimum cluster number: 6
# Final summary sentence number: 6
# Document processing time: 00:30
# Total processing time: 01:02:08:41
# ----------------------------------
# Document: 180
# Document sentence number: 392
# Intermediate summary sentence number: 77
# Optimum cluster number: 9
# Final summary sentence number: 9
# Document processing time: 00:56
# Total processing time: 01:02:09:38
# ----------------------------------
# Document: 181
# Document sentence number: 346
# Intermediate summary sentence number: 69
# Optimum cluster number: 17
# Final summary sentence number: 17
# Document processing time: 00:48
# Total processing time: 01:02:10:26
# ----------------------------------
# Document: 182
# Document sentence number: 326
# Intermediate summary sentence number: 65
# Optimum cluster number: 11
# Final summary sentence number: 11
# Document processing time: 00:43
# Total processing time: 01:02:11:09
# ----------------------------------
# Document: 183
# Document sentence number: 309
# Intermediate summary sentence number: 60
# Optimum cluster number: 13
# Final summary sentence number: 13
# Document processing time: 00:38
# Total processing time: 01:02:11:47
# ----------------------------------
# Document: 184
# Document sentence number: 225
# Intermediate summary sentence number: 45
# Optimum cluster number: 11
# Final summary sentence number: 11
# Document processing time: 00:26
# Total processing time: 01:02:12:14
# ----------------------------------
# Document: 185
# Document sentence number: 178
# Intermediate summary sentence number: 35
# Optimum cluster number: 9
# Final summary sentence number: 9
# Document processing time: 00:18
# Total processing time: 01:02:12:32
# ----------------------------------
# Document: 186
# Document sentence number: 228
# Intermediate summary sentence number: 45
# Optimum cluster number: 10
# Final summary sentence number: 10
# Document processing time: 00:25
# Total processing time: 01:02:12:58
# ...
# Optimum cluster number: 13
# Final summary sentence number: 13
# Document processing time: 00:55
# Total processing time: 01:05:49:06
# ----------------------------------
# Document: 437
# Document sentence number: 265
# Intermediate summary sentence number: 53
# Optimum cluster number: 5
# Final summary sentence number: 5
# Document processing time: 00:30
# Total processing time: 01:05:49:37
# ----------------------------------
# Document: 438
# Document sentence number: 612
# Intermediate summary sentence number: 122
# Optimum cluster number: 37
# Final summary sentence number: 37
# Document processing time: 02:25
# Total processing time: 01:05:52:02
# ----------------------------------
# Document: 439
# Document sentence number: 343
# Intermediate summary sentence number: 68
# Optimum cluster number: 21
# Final summary sentence number: 21
# Document processing time: 00:44
# Total processing time: 01:05:52:47
# ----------------------------------
# Document: 440
# Document sentence number: 438
# Intermediate summary sentence number: 87
# Optimum cluster number: 9
# Final summary sentence number: 9
# Document processing time: 01:21
# Total processing time: 01:05:54:08
# ----------------------------------
# Document: 441
# Document sentence number: 393
# Intermediate summary sentence number: 78
# Optimum cluster number: 18
# Final summary sentence number: 18
# Document processing time: 00:58
# Total processing time: 01:05:55:07
# ----------------------------------
# Document: 442
# Document sentence number: 13
# Intermediate summary sentence number: 2
# Intermediate summary is shorter than 9 sentences, Second step didn't applied
# Document processing time: 00:02
# Total processing time: 01:05:55:09
# ----------------------------------
# Document: 443
# Document sentence number: 258
# Intermediate summary sentence number: 51
# Optimum cluster number: 14
# Final summary sentence number: 14
# Document processing time: 00:37
# Total processing time: 01:05:55:46
# ----------------------------------
# Document: 444
# Document sentence number: 546
# Intermediate summary sentence number: 109
# Optimum cluster number: 33
# Final summary sentence number: 33
# Document processing time: 01:55
# Total processing time: 01:05:57:42
# ----------------------------------
# Document: 445
# Document sentence number: 282
# Intermediate summary sentence number: 56
# Optimum cluster number: 9
# Final summary sentence number: 9
# Document processing time: 00:33
# Total processing time: 01:05:58:16
# ----------------------------------
# Document: 446
# Document sentence number: 173
# Intermediate summary sentence number: 34
# Optimum cluster number: 10
# Final summary sentence number: 10
# Document processing time: 00:18
# Total processing time: 01:05:58:35
# ----------------------------------
# Document: 447
# Document sentence number: 407
# Intermediate summary sentence number: 81
# Optimum cluster number: 14
# Final summary sentence number: 14
# Document processing time: 01:09
# Total processing time: 01:05:59:44
# ----------------------------------
# Document: 448
# Document sentence number: 97
# Intermediate summary sentence number: 19
# Optimum cluster number: 5
# Final summary sentence number: 5
# Document processing time: 00:12
# Total processing time: 01:05:59:56
# ----------------------------------
# Document: 449
# Document sentence number: 364
# Intermediate summary sentence number: 72
# Optimum cluster number: 14
# Final summary sentence number: 14
# Document processing time: 00:52
# Total processing time: 01:06:00:49
# ----------------------------------
# Document: 450
# Document sentence number: 85
# Intermediate summary sentence number: 17
# Optimum cluster number: 3
# Final summary sentence number: 3
# Document processing time: 00:08
# Total processing time: 01:06:00:57
# ----------------------------------
# Document: 451
# Document sentence number: 342
# Intermediate summary sentence number: 68
# Optimum cluster number: 13
# Final summary sentence number: 13
# Document processing time: 00:46
# Total processing time: 01:06:01:43
# ----------------------------------
# Document: 452
# Document sentence number: 1028
# Intermediate summary sentence number: 205
# Optimum cluster number: 11
# Final summary sentence number: 11
# Document processing time: 05:29
# Total processing time: 01:06:07:13
# ----------------------------------
# Document: 453
# Document sentence number: 213
# Intermediate summary sentence number: 42
# Optimum cluster number: 5
# Final summary sentence number: 5
# Document processing time: 00:24
# Total processing time: 01:06:07:38
# ----------------------------------
# Document: 454
# Document sentence number: 296
# Intermediate summary sentence number: 59
# Optimum cluster number: 16
# Final summary sentence number: 16
# Document processing time: 00:37
# Total processing time: 01:06:08:15
# ----------------------------------
# Document: 455
# Document sentence number: 126
# Intermediate summary sentence number: 25
# Optimum cluster number: 5
# Final summary sentence number: 5
# Document processing time: 00:13
# Total processing time: 01:06:08:29
# ----------------------------------
# Document: 456
# Document sentence number: 119
# Intermediate summary sentence number: 23
# Optimum cluster number: 4
# Final summary sentence number: 4
# Document processing time: 00:11
# Total processing time: 01:06:08:41
# ----------------------------------
# Document: 457
# Document sentence number: 289
# Intermediate summary sentence number: 57
# Optimum cluster number: 6
# Final summary sentence number: 6
# Document processing time: 00:36
# Total processing time: 01:06:09:17
# ----------------------------------
# Document: 458
# Document sentence number: 341
# Intermediate summary sentence number: 68
# Optimum cluster number: 12
# Final summary sentence number: 12
# Document processing time: 00:47
# Total processing time: 01:06:10:04
# ----------------------------------
# Document: 459
# Document sentence number: 108
# Intermediate summary sentence number: 21
# Optimum cluster number: 5
# Final summary sentence number: 5
# Document processing time: 00:11
# Total processing time: 01:06:10:16
# ----------------------------------
# Document: 460
# Document sentence number: 75
# Intermediate summary sentence number: 15
# Optimum cluster number: 4
# Final summary sentence number: 4
# Document processing time: 00:07
# Total processing time: 01:06:10:24
# ----------------------------------
# Document: 461
# Document sentence number: 171
# Intermediate summary sentence number: 34
# Optimum cluster number: 5
# Final summary sentence number: 4
# Document processing time: 00:17
# Total processing time: 01:06:10:41
# ----------------------------------
# Document: 462
# Document sentence number: 304
# Intermediate summary sentence number: 60
# Optimum cluster number: 7
# Final summary sentence number: 7
# Document processing time: 00:39
# Total processing time: 01:06:11:21
# ----------------------------------
# Document: 463
# Document sentence number: 236
# Intermediate summary sentence number: 47
# Optimum cluster number: 6
# Final summary sentence number: 6
# Document processing time: 00:29
# Total processing time: 01:06:11:50
# ----------------------------------
# Document: 464
# Document sentence number: 499
# Intermediate summary sentence number: 99
# Optimum cluster number: 20
# Final summary sentence number: 20
# Document processing time: 01:43
# Total processing time: 01:06:13:34
# ----------------------------------
# Document: 465
# Document sentence number: 156
# Intermediate summary sentence number: 31
# Optimum cluster number: 8
# Final summary sentence number: 8
# Document processing time: 00:16
# Total processing time: 01:06:13:50
# ----------------------------------
# Document: 466
# Document sentence number: 157
# Intermediate summary sentence number: 31
# Optimum cluster number: 9
# Final summary sentence number: 9
# Document processing time: 00:15
# Total processing time: 01:06:14:06
# ----------------------------------
# Document: 467
# Document sentence number: 219
# Intermediate summary sentence number: 43
# Optimum cluster number: 4
# Final summary sentence number: 4
# Document processing time: 00:24
# Total processing time: 01:06:14:31
# ----------------------------------
# Document: 468
# Document sentence number: 84
# Intermediate summary sentence number: 16
# Optimum cluster number: 4
# Final summary sentence number: 4
# Document processing time: 00:09
# Total processing time: 01:06:14:40
# ----------------------------------
# Document: 469
# Document sentence number: 420
# Intermediate summary sentence number: 84
# Optimum cluster number: 6
# Final summary sentence number: 6
# Document processing time: 01:11
# Total processing time: 01:06:15:52
# ----------------------------------
# Document: 470
# Document sentence number: 336
# Intermediate summary sentence number: 67
# Optimum cluster number: 15
# Final summary sentence number: 15
# Document processing time: 00:46
# Total processing time: 01:06:16:39
# ----------------------------------
# Document: 471
# Document sentence number: 423
# Intermediate summary sentence number: 84
# Optimum cluster number: 20
# Final summary sentence number: 20
# Document processing time: 01:09
# Total processing time: 01:06:17:49
# ----------------------------------
# Document: 472
# Document sentence number: 382
# Intermediate summary sentence number: 76
# Optimum cluster number: 10
# Final summary sentence number: 10
# Document processing time: 00:54
# Total processing time: 01:06:18:44
# ----------------------------------
# Document: 473
# Document sentence number: 68
# Intermediate summary sentence number: 13
# Optimum cluster number: 2
# Final summary sentence number: 2
# Document processing time: 00:07
# Total processing time: 01:06:18:51
# ----------------------------------
# Document: 474
# Document sentence number: 434
# Intermediate summary sentence number: 86
# Optimum cluster number: 16
# Final summary sentence number: 16
# Document processing time: 01:18
# Total processing time: 01:06:20:10
# ----------------------------------
# Document: 475
# Document sentence number: 90
# Intermediate summary sentence number: 18
# Optimum cluster number: 4
# Final summary sentence number: 4
# Document processing time: 00:09
# Total processing time: 01:06:20:19
# ----------------------------------
# Document: 476
# Document sentence number: 404
# Intermediate summary sentence number: 80
# Optimum cluster number: 17
# Final summary sentence number: 17
# Document processing time: 01:03
# Total processing time: 01:06:21:22
# ----------------------------------
# Document: 477
# Document sentence number: 259
# Intermediate summary sentence number: 51
# Optimum cluster number: 9
# Final summary sentence number: 9
# Document processing time: 00:30
# Total processing time: 01:06:21:53
# ----------------------------------
# Document: 478
# Document sentence number: 373
# Intermediate summary sentence number: 74
# Optimum cluster number: 8
# Final summary sentence number: 8
# Document processing time: 00:55
# Total processing time: 01:06:22:49
# ----------------------------------
# Document: 479
# Document sentence number: 172
# Intermediate summary sentence number: 34
# Optimum cluster number: 9
# Final summary sentence number: 9
# Document processing time: 00:18
# Total processing time: 01:06:23:07
# ----------------------------------
# Document: 480
# Document sentence number: 213
# Intermediate summary sentence number: 41
# Optimum cluster number: 9
# Final summary sentence number: 8
# Document processing time: 00:24
# Total processing time: 01:06:23:32
# ----------------------------------
# Document: 481
# Document sentence number: 151
# Intermediate summary sentence number: 30
# Optimum cluster number: 8
# Final summary sentence number: 8
# Document processing time: 00:16
# Total processing time: 01:06:23:49
# ----------------------------------
# Document: 482
# Document sentence number: 283
# Intermediate summary sentence number: 56
# Optimum cluster number: 9
# Final summary sentence number: 9
# Document processing time: 00:35
# Total processing time: 01:06:24:24
# ----------------------------------
# Document: 483
# Document sentence number: 312
# Intermediate summary sentence number: 62
# Optimum cluster number: 9
# Final summary sentence number: 9
# Document processing time: 00:42
# Total processing time: 01:06:25:07
# ----------------------------------
# Document: 484
# Document sentence number: 217
# Intermediate summary sentence number: 43
# Optimum cluster number: 9
# Final summary sentence number: 9
# Document processing time: 00:25
# Total processing time: 01:06:25:33
# ----------------------------------
# Document: 485
# Document sentence number: 159
# Intermediate summary sentence number: 31
# Optimum cluster number: 7
# Final summary sentence number: 7
# Document processing time: 00:16
# Total processing time: 01:06:25:50
# ----------------------------------
# Document: 486
# Document sentence number: 154
# Intermediate summary sentence number: 30
# Optimum cluster number: 9
# Final summary sentence number: 9
# Document processing time: 00:16
# Total processing time: 01:06:26:06
# ----------------------------------
# Document: 487
# Document sentence number: 265
# Intermediate summary sentence number: 53
# Optimum cluster number: 8
# Final summary sentence number: 8
# Document processing time: 00:31
# Total processing time: 01:06:26:38
# ----------------------------------
# Document: 488
# Document sentence number: 609
# Intermediate summary sentence number: 121
# Optimum cluster number: 22
# Final summary sentence number: 22
# Document processing time: 02:31
# Total processing time: 01:06:29:10
# ----------------------------------
# Document: 489
# Document sentence number: 482
# Intermediate summary sentence number: 96
# Optimum cluster number: 14
# Final summary sentence number: 14
# Document processing time: 01:46
# Total processing time: 01:06:30:56
# ----------------------------------
# Document: 490
# Document sentence number: 309
# Intermediate summary sentence number: 61
# Optimum cluster number: 13
# Final summary sentence number: 13
# Document processing time: 00:42
# Total processing time: 01:06:31:39
# ----------------------------------
# Document: 491
# Document sentence number: 297
# Intermediate summary sentence number: 59
# Optimum cluster number: 8
# Final summary sentence number: 8
# Document processing time: 00:39
# Total processing time: 01:06:32:18
# ----------------------------------
# Document: 492
# Document sentence number: 466
# Intermediate summary sentence number: 93
# Optimum cluster number: 9
# Final summary sentence number: 9
# Document processing time: 01:36
# Total processing time: 01:06:33:54
# ----------------------------------
# Document: 493
# Document sentence number: 445
# Intermediate summary sentence number: 89
# Optimum cluster number: 7
# Final summary sentence number: 7
# Document processing time: 01:27
# Total processing time: 01:06:35:21
# ----------------------------------
# Document: 494
# Document sentence number: 185
# Intermediate summary sentence number: 37
# Optimum cluster number: 5
# Final summary sentence number: 5
# Document processing time: 00:19
# Total processing time: 01:06:35:40
# ----------------------------------
# Document: 495
# Document sentence number: 140
# Intermediate summary sentence number: 28
# Optimum cluster number: 5
# Final summary sentence number: 5
# Document processing time: 00:14
# Total processing time: 01:06:35:55
# ----------------------------------
# Document: 496
# Document sentence number: 486
# Intermediate summary sentence number: 97
# Optimum cluster number: 13
# Final summary sentence number: 13
# Document processing time: 01:41
# Total processing time: 01:06:37:36
# ----------------------------------
# Document: 497
# Document sentence number: 186
# Intermediate summary sentence number: 37
# Optimum cluster number: 8
# Final summary sentence number: 8
# Document processing time: 00:19
# Total processing time: 01:06:37:56
# ----------------------------------
# Document: 498
# Document sentence number: 466
# Intermediate summary sentence number: 93
# Optimum cluster number: 23
# Final summary sentence number: 23
# Document processing time: 01:34
# Total processing time: 01:06:39:30
# ----------------------------------
# Document: 499
# Document sentence number: 129
# Intermediate summary sentence number: 25
# Optimum cluster number: 3
# Final summary sentence number: 3
# Document processing time: 00:13
# Total processing time: 01:06:39:43
# ----------------------------------
# Document: 500
# Document sentence number: 117
# Intermediate summary sentence number: 23
# Optimum cluster number: 4
# Final summary sentence number: 4
# Document processing time: 00:11
# Total processing time: 01:06:39:55
# ----------------------------------

# %%
def prepare_results(m, p, r, f):
    return '\t{}:\t{}: {:5.2f}\t{}: {:5.2f}\t{}: {:5.2f}'.format(m, 'P', 100.0 * p, 'R', 100.0 * r, 'F1', 100.0 * f)

def rougeEvaluation(all_hypothesis, all_references):

    for aggregator in ['Avg']:
        print('Evaluation with {}'.format(aggregator))
        apply_avg = aggregator == 'Avg'
        apply_best = aggregator == 'Best'

        evaluator = rouge.Rouge(metrics=['rouge-n', 'rouge-l', 'rouge-w'],
                               max_n=4,
                               limit_length=False,
                               length_limit=1000,
                               length_limit_type='words',
                               apply_avg=apply_avg,
                               apply_best=apply_best,
                               alpha=0.2, # Default F1_score
                               weight_factor=1.2,
                               stemming=True)

        scores = evaluator.get_scores(all_hypothesis, all_references)

        for metric, results in sorted(scores.items(), key=lambda x: x[0]):
            if not apply_avg and not apply_best: # value is a type of list as we evaluate each summary vs each reference
                for hypothesis_id, results_per_ref in enumerate(results):
                    nb_references = len(results_per_ref['p'])
                    for reference_id in range(nb_references):
                        print('\tHypothesis #{} & Reference #{}: '.format(hypothesis_id, reference_id))
                        print('\t' + prepare_results(metric,results_per_ref['p'][reference_id], results_per_ref['r'][reference_id], results_per_ref['f'][reference_id]))
                print()
            else:
                print(prepare_results(metric, results['p'], results['r'], results['f']))
        print()

# %%
rougeEvaluation(all_intermediate_summary, all_goldstandart)
# Out:
# Evaluation with Avg
# 	rouge-1:	P: 25.71	R: 80.70	F1: 50.82
# 	rouge-2:	P: 11.97	R: 39.95	F1: 24.52
# 	rouge-3:	P:  6.29	R: 21.11	F1: 12.89
# 	rouge-4:	P:  3.98	R: 13.28	F1:  8.10
# 	rouge-l:	P: 16.76	R: 46.32	F1: 31.67
# 	rouge-w:	P:  6.32	R:  6.29	F1:  5.70

# %%
rougeEvaluation(all_summary, all_goldstandart)
# Out:
# Evaluation with Avg
# 	rouge-1:	P: 59.56	R: 40.05	F1: 40.48
# 	rouge-2:	P: 19.76	R: 12.71	F1: 12.89
# 	rouge-3:	P:  8.38	R:  5.18	F1:  5.28
# 	rouge-4:	P:  4.54	R:  2.69	F1:  2.75
# 	rouge-l:	P: 33.44	R: 22.88	F1: 23.37
# 	rouge-w:	P: 15.30	R:  2.86	F1:  3.31

# %%
# Play an audio beep. Any audio URL will do.
from google.colab import output
output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')

# %%
# Save files

import json
import os

# Define the file path
file_path = "/content/savedDocumentsandSummaries.json"  # Replace with the desired file path

# Check if the file already exists
if os.path.exists(file_path):
    # Read the existing data from the JSON file
    with open(file_path, "r") as file:
        existing_data = json.load(file)

    # Combine the existing data with the new data (lists)
    existing_intermediate_summary = existing_data.get("all_intermediate_summary", [])
    existing_summary = existing_data.get("all_summary", [])
    existing_goldstandart = existing_data.get("all_goldstandart", [])

    # Assuming you have three new lists: new_intermediate_summary, new_summary, new_goldstandart
    # Sample new lists (replace these with your actual lists)
    new_intermediate_summary = all_intermediate_summary
    new_summary = all_summary
    new_goldstandart = all_goldstandart


    # Merge the new lists with the existing ones
    all_intermediate_summary = existing_intermediate_summary + new_intermediate_summary
    all_summary = existing_summary + new_summary
    all_goldstandart = existing_goldstandart + new_goldstandart

# Combine the lists into a dictionary for easy serialization
data = {
    "all_intermediate_summary": all_intermediate_summary,
    "all_summary": all_summary,
    "all_goldstandart": all_goldstandart
}

# Save the data to a JSON file
with open(file_path, "w") as file:
    json.dump(data, file)

print("Lists have been saved to", file_path)
# Out:
# Lists have been saved to /content/savedDocumentsandSummaries.json

# %%
print(len(data['all_summary']))
# Out:
# 500

# %%
rougeEvaluation(data['all_intermediate_summary'], data['all_goldstandart'])
# Out:
# Evaluation with Avg
# 	rouge-1:	P: 25.71	R: 80.70	F1: 50.82
# 	rouge-2:	P: 11.97	R: 39.95	F1: 24.52
# 	rouge-3:	P:  6.29	R: 21.11	F1: 12.89
# 	rouge-4:	P:  3.98	R: 13.28	F1:  8.10
# 	rouge-l:	P: 16.76	R: 46.32	F1: 31.67
# 	rouge-w:	P:  6.32	R:  6.29	F1:  5.70

# %%
rougeEvaluation(data['all_summary'], data['all_goldstandart'])
# Out:
# Evaluation with Avg
# 	rouge-1:	P: 59.56	R: 40.05	F1: 40.48
# 	rouge-2:	P: 19.76	R: 12.71	F1: 12.89
# 	rouge-3:	P:  8.38	R:  5.18	F1:  5.28
# 	rouge-4:	P:  4.54	R:  2.69	F1:  2.75
# 	rouge-l:	P: 33.44	R: 22.88	F1: 23.37
# 	rouge-w:	P: 15.30	R:  2.86	F1:  3.31

# %%
# Play an audio beep. Any audio URL will do.
from google.colab import output
output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')
